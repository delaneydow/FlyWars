# %%
#Algorithm outline and testing
""" goal is to remove the 'static object' detection and just have the moving object detection then see how viable this approach is 
compared to static AND moving object detection like in algorithm 1 implementation. The goal is to be able to track moving flies at near real-time"""
# Out:
# " goal is to remove the 'static object' detection and just have the moving object detection then see how viable this approach is \ncompared to static AND moving object detection like in algorithm 1 implementation. The goal is to be able to track moving flies at near real-time"

# %%
# === PART 1: DETECT & LOCALIZE FLIES PER FRAME ===
""" goal is to record latency of frame substraction, ensure that program can keep track of multiple flies in each frame """

#imports
import cv2
import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import linear_sum_assignment
from collections import deque
from state import classify_state

# %%
#constants
VIDEO_PATH = "LUCID_TRI032S-M_251700592__20251114112116359_video3.avi" #path to AVI file
DOWNSCALE = 1.0 #<1.0 to downscale frames for speed
THRESH_VAL = 25 # frame subtraction threshold
MIN_AREA = 5 # minimum blob area (pixels)
MAX_AREA = 300 # max blob area (pixels)
MAX_MISSED = 5 # allows tracks to survive 5 frames without a detection
MAX_TRACK_DIST = 50 # max distance for track association (pixels)
HISTORY = 50 # frame to keep for plotting
MAX_TRACKS = 150 # TODO tune this
FRAME_CAP = 100 #only saves a select group of frames for quick validation

# ROI Configuration
# define ROI as fractions of frame dimensions
ROI_X_MIN = 0.5
ROI_Y_MIN = 0.0

# Precomputed morphology kernels (create once)
kernel3 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3,3))
kernel5 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5,5))

# Precompute a small circle mask for radius 6
CIRCLE_RADIUS = 20
circle_mask = np.zeros((2*CIRCLE_RADIUS+1, 2*CIRCLE_RADIUS+1), dtype=np.uint8)
cv2.circle(circle_mask, (CIRCLE_RADIUS, CIRCLE_RADIUS), CIRCLE_RADIUS, 255, -1)

#visualization frames
DRAW_EVERY = 3

#kalman constants
FPS = 60.0 # or read from video metadata
DT = 1.0 / FPS

# %%
#tracking class
class Track: 
    def __init__(self, track_id, centroid): 
        self.id = track_id
        self.centroids = deque(maxlen=HISTORY)
        self.centroids.append(centroid)
        #self.last_seen = 0 # frame idx when last seen
        self.missed = 0 # num of consecutive frames w/o detection

        # ADD KALMAN STATE
        # using initial vector [x, y, vx, vy]T
        self.kf = cv2.KalmanFilter(4,2)
        
        self.kf.transitionMatrix = np.array([
            [1, 0, DT, 0],
            [0, 1, 0, DT], 
            [0, 0, 1, 0], 
            [0, 0, 0, 1]], dtype=np.float32)

        self.kf.measurementMatrix=np.array([
            [1, 0, 0, 0],
            [0, 1, 0, 0]], dtype=np.float32)

        self.kf.processNoiseCov = np.eye(4, dtype=np.float32) *1e-2
        self.kf.measurementNoiseCov = np.eye(2, dtype=np.float32) * 1e-1

        self.kf.statePre = np.array([[centroid[0]],
                                     [centroid[1]],
                                     [0],
                                     [0]], dtype=np.float32)

    def predict(self): 
        pred = self.kf.predict()
        return pred[0,0], pred[1,0]

    def update(self, detection=None):
        if detection is not None: 
            measured = np.array([[np.float32(detection[0])],
                                 [np.float32(detection[1])]])
            self.kf.correct(measured)
            
            x = int(self.kf.statePost[0,0])
            y = int(self.kf.statePost[1,0])
            self.centroids.append((x,y))
            self.missed = 0
        else:
            self.centroids.append(self.centroids[-1])
            self.missed += 1

    @property
    def last_position(self): 
        return self.centroids[-1] # returns last position stored in centroid

# %%
# utility functions
def preprocess_and_crop(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    #gray =cv2.equalizeHist(gray)

    h, w = gray.shape 

    # Define ROI fractions (example: right half)
    x0 = int(ROI_X_MIN * w)
    y0 = int(ROI_Y_MIN * h)
    x1 = w
    y1 = h

    roi = gray[y0:y1, x0:x1]

    # force consistent minimum size
    if roi.shape[0] < 8 or roi.shape[1] < 8:
        raise ValueError(f"ROI too small: {roi.shape} from frame {gray.shape}")

    return roi, (x0, y0)


def detect_moving_objects_fast(prev_gray, curr_gray):
    diff = cv2.absdiff(curr_gray, prev_gray)
    diff = cv2.GaussianBlur(diff, (5,5), 0)
    _, thresh = cv2.threshold(diff, THRESH_VAL, 255, cv2.THRESH_BINARY)
    # reuse kernel3, do NOT create a new one
    thresh = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel3)

    num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh)
    detections = []
    for i in range(1, num_labels):
        area = stats[i, cv2.CC_STAT_AREA]
        if MIN_AREA <= area <= MAX_AREA:
            cx, cy = centroids[i]
            detections.append((int(cx), int(cy)))
    return detections, thresh


def associate_detections_to_tracking_fast(detections, tracks, next_id):
    
    # USING EARLY-EXIT GATED REPLACEMENT
    if not detections: 
        for t in tracks: 
            t.update(None)
            #t.missed +=1 
            # repeat last position for smooth trajectory; TODO see if needed
            #t.centroids.append(t.last_position)
        return [t for t in tracks if t.missed <= MAX_MISSED], next_id

    used = [False] * len(detections)
    max_dist_sq = MAX_TRACK_DIST * MAX_TRACK_DIST

    # match existing tracks using greedy algorithm 
    for t in tracks: 
        px, py =t.predict()
        best_idx = -1
        best_dist_sq = max_dist_sq

        #early-exit dist gating
        for i, (dx, dy) in enumerate(detections): 
            if used[i]: 
                continue
                
            ddx = dx-px 
            ddy = dy-py 
            dist_sq = ddx * ddx + ddy * ddy

            # early accept if very close 
            if dist_sq < best_dist_sq: 
                best_dist_sq = dist_sq
                best_idx = i 
                # optional and TODO TEST hard gate
                if dist_sq < 35: # ~5px
                    break
        if best_idx !=-1: 
            t.update(detections[best_idx])
            used[best_idx]=True
        else:
            t.update(None)

    # generate new tracks ONLY for unmatched detections
    for i, d in enumerate (detections): 
        #if not used[i]: 
        if len(tracks) < MAX_TRACKS: #caps # of tracks to stabilize runtime
            tracks.append(Track(next_id, d))
            next_id += 1

    # remove and prune old tracks
    tracks = [t for t in tracks if t.missed <=MAX_MISSED]

    return tracks, next_id


def deduplicate_tracks(tracks, radius=5): 
    # distance gating in association or deduplication only once every N frames
    # prevent same location collapse
    if len(tracks) <=1: 
        return tracks

    keep = []
    for t in tracks: 
        if not any(np.linalg.norm(
            np.array(t.last_position) - np.array(k.last_position)
        ) < radius for k in keep): 
            keep.append(t)
    return keep

# %%
# MAIN PROCESSING LOOP

def process_video(): 
    print(f"beginning...\n") 
    capture = cv2.VideoCapture(VIDEO_PATH)
    assert capture.isOpened(), "Could not open video file"
    
    ret, frame = capture.read()
    if not ret: 
        raise RuntimeError("Failed to read first frame")
        
    prev_gray, roi_offset = preprocess_and_crop(frame)
    
    # instantiate empty arrays for tracking and latency calculations
    tracks = [] #store tracking in array
    next_track_id = 0 
    #explicit multi-target capacity metrics
    latencies, det_counts, track_counts, frames, thresh_frames = [], [], [], [], []
    # kalman state factoring   
    track_states = {}
    
    
    # precompute grids ONCE
    H, W = prev_gray.shape
    yy, xx = np.mgrid[0:H, 0:W]
    CIRCLE_RADIUS_SQ = CIRCLE_RADIUS ** 2
    
    frame_idx = 0
    
    #begin loop, occurs over duration of video
    while True: 
        ret, frame = capture.read()
        if not ret: 
            break
    
        start_frame = time.perf_counter() #records detection speed
    
         # Preprocess & crop
        start = time.perf_counter()
        curr_gray, _ = preprocess_and_crop(frame)
        t_preprocess = time.perf_counter() - start
    
        # Moving detection
        start = time.perf_counter()
        detections, thresh = detect_moving_objects_fast(prev_gray, curr_gray)
        t_move = time.perf_counter() - start
    
        # tracking only (no merging) 
        start = time.perf_counter()
        tracks, next_track_id = associate_detections_to_tracking_fast(
            detections, tracks, next_track_id
        )
        tracks = deduplicate_tracks(tracks) # one track per fly, protect stationary leak
        t_tracking = time.perf_counter() - start

        #kalman calculations
        for t in tracks: 
            if frame_idx %5 == 0: # only track every 5 frames to gauge velocity better
                track_states[t.id] = classify_state(t)

        
        # Visualization
        start = time.perf_counter()
        visual = cv2.cvtColor(curr_gray, cv2.COLOR_GRAY2BGR)
        cv2.rectangle(visual, (0,0), (visual.shape[1]-1, visual.shape[0]-1), (255,255,0), 1)
        for t in tracks:
            if len(t.centroids) >= 2: 
                cv2.line(visual, t.centroids[-2], t.centroids[-1], (0, 255,0), 1)
            #for i in range(1, len(t.centroids)):
                # repeat n times
                #cv2.line(visual, t.centroids[i-1], t.centroids[i], (0,255,0), 1)
            # do NOT repeat n times (moved outside loop)
            cv2.circle(visual, t.last_position, 3, (0,0,255), -1)
            cv2.putText(visual, f"ID {t.id}", (t.last_position[0]+5, t.last_position[1]-5),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,0,0), 1)
            # ring buffer 
            if frame_idx % 10 == 0:
                frames.append(visual.copy())
                if len(frames) > FRAME_CAP:
                    frames.pop(0)
        t_vis = time.perf_counter() - start
    
        # Metrics
        total_frame = (time.perf_counter() - start_frame) * 1000.0
        print(f"Frame {frame_idx}: preprocess={t_preprocess*1000:.1f}ms, "
              f"move={t_move*1000:.1f}ms, "
              f"tracking={t_tracking*1000:.1f}ms,"
              f"vis={t_vis*1000:.1f}ms, total={total_frame:.1f}ms")

        latencies.append(total_frame)
        det_counts.append(len(detections))
        track_counts.append(len(tracks))

    
        prev_gray = curr_gray
        frame_idx += 1
    

    capture.release()
    print ("Done processing.")
    return latencies, det_counts, track_counts, frames, thresh_frames

# %%
import cProfile
import pstats


latencies, det_counts, track_counts, frames, thresh_frames = process_video()
# Out:
# beginning...
#
# Frame 0: preprocess=1.9ms, move=30.4ms, tracking=0.0ms,vis=1.9ms, total=34.3ms
# Frame 1: preprocess=1.7ms, move=12.7ms, tracking=3.6ms,vis=2.9ms, total=20.9ms
# Frame 2: preprocess=1.8ms, move=11.8ms, tracking=4.8ms,vis=2.5ms, total=20.8ms
# Frame 3: preprocess=1.8ms, move=11.1ms, tracking=0.6ms,vis=2.2ms, total=15.7ms
# Frame 4: preprocess=1.6ms, move=11.6ms, tracking=0.8ms,vis=2.1ms, total=16.1ms
# Frame 5: preprocess=1.8ms, move=11.3ms, tracking=0.9ms,vis=2.7ms, total=17.7ms
# Frame 6: preprocess=1.6ms, move=11.5ms, tracking=0.9ms,vis=2.1ms, total=16.1ms
# Frame 7: preprocess=1.6ms, move=11.9ms, tracking=1.0ms,vis=2.2ms, total=16.8ms
# Frame 8: preprocess=1.7ms, move=12.9ms, tracking=0.9ms,vis=2.2ms, total=17.7ms
# Frame 9: preprocess=1.6ms, move=12.0ms, tracking=0.9ms,vis=1.8ms, total=16.4ms
# Frame 10: preprocess=1.7ms, move=12.3ms, tracking=0.4ms,vis=13.1ms, total=27.7ms
# Frame 11: preprocess=2.1ms, move=12.4ms, tracking=0.7ms,vis=2.4ms, total=17.6ms
# Frame 12: preprocess=2.0ms, move=12.6ms, tracking=0.4ms,vis=2.3ms, total=17.3ms
# Frame 13: preprocess=2.3ms, move=13.0ms, tracking=0.2ms,vis=2.1ms, total=17.5ms
# Frame 14: preprocess=2.1ms, move=13.6ms, tracking=0.0ms,vis=2.2ms, total=18.0ms
# Frame 15: preprocess=2.8ms, move=13.5ms, tracking=0.0ms,vis=1.8ms, total=18.1ms
# Frame 16: preprocess=1.7ms, move=12.2ms, tracking=0.0ms,vis=1.9ms, total=15.9ms
# Frame 17: preprocess=2.0ms, move=11.7ms, tracking=0.0ms,vis=2.4ms, total=16.2ms
# Frame 18: preprocess=1.7ms, move=11.8ms, tracking=0.0ms,vis=2.2ms, total=15.7ms
# Frame 19: preprocess=1.6ms, move=11.6ms, tracking=0.0ms,vis=2.0ms, total=15.1ms
# Frame 20: preprocess=1.5ms, move=12.5ms, tracking=0.0ms,vis=2.5ms, total=16.5ms
# Frame 21: preprocess=1.2ms, move=10.1ms, tracking=0.0ms,vis=1.8ms, total=13.1ms
# Frame 22: preprocess=1.6ms, move=12.0ms, tracking=0.0ms,vis=2.0ms, total=15.6ms
# Frame 23: preprocess=1.5ms, move=11.5ms, tracking=0.0ms,vis=2.1ms, total=15.1ms
# Frame 24: preprocess=1.5ms, move=12.1ms, tracking=0.0ms,vis=2.0ms, total=15.6ms
# Frame 25: preprocess=1.7ms, move=10.8ms, tracking=0.0ms,vis=1.7ms, total=14.3ms
# Frame 26: preprocess=1.8ms, move=12.8ms, tracking=0.3ms,vis=2.3ms, total=17.2ms
# Frame 27: preprocess=1.5ms, move=12.0ms, tracking=0.5ms,vis=1.9ms, total=15.8ms
# Frame 28: preprocess=1.5ms, move=13.3ms, tracking=0.6ms,vis=2.4ms, total=17.8ms
# Frame 29: preprocess=1.6ms, move=9.4ms, tracking=0.6ms,vis=2.1ms, total=13.6ms
# Frame 30: preprocess=1.6ms, move=13.3ms, tracking=0.8ms,vis=12.2ms, total=28.0ms
# Frame 31: preprocess=2.3ms, move=13.5ms, tracking=1.1ms,vis=1.8ms, total=18.8ms
# Frame 32: preprocess=2.0ms, move=12.8ms, tracking=0.9ms,vis=2.2ms, total=17.9ms
# Frame 33: preprocess=1.7ms, move=12.2ms, tracking=0.6ms,vis=1.8ms, total=16.2ms
# Frame 34: preprocess=2.0ms, move=13.0ms, tracking=0.3ms,vis=2.9ms, total=18.2ms
# Frame 35: preprocess=1.5ms, move=11.7ms, tracking=0.1ms,vis=2.3ms, total=15.7ms
# Frame 36: preprocess=1.8ms, move=12.6ms, tracking=0.0ms,vis=2.2ms, total=16.7ms
# Frame 37: preprocess=1.8ms, move=11.2ms, tracking=0.0ms,vis=2.2ms, total=15.3ms
# Frame 38: preprocess=1.7ms, move=12.7ms, tracking=0.0ms,vis=2.6ms, total=17.0ms
# Frame 39: preprocess=1.4ms, move=11.9ms, tracking=0.0ms,vis=1.9ms, total=15.3ms
# Frame 40: preprocess=1.7ms, move=12.9ms, tracking=0.0ms,vis=2.0ms, total=16.7ms
# Frame 41: preprocess=1.7ms, move=12.2ms, tracking=0.0ms,vis=2.2ms, total=16.1ms
# Frame 42: preprocess=1.9ms, move=14.1ms, tracking=0.0ms,vis=2.3ms, total=18.3ms
# Frame 43: preprocess=1.7ms, move=12.6ms, tracking=0.0ms,vis=2.0ms, total=16.3ms
# Frame 44: preprocess=1.6ms, move=11.9ms, tracking=0.0ms,vis=2.0ms, total=15.5ms
# Frame 45: preprocess=1.6ms, move=12.5ms, tracking=0.0ms,vis=2.4ms, total=16.6ms
# Frame 46: preprocess=2.2ms, move=12.7ms, tracking=0.0ms,vis=2.1ms, total=17.0ms
# Frame 47: preprocess=1.6ms, move=13.2ms, tracking=0.0ms,vis=2.6ms, total=17.5ms
# Frame 48: preprocess=1.7ms, move=13.3ms, tracking=0.0ms,vis=2.5ms, total=17.5ms
# Frame 49: preprocess=1.3ms, move=12.7ms, tracking=0.0ms,vis=2.4ms, total=16.5ms
# Frame 50: preprocess=1.4ms, move=12.6ms, tracking=0.1ms,vis=2.4ms, total=16.4ms
# Frame 51: preprocess=2.3ms, move=14.6ms, tracking=0.0ms,vis=2.4ms, total=19.3ms
# Frame 52: preprocess=2.2ms, move=13.7ms, tracking=0.0ms,vis=2.3ms, total=18.1ms
# Frame 53: preprocess=2.1ms, move=12.5ms, tracking=0.0ms,vis=2.3ms, total=16.9ms
# Frame 54: preprocess=1.9ms, move=13.2ms, tracking=0.0ms,vis=1.9ms, total=17.1ms
# Frame 55: preprocess=1.8ms, move=14.4ms, tracking=0.0ms,vis=2.7ms, total=18.9ms
# Frame 56: preprocess=2.1ms, move=13.7ms, tracking=0.0ms,vis=2.9ms, total=18.7ms
# Frame 57: preprocess=2.0ms, move=16.7ms, tracking=0.0ms,vis=2.8ms, total=21.5ms
# Frame 58: preprocess=2.2ms, move=13.5ms, tracking=0.0ms,vis=2.9ms, total=18.6ms
# Frame 59: preprocess=2.0ms, move=15.1ms, tracking=0.0ms,vis=3.4ms, total=20.5ms
# Frame 60: preprocess=2.2ms, move=14.3ms, tracking=0.0ms,vis=3.1ms, total=19.7ms
# Frame 61: preprocess=2.4ms, move=15.8ms, tracking=0.0ms,vis=3.5ms, total=21.8ms
# Frame 62: preprocess=2.1ms, move=13.9ms, tracking=0.0ms,vis=2.8ms, total=18.8ms
# Frame 63: preprocess=1.7ms, move=13.8ms, tracking=0.0ms,vis=2.8ms, total=18.3ms
# Frame 64: preprocess=1.9ms, move=14.2ms, tracking=0.0ms,vis=2.9ms, total=19.0ms
# Frame 65: preprocess=2.5ms, move=15.0ms, tracking=0.0ms,vis=2.6ms, total=20.1ms
# Frame 66: preprocess=2.3ms, move=16.8ms, tracking=0.0ms,vis=3.3ms, total=22.5ms
# Frame 67: preprocess=2.0ms, move=15.6ms, tracking=0.0ms,vis=3.3ms, total=20.9ms
# Frame 68: preprocess=2.1ms, move=16.0ms, tracking=0.0ms,vis=3.4ms, total=21.5ms
# Frame 69: preprocess=2.0ms, move=18.2ms, tracking=0.0ms,vis=3.1ms, total=23.3ms
# Frame 70: preprocess=2.2ms, move=14.4ms, tracking=0.0ms,vis=3.4ms, total=20.1ms
# Frame 71: preprocess=2.4ms, move=14.3ms, tracking=0.0ms,vis=2.8ms, total=19.5ms
# Frame 72: preprocess=2.2ms, move=15.8ms, tracking=0.0ms,vis=3.2ms, total=21.2ms
# Frame 73: preprocess=2.5ms, move=16.3ms, tracking=0.0ms,vis=2.9ms, total=21.7ms
# Frame 74: preprocess=2.1ms, move=18.4ms, tracking=0.0ms,vis=3.7ms, total=24.3ms
# Frame 75: preprocess=2.2ms, move=18.0ms, tracking=0.0ms,vis=3.1ms, total=23.3ms
# Frame 76: preprocess=2.3ms, move=17.1ms, tracking=0.0ms,vis=3.2ms, total=22.7ms
# Frame 77: preprocess=2.2ms, move=17.0ms, tracking=0.0ms,vis=3.1ms, total=22.2ms
# Frame 78: preprocess=2.3ms, move=15.8ms, tracking=0.0ms,vis=2.9ms, total=21.0ms
# Frame 79: preprocess=2.0ms, move=15.3ms, tracking=0.0ms,vis=2.6ms, total=19.9ms
# Frame 80: preprocess=2.2ms, move=15.2ms, tracking=0.0ms,vis=2.7ms, total=20.1ms
# Frame 81: preprocess=2.2ms, move=15.4ms, tracking=0.0ms,vis=2.8ms, total=20.4ms
# Frame 82: preprocess=1.9ms, move=15.4ms, tracking=0.0ms,vis=2.8ms, total=20.1ms
# Frame 83: preprocess=2.3ms, move=15.6ms, tracking=0.0ms,vis=2.9ms, total=20.8ms
# Frame 84: preprocess=1.8ms, move=15.5ms, tracking=0.0ms,vis=3.1ms, total=20.4ms
# Frame 85: preprocess=2.3ms, move=15.4ms, tracking=0.0ms,vis=2.9ms, total=20.6ms
# Frame 86: preprocess=1.9ms, move=14.5ms, tracking=0.0ms,vis=2.8ms, total=19.2ms
# Frame 87: preprocess=2.4ms, move=15.5ms, tracking=0.0ms,vis=2.8ms, total=20.7ms
# Frame 88: preprocess=1.9ms, move=16.9ms, tracking=0.0ms,vis=2.9ms, total=21.8ms
# Frame 89: preprocess=2.3ms, move=14.8ms, tracking=0.0ms,vis=2.8ms, total=20.0ms
# Frame 90: preprocess=1.9ms, move=14.6ms, tracking=0.4ms,vis=6.3ms, total=23.4ms
# Frame 91: preprocess=2.7ms, move=15.0ms, tracking=0.6ms,vis=3.1ms, total=21.5ms
# Frame 92: preprocess=1.9ms, move=14.8ms, tracking=0.2ms,vis=3.1ms, total=20.0ms
# Frame 93: preprocess=2.2ms, move=15.3ms, tracking=0.2ms,vis=2.8ms, total=20.4ms
# Frame 94: preprocess=2.8ms, move=15.7ms, tracking=0.2ms,vis=3.1ms, total=21.7ms
# Frame 95: preprocess=2.1ms, move=16.1ms, tracking=0.2ms,vis=3.0ms, total=21.7ms
# Frame 96: preprocess=2.2ms, move=12.9ms, tracking=0.1ms,vis=2.9ms, total=18.1ms
# Frame 97: preprocess=2.1ms, move=17.1ms, tracking=0.0ms,vis=2.9ms, total=22.1ms
# Frame 98: preprocess=2.1ms, move=15.3ms, tracking=0.0ms,vis=2.8ms, total=20.1ms
# Frame 99: preprocess=1.8ms, move=15.5ms, tracking=0.0ms,vis=3.6ms, total=20.9ms
# Frame 100: preprocess=2.4ms, move=15.6ms, tracking=0.3ms,vis=6.7ms, total=25.1ms
# Frame 101: preprocess=1.9ms, move=17.5ms, tracking=0.0ms,vis=5.3ms, total=24.8ms
# Frame 102: preprocess=2.4ms, move=16.1ms, tracking=0.0ms,vis=2.8ms, total=21.4ms
# Frame 103: preprocess=2.2ms, move=17.4ms, tracking=0.0ms,vis=3.8ms, total=23.4ms
# Frame 104: preprocess=3.3ms, move=16.9ms, tracking=0.0ms,vis=4.0ms, total=24.3ms
# Frame 105: preprocess=2.2ms, move=17.1ms, tracking=0.0ms,vis=3.3ms, total=22.7ms
# Frame 106: preprocess=2.1ms, move=16.1ms, tracking=0.0ms,vis=3.1ms, total=21.3ms
# Frame 107: preprocess=2.3ms, move=14.4ms, tracking=0.0ms,vis=2.7ms, total=19.4ms
# Frame 108: preprocess=2.3ms, move=17.3ms, tracking=0.0ms,vis=3.4ms, total=23.1ms
# Frame 109: preprocess=1.8ms, move=15.4ms, tracking=0.0ms,vis=3.0ms, total=20.2ms
# Frame 110: preprocess=3.1ms, move=15.9ms, tracking=0.0ms,vis=2.8ms, total=21.8ms
# Frame 111: preprocess=1.8ms, move=16.3ms, tracking=0.4ms,vis=3.1ms, total=21.7ms
# Frame 112: preprocess=1.7ms, move=13.7ms, tracking=0.7ms,vis=3.0ms, total=19.2ms
# Frame 113: preprocess=1.9ms, move=14.2ms, tracking=0.8ms,vis=3.1ms, total=20.0ms
# Frame 114: preprocess=2.6ms, move=17.2ms, tracking=1.0ms,vis=3.1ms, total=23.9ms
# Frame 115: preprocess=1.8ms, move=16.3ms, tracking=1.0ms,vis=2.9ms, total=22.1ms
# Frame 116: preprocess=2.3ms, move=15.0ms, tracking=1.1ms,vis=3.2ms, total=21.7ms
# Frame 117: preprocess=2.9ms, move=15.3ms, tracking=1.5ms,vis=3.1ms, total=22.9ms
# Frame 118: preprocess=2.6ms, move=15.9ms, tracking=0.9ms,vis=3.2ms, total=22.5ms
# Frame 119: preprocess=2.5ms, move=15.8ms, tracking=1.3ms,vis=3.3ms, total=22.9ms
# Frame 120: preprocess=2.2ms, move=16.1ms, tracking=1.3ms,vis=28.8ms, total=48.6ms
# Frame 121: preprocess=2.0ms, move=16.4ms, tracking=1.2ms,vis=3.0ms, total=22.6ms
# Frame 122: preprocess=2.0ms, move=15.6ms, tracking=1.3ms,vis=3.2ms, total=22.1ms
# Frame 123: preprocess=2.4ms, move=16.7ms, tracking=1.2ms,vis=3.0ms, total=23.3ms
# Frame 124: preprocess=1.8ms, move=17.2ms, tracking=0.4ms,vis=3.4ms, total=22.8ms
# Frame 125: preprocess=1.9ms, move=14.2ms, tracking=0.4ms,vis=3.1ms, total=19.7ms
# Frame 126: preprocess=2.0ms, move=17.5ms, tracking=0.4ms,vis=2.9ms, total=22.7ms
# Frame 127: preprocess=1.8ms, move=15.8ms, tracking=0.1ms,vis=3.8ms, total=21.5ms
# Frame 128: preprocess=2.4ms, move=17.3ms, tracking=0.0ms,vis=3.4ms, total=23.1ms
# Frame 129: preprocess=2.2ms, move=17.3ms, tracking=0.0ms,vis=3.2ms, total=22.7ms
# Frame 130: preprocess=2.5ms, move=14.7ms, tracking=0.0ms,vis=3.2ms, total=20.4ms
# Frame 131: preprocess=2.2ms, move=16.3ms, tracking=0.1ms,vis=3.2ms, total=21.7ms
# Frame 132: preprocess=2.3ms, move=16.4ms, tracking=0.0ms,vis=3.0ms, total=21.8ms
# Frame 133: preprocess=2.2ms, move=15.1ms, tracking=0.0ms,vis=2.8ms, total=20.1ms
# Frame 134: preprocess=2.6ms, move=15.9ms, tracking=0.0ms,vis=3.3ms, total=21.9ms
# Frame 135: preprocess=2.1ms, move=17.5ms, tracking=0.4ms,vis=3.1ms, total=23.2ms
# Frame 136: preprocess=2.3ms, move=16.2ms, tracking=0.6ms,vis=3.1ms, total=22.2ms
# Frame 137: preprocess=2.7ms, move=16.0ms, tracking=0.8ms,vis=3.4ms, total=22.8ms
# Frame 138: preprocess=2.5ms, move=15.2ms, tracking=1.2ms,vis=3.1ms, total=21.9ms
# Frame 139: preprocess=2.3ms, move=15.3ms, tracking=1.0ms,vis=3.0ms, total=21.6ms
# Frame 140: preprocess=2.2ms, move=15.7ms, tracking=1.3ms,vis=35.1ms, total=54.5ms
# Frame 141: preprocess=2.6ms, move=18.1ms, tracking=1.0ms,vis=3.1ms, total=24.7ms
# Frame 142: preprocess=2.1ms, move=15.8ms, tracking=1.5ms,vis=3.5ms, total=22.9ms
# Frame 143: preprocess=2.6ms, move=17.2ms, tracking=1.4ms,vis=3.1ms, total=24.3ms
# Frame 144: preprocess=2.7ms, move=15.5ms, tracking=1.2ms,vis=3.6ms, total=23.0ms
# Frame 145: preprocess=2.3ms, move=16.1ms, tracking=1.4ms,vis=3.0ms, total=23.3ms
# Frame 146: preprocess=2.6ms, move=16.0ms, tracking=1.0ms,vis=3.2ms, total=22.8ms
# Frame 147: preprocess=2.1ms, move=17.4ms, tracking=1.2ms,vis=3.5ms, total=24.1ms
# Frame 148: preprocess=2.2ms, move=16.9ms, tracking=1.3ms,vis=3.6ms, total=24.0ms
# Frame 149: preprocess=3.0ms, move=20.7ms, tracking=1.4ms,vis=4.3ms, total=29.4ms
# Frame 150: preprocess=2.9ms, move=21.6ms, tracking=1.4ms,vis=28.8ms, total=54.9ms
# Frame 151: preprocess=2.1ms, move=14.8ms, tracking=3.3ms,vis=3.4ms, total=23.7ms
# Frame 152: preprocess=2.1ms, move=14.9ms, tracking=1.3ms,vis=3.2ms, total=21.5ms
# Frame 153: preprocess=2.4ms, move=15.7ms, tracking=1.3ms,vis=3.1ms, total=22.4ms
# Frame 154: preprocess=2.2ms, move=15.0ms, tracking=0.9ms,vis=3.2ms, total=21.4ms
# Frame 155: preprocess=2.6ms, move=15.2ms, tracking=1.6ms,vis=2.8ms, total=22.4ms
# Frame 156: preprocess=2.5ms, move=14.6ms, tracking=0.9ms,vis=3.0ms, total=20.9ms
# Frame 157: preprocess=5.6ms, move=19.8ms, tracking=0.7ms,vis=7.7ms, total=33.9ms
# Frame 158: preprocess=3.1ms, move=19.4ms, tracking=1.1ms,vis=3.1ms, total=26.8ms
# Frame 159: preprocess=2.2ms, move=15.2ms, tracking=1.0ms,vis=3.2ms, total=21.5ms
# Frame 160: preprocess=1.7ms, move=14.0ms, tracking=0.3ms,vis=14.0ms, total=30.1ms
# Frame 161: preprocess=2.2ms, move=14.2ms, tracking=0.3ms,vis=2.9ms, total=19.6ms
# Frame 162: preprocess=2.3ms, move=13.9ms, tracking=0.5ms,vis=2.9ms, total=19.5ms
# Frame 163: preprocess=2.1ms, move=15.8ms, tracking=0.7ms,vis=2.9ms, total=21.5ms
# Frame 164: preprocess=2.1ms, move=14.1ms, tracking=0.1ms,vis=3.1ms, total=19.3ms
# Frame 165: preprocess=2.4ms, move=14.4ms, tracking=0.6ms,vis=3.3ms, total=20.9ms
# Frame 166: preprocess=2.3ms, move=16.3ms, tracking=0.7ms,vis=3.2ms, total=22.5ms
# Frame 167: preprocess=2.0ms, move=15.3ms, tracking=0.9ms,vis=3.2ms, total=21.4ms
# Frame 168: preprocess=2.3ms, move=16.8ms, tracking=1.0ms,vis=3.2ms, total=23.3ms
# Frame 169: preprocess=2.0ms, move=16.2ms, tracking=0.4ms,vis=3.2ms, total=21.7ms
# Frame 170: preprocess=2.0ms, move=20.1ms, tracking=0.2ms,vis=12.4ms, total=35.1ms
# Frame 171: preprocess=2.4ms, move=15.1ms, tracking=0.2ms,vis=3.0ms, total=20.7ms
# Frame 172: preprocess=2.1ms, move=15.1ms, tracking=0.1ms,vis=2.5ms, total=19.8ms
# Frame 173: preprocess=1.9ms, move=13.4ms, tracking=0.0ms,vis=2.6ms, total=18.0ms
# Frame 174: preprocess=2.3ms, move=14.5ms, tracking=0.0ms,vis=2.6ms, total=19.5ms
# Frame 175: preprocess=2.1ms, move=15.6ms, tracking=0.0ms,vis=2.9ms, total=20.7ms
# Frame 176: preprocess=2.2ms, move=15.6ms, tracking=0.0ms,vis=2.8ms, total=20.6ms
# Frame 177: preprocess=2.2ms, move=15.4ms, tracking=0.0ms,vis=2.9ms, total=20.5ms
# Frame 178: preprocess=2.5ms, move=13.8ms, tracking=0.0ms,vis=2.8ms, total=19.2ms
# Frame 179: preprocess=2.3ms, move=14.9ms, tracking=0.0ms,vis=3.0ms, total=20.2ms
# Frame 180: preprocess=2.3ms, move=14.6ms, tracking=0.0ms,vis=2.9ms, total=19.8ms
# Frame 181: preprocess=2.0ms, move=16.3ms, tracking=0.0ms,vis=3.0ms, total=21.3ms
# Frame 182: preprocess=2.2ms, move=15.6ms, tracking=0.0ms,vis=2.8ms, total=20.7ms
# Frame 183: preprocess=2.6ms, move=16.2ms, tracking=0.0ms,vis=3.1ms, total=21.9ms
# Frame 184: preprocess=3.2ms, move=16.6ms, tracking=0.0ms,vis=3.0ms, total=22.8ms
# Frame 185: preprocess=1.9ms, move=16.8ms, tracking=0.0ms,vis=2.9ms, total=21.5ms
# Frame 186: preprocess=2.4ms, move=15.9ms, tracking=0.0ms,vis=2.9ms, total=21.2ms
# Frame 187: preprocess=1.8ms, move=16.5ms, tracking=0.0ms,vis=2.9ms, total=21.2ms
# Frame 188: preprocess=1.8ms, move=14.6ms, tracking=0.0ms,vis=2.9ms, total=19.3ms
# Frame 189: preprocess=1.9ms, move=16.3ms, tracking=0.0ms,vis=2.8ms, total=21.1ms
# Frame 190: preprocess=1.8ms, move=14.1ms, tracking=0.0ms,vis=2.8ms, total=18.8ms
# Frame 191: preprocess=2.1ms, move=17.7ms, tracking=0.0ms,vis=3.1ms, total=22.8ms
# Frame 192: preprocess=2.0ms, move=14.9ms, tracking=0.0ms,vis=4.2ms, total=21.1ms
# Frame 193: preprocess=2.2ms, move=14.1ms, tracking=0.0ms,vis=2.6ms, total=18.9ms
# Frame 194: preprocess=2.3ms, move=18.0ms, tracking=0.0ms,vis=2.8ms, total=23.1ms
# Frame 195: preprocess=2.2ms, move=13.4ms, tracking=0.0ms,vis=2.6ms, total=18.2ms
# Frame 196: preprocess=2.0ms, move=15.2ms, tracking=0.0ms,vis=2.8ms, total=20.0ms
# Frame 197: preprocess=1.6ms, move=13.8ms, tracking=0.0ms,vis=2.6ms, total=18.0ms
# Frame 198: preprocess=2.3ms, move=13.8ms, tracking=0.0ms,vis=2.6ms, total=18.7ms
# Frame 199: preprocess=3.3ms, move=14.4ms, tracking=0.0ms,vis=2.8ms, total=20.6ms
# Frame 200: preprocess=1.9ms, move=15.7ms, tracking=0.0ms,vis=3.1ms, total=20.7ms
# Frame 201: preprocess=2.9ms, move=18.4ms, tracking=0.0ms,vis=3.6ms, total=25.0ms
# Frame 202: preprocess=1.8ms, move=14.6ms, tracking=0.0ms,vis=2.8ms, total=19.2ms
# Frame 203: preprocess=1.9ms, move=14.6ms, tracking=0.0ms,vis=2.9ms, total=19.4ms
# Frame 204: preprocess=2.2ms, move=15.7ms, tracking=0.0ms,vis=3.1ms, total=21.1ms
# Frame 205: preprocess=2.1ms, move=15.4ms, tracking=0.0ms,vis=3.0ms, total=20.5ms
# Frame 206: preprocess=2.2ms, move=15.1ms, tracking=0.0ms,vis=3.2ms, total=20.4ms
# Frame 207: preprocess=2.1ms, move=15.6ms, tracking=0.0ms,vis=2.7ms, total=20.5ms
# Frame 208: preprocess=2.4ms, move=15.5ms, tracking=0.0ms,vis=3.0ms, total=20.9ms
# Frame 209: preprocess=2.4ms, move=18.2ms, tracking=0.0ms,vis=3.6ms, total=24.2ms
# Frame 210: preprocess=2.5ms, move=17.1ms, tracking=0.0ms,vis=3.4ms, total=23.0ms
# Frame 211: preprocess=2.0ms, move=14.8ms, tracking=0.0ms,vis=2.4ms, total=19.2ms
# Frame 212: preprocess=2.0ms, move=17.3ms, tracking=0.0ms,vis=3.0ms, total=22.3ms
# Frame 213: preprocess=2.1ms, move=13.6ms, tracking=0.0ms,vis=2.8ms, total=18.6ms
# Frame 214: preprocess=1.8ms, move=14.8ms, tracking=0.0ms,vis=3.0ms, total=19.7ms
# Frame 215: preprocess=2.1ms, move=14.8ms, tracking=0.0ms,vis=2.9ms, total=19.8ms
# Frame 216: preprocess=2.0ms, move=15.4ms, tracking=0.0ms,vis=2.9ms, total=20.4ms
# Frame 217: preprocess=1.9ms, move=14.1ms, tracking=0.0ms,vis=2.8ms, total=18.7ms
# Frame 218: preprocess=2.1ms, move=15.3ms, tracking=0.0ms,vis=2.7ms, total=20.2ms
# Frame 219: preprocess=2.3ms, move=15.5ms, tracking=0.0ms,vis=3.0ms, total=20.9ms
# Frame 220: preprocess=1.5ms, move=15.7ms, tracking=0.0ms,vis=2.8ms, total=20.1ms
# Frame 221: preprocess=1.3ms, move=14.5ms, tracking=0.0ms,vis=2.8ms, total=18.7ms
# Frame 222: preprocess=2.3ms, move=19.4ms, tracking=0.0ms,vis=2.7ms, total=24.4ms
# Frame 223: preprocess=1.7ms, move=15.8ms, tracking=0.0ms,vis=2.7ms, total=20.2ms
# Frame 224: preprocess=2.3ms, move=14.4ms, tracking=0.0ms,vis=2.5ms, total=19.3ms
# Frame 225: preprocess=3.0ms, move=15.4ms, tracking=0.0ms,vis=2.7ms, total=21.2ms
# Frame 226: preprocess=2.3ms, move=15.0ms, tracking=0.0ms,vis=3.1ms, total=20.4ms
# Frame 227: preprocess=2.2ms, move=16.1ms, tracking=0.0ms,vis=3.1ms, total=21.5ms
# Frame 228: preprocess=2.1ms, move=15.1ms, tracking=0.0ms,vis=3.0ms, total=20.3ms
# Frame 229: preprocess=2.3ms, move=15.1ms, tracking=0.0ms,vis=2.6ms, total=20.0ms
# Frame 230: preprocess=2.9ms, move=17.8ms, tracking=0.0ms,vis=3.3ms, total=24.0ms
# Frame 231: preprocess=1.8ms, move=14.9ms, tracking=0.0ms,vis=2.8ms, total=19.6ms
# Frame 232: preprocess=2.4ms, move=15.3ms, tracking=0.0ms,vis=2.6ms, total=20.3ms
# Frame 233: preprocess=1.9ms, move=15.8ms, tracking=0.0ms,vis=2.7ms, total=20.4ms
# Frame 234: preprocess=2.5ms, move=15.3ms, tracking=0.0ms,vis=2.9ms, total=20.8ms
# Frame 235: preprocess=1.8ms, move=15.4ms, tracking=0.0ms,vis=2.9ms, total=20.1ms
# Frame 236: preprocess=1.9ms, move=14.5ms, tracking=0.0ms,vis=2.9ms, total=19.3ms
# Frame 237: preprocess=1.9ms, move=15.5ms, tracking=0.0ms,vis=2.7ms, total=20.2ms
# Frame 238: preprocess=2.2ms, move=15.2ms, tracking=0.0ms,vis=2.9ms, total=20.3ms
# Frame 239: preprocess=2.2ms, move=15.7ms, tracking=0.0ms,vis=2.6ms, total=20.6ms
# Frame 240: preprocess=1.9ms, move=15.1ms, tracking=0.0ms,vis=2.8ms, total=19.9ms
# Frame 241: preprocess=2.0ms, move=15.3ms, tracking=0.0ms,vis=2.9ms, total=20.3ms
# Frame 242: preprocess=2.0ms, move=14.3ms, tracking=0.0ms,vis=2.7ms, total=19.1ms
# Frame 243: preprocess=1.5ms, move=16.1ms, tracking=0.0ms,vis=2.7ms, total=20.4ms
# Frame 244: preprocess=1.6ms, move=14.8ms, tracking=0.0ms,vis=2.8ms, total=19.2ms
# Frame 245: preprocess=2.5ms, move=16.8ms, tracking=0.0ms,vis=3.1ms, total=22.4ms
# Frame 246: preprocess=2.2ms, move=15.5ms, tracking=0.0ms,vis=2.9ms, total=20.6ms
# Frame 247: preprocess=2.1ms, move=13.6ms, tracking=0.0ms,vis=3.0ms, total=18.7ms
# Frame 248: preprocess=2.2ms, move=14.8ms, tracking=0.0ms,vis=3.5ms, total=20.5ms
# Frame 249: preprocess=1.6ms, move=16.6ms, tracking=0.0ms,vis=2.6ms, total=20.8ms
# Frame 250: preprocess=1.7ms, move=14.3ms, tracking=0.0ms,vis=2.7ms, total=18.6ms
# Frame 251: preprocess=1.9ms, move=13.6ms, tracking=0.0ms,vis=3.2ms, total=18.8ms
# Frame 252: preprocess=1.8ms, move=14.1ms, tracking=0.0ms,vis=2.3ms, total=18.2ms
# Frame 253: preprocess=2.1ms, move=14.1ms, tracking=0.0ms,vis=2.8ms, total=19.0ms
# Frame 254: preprocess=1.8ms, move=13.3ms, tracking=0.0ms,vis=2.6ms, total=17.8ms
# Frame 255: preprocess=1.9ms, move=13.7ms, tracking=0.0ms,vis=3.0ms, total=18.6ms
# Frame 256: preprocess=1.7ms, move=14.0ms, tracking=0.0ms,vis=2.5ms, total=18.3ms
# Frame 257: preprocess=1.8ms, move=14.8ms, tracking=0.0ms,vis=2.8ms, total=19.4ms
# Frame 258: preprocess=1.5ms, move=15.6ms, tracking=0.0ms,vis=2.8ms, total=20.0ms
# Frame 259: preprocess=1.6ms, move=14.2ms, tracking=0.0ms,vis=2.6ms, total=18.4ms
# Frame 260: preprocess=2.0ms, move=15.0ms, tracking=0.0ms,vis=2.6ms, total=19.6ms
# Frame 261: preprocess=2.0ms, move=15.7ms, tracking=0.0ms,vis=3.0ms, total=20.7ms
# Frame 262: preprocess=1.8ms, move=15.1ms, tracking=0.0ms,vis=3.0ms, total=20.0ms
# Frame 263: preprocess=2.0ms, move=14.4ms, tracking=0.0ms,vis=2.6ms, total=19.0ms
# Frame 264: preprocess=1.8ms, move=15.1ms, tracking=0.0ms,vis=3.1ms, total=20.0ms
# Frame 265: preprocess=2.1ms, move=15.9ms, tracking=0.0ms,vis=2.9ms, total=20.9ms
# Frame 266: preprocess=1.9ms, move=15.5ms, tracking=0.0ms,vis=3.2ms, total=20.6ms
# Frame 267: preprocess=2.2ms, move=15.6ms, tracking=0.0ms,vis=2.6ms, total=20.3ms
# Frame 268: preprocess=2.0ms, move=15.5ms, tracking=0.0ms,vis=2.9ms, total=20.4ms
# Frame 269: preprocess=2.5ms, move=15.9ms, tracking=0.0ms,vis=3.2ms, total=21.7ms
# Frame 270: preprocess=2.0ms, move=16.9ms, tracking=0.0ms,vis=3.8ms, total=22.7ms
# Frame 271: preprocess=2.1ms, move=15.7ms, tracking=0.0ms,vis=3.1ms, total=21.0ms
# Frame 272: preprocess=2.2ms, move=16.7ms, tracking=0.0ms,vis=3.0ms, total=22.0ms
# Frame 273: preprocess=2.3ms, move=17.3ms, tracking=0.0ms,vis=2.8ms, total=22.4ms
# Frame 274: preprocess=1.9ms, move=19.6ms, tracking=0.0ms,vis=2.9ms, total=24.5ms
# Frame 275: preprocess=2.0ms, move=15.8ms, tracking=0.0ms,vis=2.9ms, total=20.8ms
# Frame 276: preprocess=2.0ms, move=14.9ms, tracking=0.0ms,vis=3.6ms, total=20.5ms
# Frame 277: preprocess=3.0ms, move=16.1ms, tracking=0.0ms,vis=2.9ms, total=22.0ms
# Frame 278: preprocess=1.9ms, move=14.0ms, tracking=0.0ms,vis=2.7ms, total=18.7ms
# Frame 279: preprocess=2.2ms, move=16.7ms, tracking=0.0ms,vis=3.1ms, total=22.1ms
# Frame 280: preprocess=2.7ms, move=17.2ms, tracking=0.0ms,vis=3.1ms, total=23.0ms
# Frame 281: preprocess=2.1ms, move=15.8ms, tracking=0.0ms,vis=3.1ms, total=21.0ms
# Frame 282: preprocess=1.9ms, move=16.4ms, tracking=0.0ms,vis=3.1ms, total=21.3ms
# Frame 283: preprocess=2.3ms, move=14.7ms, tracking=0.0ms,vis=2.3ms, total=19.3ms
# Frame 284: preprocess=2.0ms, move=14.5ms, tracking=0.0ms,vis=2.7ms, total=19.3ms
# Frame 285: preprocess=2.2ms, move=14.4ms, tracking=0.0ms,vis=2.5ms, total=19.1ms
# Frame 286: preprocess=1.9ms, move=15.6ms, tracking=0.0ms,vis=3.2ms, total=20.7ms
# Frame 287: preprocess=2.0ms, move=14.5ms, tracking=0.0ms,vis=3.5ms, total=20.0ms
# Frame 288: preprocess=1.9ms, move=15.0ms, tracking=0.0ms,vis=2.5ms, total=19.4ms
# Frame 289: preprocess=1.9ms, move=14.0ms, tracking=0.0ms,vis=2.6ms, total=18.6ms
# Frame 290: preprocess=2.1ms, move=14.9ms, tracking=0.0ms,vis=2.8ms, total=19.8ms
# Frame 291: preprocess=2.1ms, move=14.3ms, tracking=0.0ms,vis=2.4ms, total=18.9ms
# Frame 292: preprocess=1.6ms, move=14.4ms, tracking=0.0ms,vis=2.7ms, total=18.7ms
# Frame 293: preprocess=1.8ms, move=15.1ms, tracking=0.0ms,vis=2.8ms, total=19.6ms
# Frame 294: preprocess=2.3ms, move=17.0ms, tracking=0.0ms,vis=2.7ms, total=22.0ms
# Frame 295: preprocess=2.3ms, move=14.5ms, tracking=0.0ms,vis=2.6ms, total=19.4ms
# Frame 296: preprocess=1.9ms, move=16.1ms, tracking=0.0ms,vis=2.4ms, total=20.4ms
# Frame 297: preprocess=1.9ms, move=16.3ms, tracking=0.0ms,vis=2.8ms, total=21.0ms
# Frame 298: preprocess=1.9ms, move=14.9ms, tracking=0.0ms,vis=3.1ms, total=19.9ms
# Frame 299: preprocess=1.8ms, move=17.4ms, tracking=0.0ms,vis=3.3ms, total=22.5ms
# Frame 300: preprocess=2.2ms, move=18.1ms, tracking=0.0ms,vis=2.8ms, total=23.2ms
# Frame 301: preprocess=1.6ms, move=14.3ms, tracking=0.0ms,vis=2.7ms, total=18.6ms
# Frame 302: preprocess=2.1ms, move=14.9ms, tracking=0.0ms,vis=2.6ms, total=19.6ms
# Frame 303: preprocess=1.9ms, move=15.3ms, tracking=0.0ms,vis=2.7ms, total=19.9ms
# Frame 304: preprocess=1.7ms, move=16.3ms, tracking=0.0ms,vis=3.4ms, total=21.4ms
# Frame 305: preprocess=2.7ms, move=16.4ms, tracking=0.0ms,vis=3.2ms, total=22.3ms
# Frame 306: preprocess=2.1ms, move=14.4ms, tracking=0.0ms,vis=2.6ms, total=19.2ms
# Frame 307: preprocess=2.6ms, move=16.2ms, tracking=0.0ms,vis=2.8ms, total=21.6ms
# Frame 308: preprocess=2.1ms, move=15.9ms, tracking=0.0ms,vis=2.8ms, total=20.8ms
# Frame 309: preprocess=1.9ms, move=16.1ms, tracking=0.0ms,vis=2.8ms, total=20.9ms
# Frame 310: preprocess=2.2ms, move=15.3ms, tracking=0.0ms,vis=2.9ms, total=20.4ms
# Frame 311: preprocess=2.2ms, move=15.1ms, tracking=0.0ms,vis=2.7ms, total=20.1ms
# Frame 312: preprocess=1.9ms, move=16.9ms, tracking=0.0ms,vis=2.9ms, total=21.7ms
# Frame 313: preprocess=2.0ms, move=15.6ms, tracking=0.0ms,vis=2.5ms, total=20.1ms
# Frame 314: preprocess=1.6ms, move=15.2ms, tracking=0.0ms,vis=3.0ms, total=19.8ms
# Frame 315: preprocess=2.3ms, move=15.7ms, tracking=0.0ms,vis=3.0ms, total=21.0ms
# Frame 316: preprocess=1.8ms, move=13.6ms, tracking=0.0ms,vis=2.6ms, total=18.1ms
# Frame 317: preprocess=1.9ms, move=16.1ms, tracking=0.0ms,vis=4.1ms, total=22.1ms
# Frame 318: preprocess=2.0ms, move=15.3ms, tracking=0.0ms,vis=3.0ms, total=20.3ms
# Frame 319: preprocess=1.8ms, move=15.6ms, tracking=0.0ms,vis=15.3ms, total=32.7ms
# Frame 320: preprocess=1.7ms, move=14.5ms, tracking=0.0ms,vis=2.9ms, total=19.2ms
# Frame 321: preprocess=3.0ms, move=12.5ms, tracking=0.0ms,vis=2.4ms, total=17.9ms
# Frame 322: preprocess=1.9ms, move=14.7ms, tracking=0.0ms,vis=2.6ms, total=19.2ms
# Frame 323: preprocess=1.7ms, move=13.6ms, tracking=0.0ms,vis=2.7ms, total=18.0ms
# Frame 324: preprocess=2.7ms, move=17.0ms, tracking=0.0ms,vis=3.0ms, total=22.8ms
# Frame 325: preprocess=1.7ms, move=15.4ms, tracking=0.0ms,vis=3.0ms, total=20.2ms
# Frame 326: preprocess=1.9ms, move=17.0ms, tracking=0.0ms,vis=2.9ms, total=21.8ms
# Frame 327: preprocess=1.8ms, move=15.2ms, tracking=0.0ms,vis=3.3ms, total=20.3ms
# Frame 328: preprocess=2.2ms, move=14.8ms, tracking=0.0ms,vis=3.2ms, total=20.2ms
# Frame 329: preprocess=1.9ms, move=16.1ms, tracking=0.0ms,vis=2.8ms, total=20.9ms
# Frame 330: preprocess=2.3ms, move=15.9ms, tracking=0.0ms,vis=2.8ms, total=21.1ms
# Frame 331: preprocess=1.9ms, move=16.9ms, tracking=0.0ms,vis=3.0ms, total=21.7ms
# Frame 332: preprocess=2.1ms, move=16.7ms, tracking=0.0ms,vis=2.8ms, total=21.6ms
# Frame 333: preprocess=1.8ms, move=16.2ms, tracking=0.0ms,vis=3.4ms, total=21.4ms
# Frame 334: preprocess=1.9ms, move=13.9ms, tracking=0.0ms,vis=3.0ms, total=18.7ms
# Frame 335: preprocess=1.8ms, move=13.7ms, tracking=0.0ms,vis=2.9ms, total=18.4ms
# Frame 336: preprocess=1.8ms, move=16.7ms, tracking=0.0ms,vis=3.0ms, total=21.6ms
# Frame 337: preprocess=2.0ms, move=15.2ms, tracking=0.0ms,vis=3.0ms, total=20.3ms
# Frame 338: preprocess=1.9ms, move=15.5ms, tracking=0.0ms,vis=2.8ms, total=20.3ms
# Frame 339: preprocess=1.7ms, move=13.9ms, tracking=0.3ms,vis=2.5ms, total=18.4ms
# Frame 340: preprocess=1.8ms, move=15.5ms, tracking=0.0ms,vis=7.6ms, total=25.0ms
# Frame 341: preprocess=1.7ms, move=18.4ms, tracking=0.0ms,vis=3.2ms, total=23.4ms
# Frame 342: preprocess=1.9ms, move=15.8ms, tracking=0.0ms,vis=3.1ms, total=20.9ms
# Frame 343: preprocess=1.9ms, move=14.4ms, tracking=0.0ms,vis=2.8ms, total=19.2ms
# Frame 344: preprocess=2.3ms, move=14.7ms, tracking=0.5ms,vis=2.9ms, total=20.3ms
# Frame 345: preprocess=2.1ms, move=16.6ms, tracking=0.1ms,vis=3.0ms, total=22.0ms
# Frame 346: preprocess=4.5ms, move=14.8ms, tracking=0.0ms,vis=3.3ms, total=22.7ms
# Frame 347: preprocess=1.9ms, move=15.6ms, tracking=0.0ms,vis=2.5ms, total=20.0ms
# Frame 348: preprocess=1.8ms, move=15.2ms, tracking=0.0ms,vis=2.9ms, total=19.9ms
# Frame 349: preprocess=2.0ms, move=15.4ms, tracking=0.0ms,vis=2.7ms, total=20.2ms
# Frame 350: preprocess=2.5ms, move=16.0ms, tracking=0.0ms,vis=3.2ms, total=21.8ms
# Frame 351: preprocess=2.2ms, move=15.3ms, tracking=0.0ms,vis=2.9ms, total=20.4ms
# Frame 352: preprocess=2.1ms, move=15.2ms, tracking=0.0ms,vis=2.9ms, total=20.3ms
# Frame 353: preprocess=2.3ms, move=17.9ms, tracking=0.0ms,vis=3.0ms, total=23.2ms
# Frame 354: preprocess=2.0ms, move=16.0ms, tracking=0.0ms,vis=3.2ms, total=21.2ms
# Frame 355: preprocess=1.8ms, move=15.5ms, tracking=0.0ms,vis=2.6ms, total=20.0ms
# Frame 356: preprocess=2.0ms, move=14.4ms, tracking=0.0ms,vis=2.6ms, total=19.0ms
# Frame 357: preprocess=2.1ms, move=14.7ms, tracking=0.0ms,vis=3.0ms, total=19.8ms
# Frame 358: preprocess=2.0ms, move=15.6ms, tracking=0.0ms,vis=3.0ms, total=20.7ms
# Frame 359: preprocess=2.4ms, move=16.2ms, tracking=0.0ms,vis=2.7ms, total=21.3ms
# Frame 360: preprocess=1.9ms, move=13.8ms, tracking=0.0ms,vis=2.9ms, total=18.6ms
# Frame 361: preprocess=2.1ms, move=14.1ms, tracking=0.0ms,vis=2.5ms, total=18.8ms
# Frame 362: preprocess=1.9ms, move=14.0ms, tracking=0.0ms,vis=2.6ms, total=18.7ms
# Frame 363: preprocess=1.9ms, move=14.3ms, tracking=0.0ms,vis=2.8ms, total=18.9ms
# Frame 364: preprocess=2.0ms, move=18.0ms, tracking=0.0ms,vis=3.2ms, total=23.3ms
# Frame 365: preprocess=2.0ms, move=14.6ms, tracking=0.0ms,vis=2.5ms, total=19.1ms
# Frame 366: preprocess=2.3ms, move=15.7ms, tracking=0.4ms,vis=4.1ms, total=22.4ms
# Frame 367: preprocess=2.0ms, move=16.9ms, tracking=0.0ms,vis=3.3ms, total=22.3ms
# Frame 368: preprocess=2.4ms, move=14.5ms, tracking=0.0ms,vis=3.0ms, total=20.0ms
# Frame 369: preprocess=2.0ms, move=15.3ms, tracking=0.0ms,vis=2.7ms, total=20.1ms
# Frame 370: preprocess=2.3ms, move=15.2ms, tracking=0.0ms,vis=6.0ms, total=23.7ms
# Frame 371: preprocess=2.3ms, move=15.7ms, tracking=0.0ms,vis=3.3ms, total=21.4ms
# Frame 372: preprocess=2.0ms, move=15.7ms, tracking=0.0ms,vis=3.0ms, total=20.7ms
# Frame 373: preprocess=2.7ms, move=14.7ms, tracking=0.0ms,vis=3.5ms, total=20.9ms
# Frame 374: preprocess=2.3ms, move=18.8ms, tracking=0.0ms,vis=2.7ms, total=23.9ms
# Frame 375: preprocess=2.2ms, move=14.6ms, tracking=0.0ms,vis=2.8ms, total=19.6ms
# Frame 376: preprocess=2.5ms, move=15.5ms, tracking=0.0ms,vis=3.5ms, total=21.5ms
# Frame 377: preprocess=2.2ms, move=15.1ms, tracking=0.0ms,vis=2.8ms, total=20.1ms
# Frame 378: preprocess=2.7ms, move=15.5ms, tracking=0.0ms,vis=3.2ms, total=21.5ms
# Frame 379: preprocess=2.1ms, move=15.1ms, tracking=0.0ms,vis=3.1ms, total=20.3ms
# Frame 380: preprocess=1.9ms, move=13.8ms, tracking=0.0ms,vis=2.8ms, total=18.5ms
# Frame 381: preprocess=2.3ms, move=15.8ms, tracking=0.0ms,vis=2.7ms, total=20.8ms
# Frame 382: preprocess=2.4ms, move=15.8ms, tracking=0.0ms,vis=3.6ms, total=21.9ms
# Frame 383: preprocess=2.0ms, move=18.6ms, tracking=0.0ms,vis=3.0ms, total=23.7ms
# Frame 384: preprocess=3.3ms, move=14.7ms, tracking=0.0ms,vis=2.8ms, total=20.8ms
# Frame 385: preprocess=1.9ms, move=15.3ms, tracking=0.0ms,vis=2.8ms, total=20.0ms
# Frame 386: preprocess=2.1ms, move=16.4ms, tracking=0.0ms,vis=3.6ms, total=22.2ms
# Frame 387: preprocess=4.1ms, move=15.4ms, tracking=0.0ms,vis=2.7ms, total=22.2ms
# Frame 388: preprocess=2.5ms, move=14.1ms, tracking=0.0ms,vis=3.0ms, total=19.7ms
# Frame 389: preprocess=2.4ms, move=15.9ms, tracking=0.0ms,vis=2.9ms, total=21.3ms
# Frame 390: preprocess=1.9ms, move=15.9ms, tracking=0.0ms,vis=3.4ms, total=21.2ms
# Frame 391: preprocess=2.3ms, move=18.0ms, tracking=0.0ms,vis=2.8ms, total=23.2ms
# Frame 392: preprocess=2.0ms, move=15.5ms, tracking=0.0ms,vis=3.2ms, total=20.7ms
# Frame 393: preprocess=2.3ms, move=15.5ms, tracking=0.0ms,vis=3.3ms, total=21.2ms
# Frame 394: preprocess=2.0ms, move=16.0ms, tracking=0.0ms,vis=2.9ms, total=20.9ms
# Frame 395: preprocess=2.3ms, move=16.0ms, tracking=0.0ms,vis=3.0ms, total=21.3ms
# Frame 396: preprocess=1.9ms, move=15.0ms, tracking=0.0ms,vis=2.9ms, total=19.9ms
# Frame 397: preprocess=2.1ms, move=16.5ms, tracking=0.0ms,vis=2.9ms, total=21.5ms
# Frame 398: preprocess=1.8ms, move=15.6ms, tracking=0.0ms,vis=3.2ms, total=20.7ms
# Frame 399: preprocess=2.1ms, move=15.9ms, tracking=0.0ms,vis=3.1ms, total=21.2ms
# Frame 400: preprocess=2.0ms, move=15.8ms, tracking=0.0ms,vis=3.1ms, total=20.9ms
# Frame 401: preprocess=1.9ms, move=16.0ms, tracking=0.0ms,vis=2.6ms, total=20.5ms
# Frame 402: preprocess=1.8ms, move=17.4ms, tracking=0.3ms,vis=2.9ms, total=22.5ms
# Frame 403: preprocess=2.1ms, move=16.5ms, tracking=0.7ms,vis=3.3ms, total=22.6ms
# Frame 404: preprocess=2.6ms, move=13.7ms, tracking=1.0ms,vis=3.1ms, total=20.4ms
# Frame 405: preprocess=2.3ms, move=14.5ms, tracking=0.7ms,vis=3.1ms, total=20.7ms
# Frame 406: preprocess=2.9ms, move=15.5ms, tracking=1.2ms,vis=3.2ms, total=22.8ms
# Frame 407: preprocess=2.3ms, move=16.3ms, tracking=1.2ms,vis=3.2ms, total=23.0ms
# Frame 408: preprocess=2.6ms, move=16.4ms, tracking=1.3ms,vis=3.1ms, total=23.4ms
# Frame 409: preprocess=2.6ms, move=16.6ms, tracking=1.4ms,vis=3.2ms, total=23.8ms
# Frame 410: preprocess=2.3ms, move=17.3ms, tracking=0.8ms,vis=30.1ms, total=50.7ms
# Frame 411: preprocess=2.1ms, move=14.5ms, tracking=1.1ms,vis=3.0ms, total=20.7ms
# Frame 412: preprocess=2.3ms, move=17.4ms, tracking=1.3ms,vis=3.3ms, total=24.4ms
# Frame 413: preprocess=1.8ms, move=14.8ms, tracking=1.2ms,vis=3.1ms, total=20.9ms
# Frame 414: preprocess=2.0ms, move=14.3ms, tracking=0.9ms,vis=4.4ms, total=21.7ms
# Frame 415: preprocess=2.5ms, move=16.6ms, tracking=1.4ms,vis=3.3ms, total=24.0ms
# Frame 416: preprocess=2.2ms, move=16.9ms, tracking=1.2ms,vis=3.0ms, total=23.3ms
# Frame 417: preprocess=2.0ms, move=13.7ms, tracking=1.3ms,vis=3.1ms, total=20.2ms
# Frame 418: preprocess=2.0ms, move=16.5ms, tracking=1.2ms,vis=3.0ms, total=22.8ms
# Frame 419: preprocess=2.3ms, move=15.1ms, tracking=1.5ms,vis=4.6ms, total=23.4ms
# Frame 420: preprocess=3.7ms, move=14.7ms, tracking=1.3ms,vis=28.8ms, total=48.7ms
# Frame 421: preprocess=2.5ms, move=15.4ms, tracking=1.6ms,vis=2.9ms, total=22.4ms
# Frame 422: preprocess=2.4ms, move=16.3ms, tracking=1.2ms,vis=3.1ms, total=23.0ms
# Frame 423: preprocess=2.0ms, move=16.0ms, tracking=1.0ms,vis=3.0ms, total=22.0ms
# Frame 424: preprocess=1.7ms, move=14.0ms, tracking=0.8ms,vis=2.6ms, total=19.1ms
# Frame 425: preprocess=2.5ms, move=15.5ms, tracking=1.2ms,vis=2.9ms, total=22.1ms
# Frame 426: preprocess=3.2ms, move=14.4ms, tracking=1.0ms,vis=2.8ms, total=21.4ms
# Frame 427: preprocess=2.1ms, move=15.1ms, tracking=2.0ms,vis=3.1ms, total=22.3ms
# Frame 428: preprocess=6.3ms, move=15.7ms, tracking=1.0ms,vis=3.9ms, total=26.8ms
# Frame 429: preprocess=1.6ms, move=17.5ms, tracking=1.1ms,vis=2.2ms, total=22.4ms
# Frame 430: preprocess=2.0ms, move=13.8ms, tracking=0.9ms,vis=22.0ms, total=38.8ms
# Frame 431: preprocess=2.7ms, move=15.3ms, tracking=1.3ms,vis=3.6ms, total=23.1ms
# Frame 432: preprocess=2.0ms, move=15.5ms, tracking=1.2ms,vis=3.4ms, total=22.1ms
# Frame 433: preprocess=2.3ms, move=16.1ms, tracking=1.3ms,vis=3.3ms, total=22.9ms
# Frame 434: preprocess=2.5ms, move=15.5ms, tracking=1.2ms,vis=3.4ms, total=22.6ms
# Frame 435: preprocess=2.7ms, move=17.5ms, tracking=1.3ms,vis=3.2ms, total=24.9ms
# Frame 436: preprocess=2.3ms, move=16.1ms, tracking=2.4ms,vis=3.9ms, total=24.7ms
# Frame 437: preprocess=2.1ms, move=15.5ms, tracking=1.3ms,vis=2.8ms, total=21.8ms
# Frame 438: preprocess=2.5ms, move=15.0ms, tracking=1.7ms,vis=3.6ms, total=22.8ms
# Frame 439: preprocess=2.2ms, move=15.2ms, tracking=1.8ms,vis=2.8ms, total=22.0ms
# Frame 440: preprocess=2.2ms, move=14.6ms, tracking=1.8ms,vis=31.5ms, total=50.3ms
# Frame 441: preprocess=2.2ms, move=15.7ms, tracking=1.1ms,vis=2.9ms, total=21.9ms
# Frame 442: preprocess=2.5ms, move=14.5ms, tracking=1.0ms,vis=3.4ms, total=21.4ms
# Frame 443: preprocess=2.8ms, move=13.8ms, tracking=2.0ms,vis=3.1ms, total=21.7ms
# Frame 444: preprocess=1.9ms, move=14.1ms, tracking=0.9ms,vis=3.1ms, total=20.1ms
# Frame 445: preprocess=2.1ms, move=15.3ms, tracking=0.7ms,vis=3.1ms, total=21.4ms
# Frame 446: preprocess=1.9ms, move=16.7ms, tracking=0.4ms,vis=3.6ms, total=22.6ms
# Frame 447: preprocess=2.0ms, move=15.4ms, tracking=1.5ms,vis=3.1ms, total=21.9ms
# Frame 448: preprocess=1.9ms, move=13.9ms, tracking=1.0ms,vis=3.3ms, total=20.1ms
# Frame 449: preprocess=3.2ms, move=16.7ms, tracking=0.9ms,vis=3.0ms, total=23.8ms
# Frame 450: preprocess=2.4ms, move=15.8ms, tracking=1.3ms,vis=30.2ms, total=50.0ms
# Frame 451: preprocess=2.1ms, move=14.0ms, tracking=1.5ms,vis=3.2ms, total=20.9ms
# Frame 452: preprocess=1.8ms, move=14.8ms, tracking=1.7ms,vis=3.2ms, total=21.5ms
# Frame 453: preprocess=1.8ms, move=15.1ms, tracking=0.7ms,vis=2.8ms, total=20.4ms
# Frame 454: preprocess=2.1ms, move=15.3ms, tracking=0.9ms,vis=3.2ms, total=21.5ms
# Frame 455: preprocess=2.2ms, move=16.1ms, tracking=1.2ms,vis=3.2ms, total=22.9ms
# Frame 456: preprocess=2.8ms, move=16.3ms, tracking=1.4ms,vis=3.6ms, total=24.1ms
# Frame 457: preprocess=2.0ms, move=16.2ms, tracking=0.9ms,vis=3.0ms, total=22.1ms
# Frame 458: preprocess=1.8ms, move=16.9ms, tracking=1.5ms,vis=3.1ms, total=23.3ms
# Frame 459: preprocess=2.3ms, move=15.2ms, tracking=3.6ms,vis=3.4ms, total=24.5ms
# Frame 460: preprocess=2.5ms, move=15.0ms, tracking=2.0ms,vis=38.7ms, total=58.4ms
# Frame 461: preprocess=2.2ms, move=14.6ms, tracking=1.7ms,vis=3.3ms, total=21.8ms
# Frame 462: preprocess=2.9ms, move=15.0ms, tracking=1.6ms,vis=3.3ms, total=22.8ms
# Frame 463: preprocess=3.0ms, move=16.8ms, tracking=1.5ms,vis=3.3ms, total=24.7ms
# Frame 464: preprocess=3.3ms, move=14.3ms, tracking=1.5ms,vis=3.1ms, total=22.2ms
# Frame 465: preprocess=1.9ms, move=15.1ms, tracking=0.9ms,vis=2.9ms, total=21.0ms
# Frame 466: preprocess=2.2ms, move=14.9ms, tracking=0.7ms,vis=3.0ms, total=20.8ms
# Frame 467: preprocess=3.5ms, move=15.6ms, tracking=2.1ms,vis=3.1ms, total=24.4ms
# Frame 468: preprocess=2.2ms, move=16.3ms, tracking=1.1ms,vis=3.1ms, total=22.7ms
# Frame 469: preprocess=2.3ms, move=16.2ms, tracking=1.3ms,vis=3.3ms, total=23.1ms
# Frame 470: preprocess=2.1ms, move=16.8ms, tracking=1.7ms,vis=34.1ms, total=54.9ms
# Frame 471: preprocess=2.3ms, move=15.2ms, tracking=1.8ms,vis=3.5ms, total=22.8ms
# Frame 472: preprocess=2.3ms, move=15.2ms, tracking=1.2ms,vis=4.0ms, total=22.8ms
# Frame 473: preprocess=2.5ms, move=15.2ms, tracking=1.5ms,vis=2.7ms, total=22.0ms
# Frame 474: preprocess=2.7ms, move=14.6ms, tracking=1.2ms,vis=3.1ms, total=21.6ms
# Frame 475: preprocess=1.8ms, move=15.5ms, tracking=1.2ms,vis=3.3ms, total=22.1ms
# Frame 476: preprocess=2.6ms, move=14.7ms, tracking=1.0ms,vis=2.8ms, total=21.0ms
# Frame 477: preprocess=2.6ms, move=14.6ms, tracking=1.2ms,vis=3.1ms, total=21.6ms
# Frame 478: preprocess=2.6ms, move=15.3ms, tracking=0.8ms,vis=2.9ms, total=21.6ms
# Frame 479: preprocess=2.2ms, move=16.7ms, tracking=1.2ms,vis=3.1ms, total=23.3ms
# Frame 480: preprocess=3.4ms, move=23.1ms, tracking=0.7ms,vis=22.6ms, total=49.9ms
# Frame 481: preprocess=1.9ms, move=15.2ms, tracking=0.9ms,vis=4.0ms, total=22.1ms
# Frame 482: preprocess=2.6ms, move=13.7ms, tracking=0.7ms,vis=2.9ms, total=19.9ms
# Frame 483: preprocess=2.0ms, move=13.7ms, tracking=1.6ms,vis=2.8ms, total=20.1ms
# Frame 484: preprocess=2.5ms, move=13.7ms, tracking=1.7ms,vis=2.6ms, total=20.4ms
# Frame 485: preprocess=2.0ms, move=13.8ms, tracking=1.4ms,vis=2.9ms, total=20.4ms
# Frame 486: preprocess=2.2ms, move=15.4ms, tracking=1.0ms,vis=3.4ms, total=22.0ms
# Frame 487: preprocess=1.9ms, move=15.1ms, tracking=1.7ms,vis=3.3ms, total=22.1ms
# Frame 488: preprocess=2.2ms, move=16.1ms, tracking=1.8ms,vis=2.9ms, total=23.0ms
# Frame 489: preprocess=1.6ms, move=15.7ms, tracking=1.4ms,vis=2.9ms, total=21.6ms
# Frame 490: preprocess=2.8ms, move=15.1ms, tracking=1.2ms,vis=23.4ms, total=42.6ms
# Frame 491: preprocess=2.3ms, move=14.7ms, tracking=1.2ms,vis=3.1ms, total=21.3ms
# Frame 492: preprocess=2.4ms, move=16.8ms, tracking=0.8ms,vis=3.1ms, total=23.0ms
# Frame 493: preprocess=2.3ms, move=15.0ms, tracking=1.3ms,vis=3.2ms, total=21.7ms
# Frame 494: preprocess=1.9ms, move=15.4ms, tracking=1.2ms,vis=3.2ms, total=21.7ms
# Frame 495: preprocess=1.7ms, move=15.8ms, tracking=1.4ms,vis=3.2ms, total=22.2ms
# Frame 496: preprocess=2.3ms, move=16.3ms, tracking=1.1ms,vis=3.2ms, total=22.9ms
# Frame 497: preprocess=2.1ms, move=15.6ms, tracking=0.9ms,vis=3.3ms, total=21.9ms
# Frame 498: preprocess=2.1ms, move=16.1ms, tracking=0.9ms,vis=3.1ms, total=22.2ms
# Frame 499: preprocess=1.8ms, move=15.4ms, tracking=1.2ms,vis=3.1ms, total=21.6ms
# Frame 500: preprocess=2.5ms, move=15.1ms, tracking=0.7ms,vis=27.1ms, total=45.6ms
# Frame 501: preprocess=2.7ms, move=14.3ms, tracking=1.4ms,vis=3.2ms, total=21.6ms
# Frame 502: preprocess=1.9ms, move=16.3ms, tracking=1.3ms,vis=3.2ms, total=22.7ms
# Frame 503: preprocess=1.9ms, move=16.8ms, tracking=0.9ms,vis=3.4ms, total=23.0ms
# Frame 504: preprocess=2.4ms, move=16.3ms, tracking=0.9ms,vis=3.2ms, total=22.9ms
# Frame 505: preprocess=2.6ms, move=15.2ms, tracking=1.7ms,vis=3.2ms, total=22.8ms
# Frame 506: preprocess=2.4ms, move=16.1ms, tracking=1.2ms,vis=3.0ms, total=22.7ms
# Frame 507: preprocess=1.8ms, move=15.5ms, tracking=1.1ms,vis=3.1ms, total=21.6ms
# Frame 508: preprocess=2.2ms, move=15.4ms, tracking=0.6ms,vis=3.6ms, total=21.8ms
# Frame 509: preprocess=2.6ms, move=19.3ms, tracking=0.3ms,vis=7.2ms, total=29.5ms
# Frame 510: preprocess=2.5ms, move=13.4ms, tracking=0.2ms,vis=14.6ms, total=30.8ms
# Frame 511: preprocess=2.3ms, move=16.5ms, tracking=0.3ms,vis=3.2ms, total=22.2ms
# Frame 512: preprocess=1.9ms, move=14.1ms, tracking=0.1ms,vis=2.7ms, total=18.8ms
# Frame 513: preprocess=2.3ms, move=16.0ms, tracking=0.0ms,vis=2.9ms, total=21.2ms
# Frame 514: preprocess=2.1ms, move=14.8ms, tracking=0.0ms,vis=2.9ms, total=19.9ms
# Frame 515: preprocess=2.3ms, move=14.6ms, tracking=0.0ms,vis=2.8ms, total=19.8ms
# Frame 516: preprocess=2.4ms, move=15.0ms, tracking=0.0ms,vis=2.8ms, total=20.2ms
# Frame 517: preprocess=1.8ms, move=15.3ms, tracking=0.0ms,vis=2.8ms, total=19.9ms
# Frame 518: preprocess=2.2ms, move=14.4ms, tracking=0.0ms,vis=3.2ms, total=19.9ms
# Frame 519: preprocess=2.3ms, move=16.1ms, tracking=0.0ms,vis=2.8ms, total=21.2ms
# Frame 520: preprocess=1.7ms, move=14.5ms, tracking=0.0ms,vis=2.8ms, total=19.0ms
# Frame 521: preprocess=2.0ms, move=14.9ms, tracking=0.0ms,vis=3.4ms, total=20.3ms
# Frame 522: preprocess=2.0ms, move=15.8ms, tracking=0.0ms,vis=3.0ms, total=20.8ms
# Frame 523: preprocess=2.1ms, move=14.2ms, tracking=0.0ms,vis=2.7ms, total=19.1ms
# Frame 524: preprocess=1.9ms, move=14.8ms, tracking=0.0ms,vis=2.9ms, total=19.7ms
# Frame 525: preprocess=2.0ms, move=12.9ms, tracking=0.0ms,vis=2.7ms, total=17.6ms
# Frame 526: preprocess=2.0ms, move=14.6ms, tracking=0.0ms,vis=2.7ms, total=19.4ms
# Frame 527: preprocess=1.8ms, move=16.0ms, tracking=0.0ms,vis=2.7ms, total=20.5ms
# Frame 528: preprocess=1.8ms, move=13.6ms, tracking=0.0ms,vis=3.0ms, total=18.5ms
# Frame 529: preprocess=1.7ms, move=14.7ms, tracking=0.0ms,vis=2.7ms, total=19.1ms
# Frame 530: preprocess=2.1ms, move=15.2ms, tracking=0.3ms,vis=7.7ms, total=25.4ms
# Frame 531: preprocess=2.5ms, move=14.9ms, tracking=0.0ms,vis=2.7ms, total=20.2ms
# Frame 532: preprocess=2.2ms, move=14.8ms, tracking=0.0ms,vis=3.0ms, total=20.1ms
# Frame 533: preprocess=2.0ms, move=17.3ms, tracking=0.0ms,vis=3.3ms, total=22.6ms
# Frame 534: preprocess=2.2ms, move=14.5ms, tracking=0.0ms,vis=2.7ms, total=19.5ms
# Frame 535: preprocess=2.3ms, move=15.2ms, tracking=0.0ms,vis=3.7ms, total=21.3ms
# Frame 536: preprocess=1.8ms, move=14.9ms, tracking=0.0ms,vis=2.6ms, total=19.4ms
# Frame 537: preprocess=2.0ms, move=13.9ms, tracking=0.0ms,vis=2.7ms, total=18.5ms
# Frame 538: preprocess=2.3ms, move=15.0ms, tracking=0.0ms,vis=3.1ms, total=20.5ms
# Frame 539: preprocess=1.9ms, move=16.5ms, tracking=0.0ms,vis=2.7ms, total=21.1ms
# Frame 540: preprocess=2.1ms, move=14.0ms, tracking=0.0ms,vis=2.7ms, total=18.8ms
# Frame 541: preprocess=1.9ms, move=14.5ms, tracking=0.0ms,vis=2.8ms, total=19.2ms
# Frame 542: preprocess=2.1ms, move=14.9ms, tracking=0.0ms,vis=2.6ms, total=19.6ms
# Frame 543: preprocess=2.2ms, move=15.3ms, tracking=0.0ms,vis=2.6ms, total=20.1ms
# Frame 544: preprocess=2.4ms, move=15.4ms, tracking=0.0ms,vis=2.9ms, total=20.7ms
# Frame 545: preprocess=2.8ms, move=15.4ms, tracking=0.0ms,vis=3.3ms, total=21.5ms
# Frame 546: preprocess=2.0ms, move=13.8ms, tracking=0.0ms,vis=2.5ms, total=18.3ms
# Frame 547: preprocess=2.1ms, move=14.8ms, tracking=0.0ms,vis=2.9ms, total=19.8ms
# Frame 548: preprocess=2.3ms, move=14.1ms, tracking=0.0ms,vis=3.2ms, total=19.6ms
# Frame 549: preprocess=2.4ms, move=17.1ms, tracking=0.0ms,vis=3.0ms, total=22.5ms
# Frame 550: preprocess=2.2ms, move=14.9ms, tracking=0.0ms,vis=3.1ms, total=20.3ms
# Frame 551: preprocess=1.9ms, move=16.4ms, tracking=0.0ms,vis=2.8ms, total=21.1ms
# Frame 552: preprocess=2.0ms, move=17.1ms, tracking=0.0ms,vis=3.0ms, total=22.2ms
# Frame 553: preprocess=2.4ms, move=14.5ms, tracking=0.0ms,vis=2.8ms, total=19.7ms
# Frame 554: preprocess=2.3ms, move=13.9ms, tracking=0.0ms,vis=2.8ms, total=19.0ms
# Frame 555: preprocess=2.0ms, move=15.4ms, tracking=0.0ms,vis=2.8ms, total=20.2ms
# Frame 556: preprocess=2.4ms, move=16.4ms, tracking=0.0ms,vis=3.0ms, total=21.8ms
# Frame 557: preprocess=2.1ms, move=16.3ms, tracking=0.0ms,vis=2.7ms, total=21.1ms
# Frame 558: preprocess=2.4ms, move=15.6ms, tracking=0.0ms,vis=2.6ms, total=20.5ms
# Frame 559: preprocess=1.9ms, move=14.9ms, tracking=0.0ms,vis=3.2ms, total=20.0ms
# Frame 560: preprocess=2.3ms, move=17.1ms, tracking=0.0ms,vis=2.8ms, total=22.2ms
# Frame 561: preprocess=2.2ms, move=14.5ms, tracking=0.0ms,vis=2.7ms, total=19.5ms
# Frame 562: preprocess=2.5ms, move=15.3ms, tracking=0.0ms,vis=2.9ms, total=20.6ms
# Frame 563: preprocess=2.3ms, move=14.4ms, tracking=0.0ms,vis=2.7ms, total=19.4ms
# Frame 564: preprocess=2.1ms, move=16.3ms, tracking=0.0ms,vis=3.3ms, total=21.7ms
# Frame 565: preprocess=2.4ms, move=16.1ms, tracking=0.0ms,vis=3.0ms, total=21.5ms
# Frame 566: preprocess=2.5ms, move=14.8ms, tracking=0.0ms,vis=3.0ms, total=20.3ms
# Frame 567: preprocess=2.4ms, move=15.4ms, tracking=0.0ms,vis=2.8ms, total=20.6ms
# Frame 568: preprocess=1.9ms, move=14.6ms, tracking=0.0ms,vis=2.8ms, total=19.3ms
# Frame 569: preprocess=2.1ms, move=15.1ms, tracking=0.0ms,vis=2.6ms, total=19.8ms
# Frame 570: preprocess=2.4ms, move=15.6ms, tracking=0.0ms,vis=3.1ms, total=21.1ms
# Frame 571: preprocess=1.5ms, move=15.9ms, tracking=0.0ms,vis=2.6ms, total=20.0ms
# Frame 572: preprocess=2.2ms, move=16.6ms, tracking=0.3ms,vis=2.7ms, total=21.8ms
# Frame 573: preprocess=2.1ms, move=17.1ms, tracking=0.5ms,vis=2.9ms, total=22.6ms
# Frame 574: preprocess=2.4ms, move=15.6ms, tracking=0.7ms,vis=2.9ms, total=21.7ms
# Frame 575: preprocess=2.2ms, move=14.2ms, tracking=1.1ms,vis=3.0ms, total=20.7ms
# Frame 576: preprocess=2.5ms, move=15.4ms, tracking=1.0ms,vis=4.0ms, total=22.9ms
# Frame 577: preprocess=2.4ms, move=15.2ms, tracking=0.9ms,vis=3.0ms, total=21.5ms
# Frame 578: preprocess=1.8ms, move=16.9ms, tracking=1.1ms,vis=3.2ms, total=23.0ms
# Frame 579: preprocess=2.5ms, move=15.2ms, tracking=1.1ms,vis=3.2ms, total=21.9ms
# Frame 580: preprocess=2.2ms, move=16.1ms, tracking=1.3ms,vis=26.2ms, total=45.9ms
# Frame 581: preprocess=2.3ms, move=17.6ms, tracking=0.8ms,vis=3.1ms, total=23.8ms
# Frame 582: preprocess=2.4ms, move=15.7ms, tracking=0.7ms,vis=3.0ms, total=21.8ms
# Frame 583: preprocess=2.6ms, move=16.3ms, tracking=1.0ms,vis=3.3ms, total=23.2ms
# Frame 584: preprocess=2.5ms, move=15.7ms, tracking=1.0ms,vis=3.1ms, total=22.3ms
# Frame 585: preprocess=1.8ms, move=36.6ms, tracking=1.1ms,vis=3.5ms, total=43.1ms
# Frame 586: preprocess=2.4ms, move=13.8ms, tracking=1.3ms,vis=3.3ms, total=20.7ms
# Frame 587: preprocess=1.8ms, move=16.1ms, tracking=1.0ms,vis=2.7ms, total=21.6ms
# Frame 588: preprocess=2.1ms, move=15.8ms, tracking=1.3ms,vis=3.1ms, total=22.2ms
# Frame 589: preprocess=1.8ms, move=15.1ms, tracking=1.3ms,vis=3.2ms, total=21.3ms
# Frame 590: preprocess=2.5ms, move=16.7ms, tracking=1.3ms,vis=29.8ms, total=50.4ms
# Frame 591: preprocess=2.3ms, move=16.6ms, tracking=1.3ms,vis=3.8ms, total=24.0ms
# Frame 592: preprocess=3.3ms, move=16.4ms, tracking=1.3ms,vis=3.3ms, total=24.3ms
# ...
# Frame 1361: preprocess=2.4ms, move=15.7ms, tracking=1.3ms,vis=4.0ms, total=23.5ms
# Frame 1362: preprocess=2.0ms, move=15.9ms, tracking=1.3ms,vis=3.4ms, total=22.6ms
# Frame 1363: preprocess=2.3ms, move=38.5ms, tracking=0.9ms,vis=4.6ms, total=46.4ms
# Frame 1364: preprocess=2.1ms, move=13.5ms, tracking=1.3ms,vis=3.1ms, total=19.9ms
# Frame 1365: preprocess=1.8ms, move=14.6ms, tracking=1.3ms,vis=4.2ms, total=22.1ms
# Frame 1366: preprocess=1.7ms, move=15.4ms, tracking=1.2ms,vis=3.2ms, total=21.7ms
# Frame 1367: preprocess=2.5ms, move=17.1ms, tracking=1.4ms,vis=3.3ms, total=24.3ms
# Frame 1368: preprocess=2.3ms, move=15.3ms, tracking=1.6ms,vis=3.1ms, total=22.3ms
# Frame 1369: preprocess=2.4ms, move=15.7ms, tracking=1.3ms,vis=3.1ms, total=22.5ms
# Frame 1370: preprocess=2.3ms, move=14.8ms, tracking=1.5ms,vis=39.2ms, total=57.9ms
# Frame 1371: preprocess=2.3ms, move=16.1ms, tracking=2.1ms,vis=3.7ms, total=24.2ms
# Frame 1372: preprocess=2.2ms, move=16.1ms, tracking=1.2ms,vis=3.3ms, total=22.8ms
# Frame 1373: preprocess=1.9ms, move=15.0ms, tracking=1.2ms,vis=2.9ms, total=21.0ms
# Frame 1374: preprocess=2.3ms, move=15.5ms, tracking=1.6ms,vis=3.1ms, total=22.6ms
# Frame 1375: preprocess=2.0ms, move=18.1ms, tracking=2.0ms,vis=3.0ms, total=25.3ms
# Frame 1376: preprocess=2.4ms, move=15.3ms, tracking=1.3ms,vis=2.9ms, total=21.9ms
# Frame 1377: preprocess=2.1ms, move=15.8ms, tracking=1.2ms,vis=3.1ms, total=22.2ms
# Frame 1378: preprocess=2.1ms, move=16.4ms, tracking=1.0ms,vis=3.2ms, total=22.8ms
# Frame 1379: preprocess=1.9ms, move=15.6ms, tracking=0.4ms,vis=3.0ms, total=20.9ms
# Frame 1380: preprocess=2.0ms, move=16.3ms, tracking=0.3ms,vis=17.1ms, total=35.9ms
# Frame 1381: preprocess=2.4ms, move=16.1ms, tracking=0.1ms,vis=2.3ms, total=21.0ms
# Frame 1382: preprocess=2.2ms, move=15.9ms, tracking=0.1ms,vis=2.8ms, total=20.9ms
# Frame 1383: preprocess=3.0ms, move=13.3ms, tracking=0.3ms,vis=3.1ms, total=19.8ms
# Frame 1384: preprocess=2.0ms, move=15.0ms, tracking=0.0ms,vis=2.9ms, total=20.0ms
# Frame 1385: preprocess=2.6ms, move=16.0ms, tracking=0.0ms,vis=3.2ms, total=22.0ms
# Frame 1386: preprocess=2.1ms, move=16.8ms, tracking=0.0ms,vis=4.4ms, total=23.4ms
# Frame 1387: preprocess=2.0ms, move=16.8ms, tracking=0.0ms,vis=2.9ms, total=21.7ms
# Frame 1388: preprocess=2.0ms, move=17.0ms, tracking=0.0ms,vis=3.4ms, total=22.4ms
# Frame 1389: preprocess=2.6ms, move=15.2ms, tracking=0.4ms,vis=2.8ms, total=21.0ms
# Frame 1390: preprocess=2.1ms, move=15.9ms, tracking=0.0ms,vis=7.9ms, total=26.1ms
# Frame 1391: preprocess=2.3ms, move=15.8ms, tracking=0.0ms,vis=3.1ms, total=21.3ms
# Frame 1392: preprocess=2.0ms, move=14.4ms, tracking=0.0ms,vis=3.1ms, total=19.6ms
# Frame 1393: preprocess=2.3ms, move=16.1ms, tracking=0.0ms,vis=3.8ms, total=22.1ms
# Frame 1394: preprocess=1.9ms, move=15.5ms, tracking=0.0ms,vis=3.6ms, total=21.1ms
# Frame 1395: preprocess=2.0ms, move=15.3ms, tracking=0.0ms,vis=2.9ms, total=20.3ms
# Frame 1396: preprocess=2.0ms, move=15.2ms, tracking=0.0ms,vis=3.6ms, total=20.8ms
# Frame 1397: preprocess=5.1ms, move=17.3ms, tracking=0.0ms,vis=7.4ms, total=29.9ms
# Frame 1398: preprocess=2.0ms, move=14.4ms, tracking=0.0ms,vis=2.8ms, total=19.2ms
# Frame 1399: preprocess=1.7ms, move=15.1ms, tracking=0.0ms,vis=2.8ms, total=19.6ms
# Frame 1400: preprocess=2.6ms, move=17.2ms, tracking=0.0ms,vis=2.8ms, total=22.6ms
# Frame 1401: preprocess=2.0ms, move=17.6ms, tracking=0.0ms,vis=3.0ms, total=22.7ms
# Frame 1402: preprocess=1.9ms, move=14.2ms, tracking=0.0ms,vis=2.9ms, total=19.1ms
# Frame 1403: preprocess=2.1ms, move=15.0ms, tracking=0.0ms,vis=3.0ms, total=20.2ms
# Frame 1404: preprocess=1.9ms, move=15.6ms, tracking=0.0ms,vis=2.8ms, total=20.3ms
# Frame 1405: preprocess=1.8ms, move=16.3ms, tracking=0.0ms,vis=2.9ms, total=21.1ms
# Frame 1406: preprocess=2.2ms, move=15.4ms, tracking=0.0ms,vis=2.4ms, total=20.0ms
# Frame 1407: preprocess=1.8ms, move=14.6ms, tracking=0.0ms,vis=2.9ms, total=19.4ms
# Frame 1408: preprocess=2.7ms, move=16.3ms, tracking=0.0ms,vis=3.4ms, total=22.5ms
# Frame 1409: preprocess=2.0ms, move=14.8ms, tracking=0.0ms,vis=2.9ms, total=19.8ms
# Frame 1410: preprocess=1.8ms, move=16.5ms, tracking=0.0ms,vis=2.7ms, total=21.1ms
# Frame 1411: preprocess=1.9ms, move=15.9ms, tracking=0.0ms,vis=3.0ms, total=20.7ms
# Frame 1412: preprocess=2.0ms, move=15.9ms, tracking=0.0ms,vis=2.9ms, total=20.9ms
# Frame 1413: preprocess=2.5ms, move=14.7ms, tracking=0.0ms,vis=3.3ms, total=20.4ms
# Frame 1414: preprocess=2.1ms, move=14.5ms, tracking=0.0ms,vis=2.8ms, total=19.5ms
# Frame 1415: preprocess=1.9ms, move=16.0ms, tracking=0.0ms,vis=3.8ms, total=21.8ms
# Frame 1416: preprocess=2.2ms, move=13.9ms, tracking=0.0ms,vis=2.7ms, total=18.9ms
# Frame 1417: preprocess=3.0ms, move=14.5ms, tracking=0.0ms,vis=2.8ms, total=20.3ms
# Frame 1418: preprocess=2.8ms, move=17.2ms, tracking=0.0ms,vis=3.2ms, total=23.2ms
# Frame 1419: preprocess=1.7ms, move=15.1ms, tracking=0.0ms,vis=2.9ms, total=19.7ms
# Frame 1420: preprocess=2.1ms, move=15.1ms, tracking=0.0ms,vis=2.5ms, total=19.7ms
# Frame 1421: preprocess=1.7ms, move=16.3ms, tracking=0.0ms,vis=2.8ms, total=20.8ms
# Frame 1422: preprocess=1.7ms, move=14.0ms, tracking=0.0ms,vis=2.5ms, total=18.2ms
# Frame 1423: preprocess=1.9ms, move=15.6ms, tracking=0.0ms,vis=3.3ms, total=20.8ms
# Frame 1424: preprocess=2.1ms, move=15.3ms, tracking=0.0ms,vis=3.0ms, total=20.3ms
# Frame 1425: preprocess=2.2ms, move=17.7ms, tracking=0.0ms,vis=2.9ms, total=22.8ms
# Frame 1426: preprocess=2.2ms, move=13.8ms, tracking=0.0ms,vis=2.9ms, total=19.0ms
# Frame 1427: preprocess=1.8ms, move=17.2ms, tracking=0.0ms,vis=3.3ms, total=22.3ms
# Frame 1428: preprocess=1.8ms, move=16.9ms, tracking=0.0ms,vis=3.4ms, total=22.2ms
# Frame 1429: preprocess=2.0ms, move=15.7ms, tracking=0.0ms,vis=2.5ms, total=20.3ms
# Frame 1430: preprocess=2.0ms, move=15.1ms, tracking=0.0ms,vis=3.0ms, total=20.1ms
# Frame 1431: preprocess=2.0ms, move=13.9ms, tracking=0.0ms,vis=2.7ms, total=18.6ms
# Frame 1432: preprocess=1.8ms, move=15.1ms, tracking=0.0ms,vis=3.0ms, total=19.9ms
# Frame 1433: preprocess=2.3ms, move=29.1ms, tracking=0.0ms,vis=6.4ms, total=37.8ms
# Frame 1434: preprocess=2.0ms, move=15.1ms, tracking=0.0ms,vis=3.1ms, total=20.2ms
# Frame 1435: preprocess=1.5ms, move=15.6ms, tracking=0.0ms,vis=2.8ms, total=20.0ms
# Frame 1436: preprocess=2.0ms, move=13.8ms, tracking=0.0ms,vis=2.3ms, total=18.1ms
# Frame 1437: preprocess=2.1ms, move=14.5ms, tracking=0.0ms,vis=2.2ms, total=18.9ms
# Frame 1438: preprocess=1.6ms, move=14.7ms, tracking=0.0ms,vis=2.8ms, total=19.1ms
# Frame 1439: preprocess=2.1ms, move=15.7ms, tracking=0.0ms,vis=2.8ms, total=20.7ms
# Frame 1440: preprocess=2.1ms, move=14.2ms, tracking=0.3ms,vis=7.6ms, total=24.2ms
# Frame 1441: preprocess=2.0ms, move=14.9ms, tracking=0.0ms,vis=2.7ms, total=19.6ms
# Frame 1442: preprocess=1.9ms, move=14.3ms, tracking=0.0ms,vis=2.9ms, total=19.1ms
# Frame 1443: preprocess=2.2ms, move=14.5ms, tracking=0.0ms,vis=4.3ms, total=21.0ms
# Frame 1444: preprocess=1.8ms, move=15.7ms, tracking=0.0ms,vis=3.4ms, total=20.9ms
# Frame 1445: preprocess=1.9ms, move=14.6ms, tracking=0.0ms,vis=2.8ms, total=19.5ms
# Frame 1446: preprocess=2.2ms, move=16.2ms, tracking=0.0ms,vis=2.7ms, total=21.2ms
# Frame 1447: preprocess=2.3ms, move=15.6ms, tracking=0.0ms,vis=2.8ms, total=20.7ms
# Frame 1448: preprocess=2.5ms, move=15.4ms, tracking=0.0ms,vis=3.0ms, total=20.9ms
# Frame 1449: preprocess=2.2ms, move=15.6ms, tracking=0.0ms,vis=2.7ms, total=20.6ms
# Frame 1450: preprocess=2.0ms, move=16.8ms, tracking=0.0ms,vis=3.1ms, total=21.9ms
# Frame 1451: preprocess=2.2ms, move=15.1ms, tracking=0.0ms,vis=3.0ms, total=20.3ms
# Frame 1452: preprocess=2.6ms, move=15.1ms, tracking=0.0ms,vis=3.2ms, total=20.9ms
# Frame 1453: preprocess=2.3ms, move=17.5ms, tracking=0.0ms,vis=3.1ms, total=22.9ms
# Frame 1454: preprocess=2.2ms, move=16.0ms, tracking=0.0ms,vis=2.7ms, total=21.0ms
# Frame 1455: preprocess=2.4ms, move=16.9ms, tracking=0.0ms,vis=3.2ms, total=22.4ms
# Frame 1456: preprocess=2.2ms, move=18.5ms, tracking=0.3ms,vis=3.0ms, total=24.1ms
# Frame 1457: preprocess=1.9ms, move=15.6ms, tracking=0.5ms,vis=3.1ms, total=21.2ms
# Frame 1458: preprocess=1.9ms, move=15.3ms, tracking=0.5ms,vis=2.8ms, total=20.5ms
# Frame 1459: preprocess=2.3ms, move=16.1ms, tracking=0.6ms,vis=3.4ms, total=22.3ms
# Frame 1460: preprocess=2.1ms, move=14.9ms, tracking=0.2ms,vis=11.1ms, total=28.4ms
# Frame 1461: preprocess=1.9ms, move=14.3ms, tracking=0.2ms,vis=2.8ms, total=19.2ms
# Frame 1462: preprocess=2.3ms, move=15.8ms, tracking=0.1ms,vis=5.3ms, total=23.4ms
# Frame 1463: preprocess=2.1ms, move=15.2ms, tracking=0.0ms,vis=3.1ms, total=20.5ms
# Frame 1464: preprocess=2.0ms, move=16.8ms, tracking=0.0ms,vis=3.1ms, total=21.9ms
# Frame 1465: preprocess=2.0ms, move=14.4ms, tracking=0.0ms,vis=2.8ms, total=19.3ms
# Frame 1466: preprocess=2.1ms, move=15.2ms, tracking=0.0ms,vis=2.8ms, total=20.2ms
# Frame 1467: preprocess=1.9ms, move=13.9ms, tracking=0.0ms,vis=2.8ms, total=18.6ms
# Frame 1468: preprocess=3.1ms, move=17.1ms, tracking=0.0ms,vis=2.9ms, total=23.1ms
# Frame 1469: preprocess=2.7ms, move=20.9ms, tracking=0.0ms,vis=3.3ms, total=26.9ms
# Frame 1470: preprocess=1.9ms, move=14.9ms, tracking=0.0ms,vis=3.3ms, total=20.1ms
# Frame 1471: preprocess=2.1ms, move=15.1ms, tracking=0.0ms,vis=2.9ms, total=20.1ms
# Frame 1472: preprocess=2.2ms, move=14.1ms, tracking=0.0ms,vis=3.3ms, total=19.6ms
# Frame 1473: preprocess=2.2ms, move=15.1ms, tracking=0.0ms,vis=2.9ms, total=20.1ms
# Frame 1474: preprocess=1.6ms, move=14.7ms, tracking=0.0ms,vis=3.1ms, total=19.4ms
# Frame 1475: preprocess=1.9ms, move=14.2ms, tracking=0.0ms,vis=2.7ms, total=18.8ms
# Frame 1476: preprocess=1.9ms, move=14.7ms, tracking=0.0ms,vis=2.6ms, total=19.2ms
# Frame 1477: preprocess=1.7ms, move=14.2ms, tracking=0.0ms,vis=3.1ms, total=19.0ms
# Frame 1478: preprocess=2.3ms, move=15.0ms, tracking=0.0ms,vis=2.9ms, total=20.2ms
# Frame 1479: preprocess=3.4ms, move=14.5ms, tracking=0.0ms,vis=2.7ms, total=20.5ms
# Frame 1480: preprocess=2.0ms, move=14.6ms, tracking=0.0ms,vis=2.9ms, total=19.5ms
# Frame 1481: preprocess=2.3ms, move=14.3ms, tracking=0.0ms,vis=2.9ms, total=19.5ms
# Frame 1482: preprocess=2.1ms, move=14.9ms, tracking=0.0ms,vis=2.7ms, total=19.7ms
# Frame 1483: preprocess=2.9ms, move=14.9ms, tracking=0.0ms,vis=2.6ms, total=20.5ms
# Frame 1484: preprocess=1.8ms, move=15.8ms, tracking=0.0ms,vis=2.8ms, total=20.4ms
# Frame 1485: preprocess=3.0ms, move=15.3ms, tracking=0.0ms,vis=2.7ms, total=21.2ms
# Frame 1486: preprocess=1.7ms, move=14.8ms, tracking=0.0ms,vis=2.8ms, total=19.3ms
# Frame 1487: preprocess=2.2ms, move=15.9ms, tracking=0.0ms,vis=3.3ms, total=21.5ms
# Frame 1488: preprocess=2.4ms, move=14.7ms, tracking=0.0ms,vis=3.0ms, total=20.1ms
# Frame 1489: preprocess=2.0ms, move=15.8ms, tracking=0.0ms,vis=3.0ms, total=20.7ms
# Frame 1490: preprocess=3.7ms, move=17.9ms, tracking=0.0ms,vis=3.0ms, total=24.7ms
# Frame 1491: preprocess=2.2ms, move=15.8ms, tracking=0.0ms,vis=2.8ms, total=20.9ms
# Frame 1492: preprocess=2.3ms, move=15.0ms, tracking=0.0ms,vis=2.9ms, total=20.2ms
# Frame 1493: preprocess=2.4ms, move=15.4ms, tracking=0.0ms,vis=2.8ms, total=20.6ms
# Frame 1494: preprocess=1.9ms, move=15.8ms, tracking=0.0ms,vis=2.7ms, total=20.5ms
# Frame 1495: preprocess=2.1ms, move=17.5ms, tracking=0.0ms,vis=3.5ms, total=23.1ms
# Frame 1496: preprocess=1.8ms, move=14.9ms, tracking=0.0ms,vis=2.7ms, total=19.5ms
# Frame 1497: preprocess=2.5ms, move=15.4ms, tracking=0.0ms,vis=3.3ms, total=21.2ms
# Frame 1498: preprocess=5.7ms, move=15.8ms, tracking=0.0ms,vis=3.8ms, total=25.3ms
# Frame 1499: preprocess=1.9ms, move=17.1ms, tracking=0.0ms,vis=3.0ms, total=22.0ms
# Frame 1500: preprocess=1.9ms, move=15.6ms, tracking=0.0ms,vis=3.1ms, total=20.6ms
# Frame 1501: preprocess=2.2ms, move=16.2ms, tracking=0.0ms,vis=2.5ms, total=21.0ms
# Frame 1502: preprocess=1.9ms, move=14.5ms, tracking=0.0ms,vis=2.7ms, total=19.2ms
# Frame 1503: preprocess=2.1ms, move=14.2ms, tracking=0.0ms,vis=3.0ms, total=19.3ms
# Frame 1504: preprocess=1.7ms, move=15.1ms, tracking=0.0ms,vis=2.8ms, total=19.7ms
# Frame 1505: preprocess=3.8ms, move=16.4ms, tracking=0.0ms,vis=2.7ms, total=23.0ms
# Frame 1506: preprocess=2.2ms, move=14.1ms, tracking=0.0ms,vis=2.8ms, total=19.1ms
# Frame 1507: preprocess=2.2ms, move=15.6ms, tracking=0.0ms,vis=3.1ms, total=21.0ms
# Frame 1508: preprocess=4.3ms, move=15.4ms, tracking=0.0ms,vis=2.7ms, total=22.4ms
# Frame 1509: preprocess=2.7ms, move=17.7ms, tracking=0.0ms,vis=3.1ms, total=23.6ms
# Frame 1510: preprocess=2.6ms, move=13.6ms, tracking=0.1ms,vis=3.4ms, total=19.6ms
# Frame 1511: preprocess=3.4ms, move=14.8ms, tracking=0.0ms,vis=3.1ms, total=21.3ms
# Frame 1512: preprocess=2.1ms, move=15.1ms, tracking=0.0ms,vis=2.6ms, total=19.8ms
# Frame 1513: preprocess=2.3ms, move=15.1ms, tracking=0.0ms,vis=2.7ms, total=20.1ms
# Frame 1514: preprocess=3.2ms, move=15.8ms, tracking=0.0ms,vis=2.9ms, total=22.0ms
# Frame 1515: preprocess=3.5ms, move=14.5ms, tracking=0.0ms,vis=4.2ms, total=22.2ms
# Frame 1516: preprocess=2.2ms, move=15.0ms, tracking=0.0ms,vis=2.6ms, total=19.9ms
# Frame 1517: preprocess=2.5ms, move=16.7ms, tracking=0.0ms,vis=2.8ms, total=22.0ms
# Frame 1518: preprocess=2.1ms, move=15.5ms, tracking=0.0ms,vis=3.0ms, total=20.7ms
# Frame 1519: preprocess=2.3ms, move=14.6ms, tracking=0.0ms,vis=2.7ms, total=19.7ms
# Frame 1520: preprocess=2.2ms, move=16.0ms, tracking=0.0ms,vis=2.9ms, total=21.1ms
# Frame 1521: preprocess=2.2ms, move=15.5ms, tracking=0.0ms,vis=3.0ms, total=20.8ms
# Frame 1522: preprocess=2.2ms, move=14.5ms, tracking=0.0ms,vis=2.8ms, total=19.5ms
# Frame 1523: preprocess=3.2ms, move=15.9ms, tracking=0.0ms,vis=2.6ms, total=21.7ms
# Frame 1524: preprocess=2.7ms, move=16.5ms, tracking=0.0ms,vis=3.0ms, total=22.2ms
# Frame 1525: preprocess=2.5ms, move=15.0ms, tracking=0.0ms,vis=2.9ms, total=20.4ms
# Frame 1526: preprocess=2.0ms, move=14.9ms, tracking=0.0ms,vis=3.6ms, total=20.5ms
# Frame 1527: preprocess=1.9ms, move=14.6ms, tracking=0.0ms,vis=3.0ms, total=19.6ms
# Frame 1528: preprocess=2.1ms, move=16.6ms, tracking=0.0ms,vis=3.0ms, total=21.7ms
# Frame 1529: preprocess=1.8ms, move=16.9ms, tracking=0.0ms,vis=2.8ms, total=21.5ms
# Frame 1530: preprocess=2.0ms, move=17.3ms, tracking=0.0ms,vis=3.0ms, total=22.4ms
# Frame 1531: preprocess=2.8ms, move=14.9ms, tracking=0.0ms,vis=3.8ms, total=21.6ms
# Frame 1532: preprocess=1.8ms, move=14.8ms, tracking=0.0ms,vis=2.8ms, total=19.4ms
# Frame 1533: preprocess=2.9ms, move=15.3ms, tracking=0.0ms,vis=2.8ms, total=21.0ms
# Frame 1534: preprocess=2.0ms, move=16.4ms, tracking=0.0ms,vis=2.8ms, total=21.3ms
# Frame 1535: preprocess=2.2ms, move=15.7ms, tracking=0.0ms,vis=2.7ms, total=20.7ms
# Frame 1536: preprocess=2.4ms, move=18.1ms, tracking=0.0ms,vis=2.9ms, total=23.5ms
# Frame 1537: preprocess=2.4ms, move=15.6ms, tracking=0.0ms,vis=2.8ms, total=20.8ms
# Frame 1538: preprocess=2.0ms, move=16.1ms, tracking=0.0ms,vis=3.0ms, total=21.1ms
# Frame 1539: preprocess=1.8ms, move=14.5ms, tracking=0.0ms,vis=2.8ms, total=19.1ms
# Frame 1540: preprocess=3.1ms, move=15.6ms, tracking=0.0ms,vis=3.3ms, total=22.0ms
# Frame 1541: preprocess=4.4ms, move=22.3ms, tracking=0.0ms,vis=4.9ms, total=31.7ms
# Frame 1542: preprocess=2.5ms, move=19.3ms, tracking=0.0ms,vis=2.2ms, total=24.1ms
# Frame 1543: preprocess=2.3ms, move=13.7ms, tracking=0.0ms,vis=2.6ms, total=18.6ms
# Frame 1544: preprocess=2.3ms, move=14.6ms, tracking=0.0ms,vis=3.4ms, total=20.3ms
# Frame 1545: preprocess=2.2ms, move=16.2ms, tracking=0.0ms,vis=2.8ms, total=21.1ms
# Frame 1546: preprocess=2.4ms, move=15.1ms, tracking=0.0ms,vis=2.8ms, total=20.3ms
# Frame 1547: preprocess=2.0ms, move=15.8ms, tracking=0.0ms,vis=3.0ms, total=20.9ms
# Frame 1548: preprocess=2.2ms, move=14.5ms, tracking=0.0ms,vis=3.3ms, total=20.0ms
# Frame 1549: preprocess=1.9ms, move=16.4ms, tracking=0.0ms,vis=4.0ms, total=22.4ms
# Frame 1550: preprocess=2.1ms, move=15.8ms, tracking=0.0ms,vis=2.9ms, total=20.8ms
# Frame 1551: preprocess=1.9ms, move=15.8ms, tracking=0.0ms,vis=2.7ms, total=20.4ms
# Frame 1552: preprocess=2.0ms, move=15.1ms, tracking=0.0ms,vis=3.1ms, total=20.2ms
# Frame 1553: preprocess=3.9ms, move=29.5ms, tracking=0.0ms,vis=4.2ms, total=37.6ms
# Frame 1554: preprocess=2.3ms, move=23.4ms, tracking=0.0ms,vis=4.3ms, total=30.0ms
# Done processing.

# %%
# === RESULTS AND DIAGNOSTICS ===

# latency metrics
#print(f"Processed {frame_idx} frames")
print(f"Average per-frame latency: {np.mean(latencies):.2f} ms")
print(f"Max per-frame latency: {np.max(latencies):.2f} ms")
print(f"Estimated FPS capability: {1000.0 / np.mean(latencies):.1f} FPS")

# plot latency distribution 
plt.figure()
plt.hist(latencies, bins=30)
plt.xlabel("Latency per frame (ms)")
plt.ylabel("Count")
plt.title("Frame Processing Latency Distribution")
plt.show()

#plot detection metrics to quantitatively show scaling behavior
plt.figure()
plt.plot(det_counts, label="Detections")
plt.plot(track_counts, label="Active Tracks")
plt.legend()
plt.title("Multi-target Capacity Over Time")
plt.xlabel("Frame")
plt.ylabel("Count")
plt.show()
# Out:
# Average per-frame latency: 26.47 ms
# Max per-frame latency: 644.51 ms
# Estimated FPS capability: 37.8 FPS

# %%
# example frames
num_show = min(25, len(frames))
for i in range(num_show):
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.imshow(frames[i][..., ::-1])
    plt.title("Tracked Flies")
    plt.axis("off")
    
    
    plt.subplot(1,2,2)
    plt.imshow(thresh_frames[i], cmap='gray')
    plt.title("Frame Subtraction Mask")
    plt.axis("off")
    plt.show()

# TODO FIGURE OUT HOW TO VALIDATE FRAME SUBTRACTION/ACCURACY - MAYBE CUT/SAMPLE PARTICULAR VIDEO SECTIONS

# %%
# ADD ABLATION TO COMPARE EFFICACY VS CURRENT ALGORITHM 
""" KEY HYPOTHESIS: 
1. DISCOVERY RECALL REMAINS UNCHANGED
2. TRACK CONTINUITY IMPROVES OR STAYS EQUAL
3. LATENCY DROPS SIGNIFICANTLY
4. FALSE POSITIVES TO NO INCREASE MATERIALLY """
