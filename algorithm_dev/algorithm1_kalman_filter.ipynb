# %%
#Algorithm outline and testing

# %%
# === PART 1: DETECT & LOCALIZE FLIES PER FRAME ===
""" goal is to record latency of frame substraction, ensure that program can keep track of multiple flies in each frame """

#imports
import cv2
import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import linear_sum_assignment
from collections import deque

# %%
#constants
VIDEO_PATH = "LUCID_TRI032S-M_251700592__20251114112116359_video3.avi" #path to AVI file
DOWNSCALE = 1.0 #<1.0 to downscale frames for speed
THRESH_VAL = 25 # frame subtraction threshold
MIN_AREA = 5 # minimum blob area (pixels)
MAX_AREA = 500 # max blob area (pixels)
MAX_MISSED = 10 # allows tracks to survive 10 frames without a detection
MAX_TRACK_DIST = 50 # max distance for track association (pixels)
HISTORY = 50 # frame to keep for plotting

# ROI Configuration
# define ROI as fractions of frame dimensions
ROI_X_MIN = 0.5
ROI_Y_MIN = 0.0

# static object detection
STATIC_THRESH = 120 #grayscale threshold for dark objects 
BACKGROUND_ALPHA = 0.005 # running background update rate
SLOW_ALPHA = 0.0002
PERSIST_THRESH = 15 # how dark is "fly-like"
PERSIST_FRAMES = 20 #how long it must persist

# Precomputed morphology kernels (create once)
kernel3 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3,3))
kernel5 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5,5))

# Precompute a small circle mask for radius 6
CIRCLE_RADIUS = 20
circle_mask = np.zeros((2*CIRCLE_RADIUS+1, 2*CIRCLE_RADIUS+1), dtype=np.uint8)
cv2.circle(circle_mask, (CIRCLE_RADIUS, CIRCLE_RADIUS), CIRCLE_RADIUS, 255, -1)


# manual kalman transition model
DT = 1.0 # assume constant frame interval

#transition
F = np.array([
    [1, 0, DT, 0],
    [0, 1, 0, DT],
    [0, 0, 1,  0],
    [0, 0, 0,  1]
], dtype=np.float32)

# measurement/observation
H = np.array([
    [1, 0, 0, 0],
    [0, 1, 0, 0]
], dtype=np.float32)

# noise 
Q = np.eye(4, dtype=np.float32) * 0.01 # process noise
R = np.eye(2, dtype=np.float32) * 4.0 # measurement noise

# Kalman state vocabulary 
# init --> just spawned, not trusted
# tracked --> stable, being updated
# stationary --> velocity near zero for N frames
# lost --> missed but not yet deleted (minimize # of these to avoid egregious computation time)
INIT_FRAMES=3
STATIONARY_VEL_THRESH = 0.3
STATIONARY_FRAMES = 10

# %%
#tracking class
class Track: 
    def __init__(self, track_id, centroid): 
        self.id = track_id
        self.centroids = deque(maxlen=HISTORY)
        self.centroids.append(centroid)
        #self.last_seen = 0 # frame idx when last seen
        self.missed = 0 # num of consecutive frames w/o detection
        self.age=1
        self.hits=1 #successful updates

    # add kalman state
        x, y = centroid
        # initialize new flies to have unknown velocity in kalman
        #self.x = np.array([[d[0]], [d[1]], [0.], [0.]])
        self.x = np.array([[x], [y], [0.0], [0.0]]) #state
        self.P = np.eye(4) * 100.0 # covariance

        self.state_label = "init" # initial state initialized 

        # store history for post-hoc metrics & visualization 
        self.history = {
            "meas": [], #detection assigned
            "pred": [], #prediction before update
            "post": [], #state after update
            "vel": [], #velocity magnitude
        }
        self.stationary_count=0

    @property
    def last_position(self): 
        return self.centroids[-1] # returns last position stored in centroid

# %%
# utility functions
def preprocess_and_crop(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    #gray =cv2.equalizeHist(gray)

    h, w = gray.shape 

    # Define ROI fractions (example: right half)
    x0 = int(ROI_X_MIN * w)
    y0 = int(ROI_Y_MIN * h)
    x1 = w
    y1 = h

    roi = gray[y0:y1, x0:x1]

    # force consistent minimum size
    if roi.shape[0] < 8 or roi.shape[1] < 8:
        raise ValueError(f"ROI too small: {roi.shape} from frame {gray.shape}")
    return roi, (x0, y0)

def detect_static_objects_fast(curr_gray, bg_model_fast, bg_model_slow, persist_map):

    # take diff compared to slow background so flies don't disappear
    diff_slow = cv2.absdiff(curr_gray, bg_model_slow)

    # pull out dark persistent objects
    static_mask = diff_slow < PERSIST_THRESH

    # accumulate persistence
    persist_map[static_mask] = np.minimum(persist_map[static_mask] +1, 255)
    persist_map[~static_mask]=0

    # binary persistence threshold
    stable = persist_map > PERSIST_FRAMES

    # cheap morphology thresholding
    stable = cv2.morphologyEx(stable.astype(np.uint8)*255, cv2.MORPH_OPEN, kernel3)

    num_labels, _, stats, centroids = cv2.connectedComponentsWithStats(stable)
    detections = []

    for i in range (1, num_labels): 
        area = stats[i, cv2.CC_STAT_AREA]
        if MIN_AREA <= area <= MAX_AREA: 
            detections.append(tuple(centroids[i].astype(int)))
    return detections
    


def detect_moving_objects_fast(prev_gray, curr_gray):
    diff = cv2.absdiff(curr_gray, prev_gray)
    diff = cv2.GaussianBlur(diff, (5,5), 0)
    _, thresh = cv2.threshold(diff, THRESH_VAL, 255, cv2.THRESH_BINARY)
    # reuse kernel3, do NOT create a new one
    thresh = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel3)

    num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh)
    detections = []
    for i in range(1, num_labels):
        area = stats[i, cv2.CC_STAT_AREA]
        if MIN_AREA <= area <= MAX_AREA:
            cx, cy = centroids[i]
            detections.append((int(cx), int(cy)))
    return detections, thresh

def track_position_for_matching(t):
    return (int(t.x[0,0]), int(t.x[1,0]))  # predicted (x,y)


def associate_detections_to_tracking_fast(detections, tracks, next_id):
    if not detections: 
        for t in tracks: 
            t.missed +=1 
        return [t for t in tracks if t.missed <= MAX_MISSED], next_id

    used = np.zeros(len(detections), dtype=bool)

    # match existing tracks using greedy algorithm 
    for t in tracks: 
        dists = np.linalg.norm(np.array(detections) - np.array(track_position_for_matching(t)), axis = 1)
        idx = np.argmin(dists)

        if dists[idx] < MAX_TRACK_DIST and not used[idx]: 
            z = detections[idx]
            kalman_update(t, z) 
            t.centroids.append(z)
            t.missed=0
            t.hits += 1
            update_track_state(t)
            used[idx] = True
        else: 
            t.missed += 1
            if t.missed > 0: 
                t.state_label = "lost"

    # generate new tracks ONLY for unmatched detections
    for i, d in enumerate (detections): 
        if not used[i]: 
            tracks.append(Track(next_id, d))
            next_id += 1

    # remove old tracks
    tracks = [t for t in tracks if t.missed <=MAX_MISSED]

    return tracks, next_id


def merge_detections(move_dets, static_dets, tracks, move_radius = 15, static_radius = 6):
    merged = list(move_dets)

    track_positions = np.array([t.last_position for t in tracks]) if tracks else np.empty((0,2))

    # static is confirmation, not discovery
    for sd in static_dets:
        if len(track_positions) == 0: 
            continue
        dists = np.linalg.norm(track_positions - np.array(sd), axis =1)

        # static deteections only confirm 
        if np.min(dists) < static_radius: 
            merged.append(sd)

    return merged

def deduplicate_tracks(tracks, radius=5): 
    # prevent same location collapse
    if len(tracks) <=1: 
        return tracks

    keep = []
    for t in tracks: 
        if not any(np.linalg.norm(
            np.array(t.last_position) - np.array(k.last_position)
        ) < radius for k in keep): 
            keep.append(t)
    return keep

# kalman predictions
def kalman_predict(track): 
    # F = state transition
    # Q = noise matrix
    track.history["pred"].append(track.x[:2].flatten()) # store predicted (x,y)
    track.x = F @ track.x
    track.P = F @ track.P @ F.T + Q

# update kalman if detection is assigned 
def kalman_update(track, z): 
    # H = measurement
    # R = noise matrix
    z = np.array(z).reshape(2,1)
    track.history["meas"].append(z.flatten()) # store detection
    
    y = z - H @ track.x
    S = H @ track.P @H.T + R
    K = track.P @ H.T @ np.linalg.inv(S)

    track.x = track.x + K @ y
    track.P = (np.eye(4) - K @ H) @ track.P

    track.history["post"].append(track.x[:2].flatten()) #store updated (x,y)
    track.history["vel"].append(np.linalg.norm(track.x[2:4])) #vx, vy magnitude

def update_track_state(t): 
    vx, vy = t.x[2,0], t.x[3,0]
    speed = np.hypot(vx, vy)

    if t.hits < INIT_FRAMES: #init state
        t.state_label = "init"
    elif speed < STATIONARY_VEL_THRESH: # stationary state
        t.stationary_count += 1
        if t.stationary_count >= STATIONARY_FRAMES: 
            t.state_label = "stationary"
        else:
            t.state_label = "tracked" # tracked states
    else: 
        t.stationary_count = 0
        t.state_label = "tracked" # TODO or tracked?

# %%
# MAIN PROCESSING LOOP

def process_video(): 
    print(f"beginning...\n") 
    capture = cv2.VideoCapture(VIDEO_PATH)
    assert capture.isOpened(), "Could not open video file"
    
    ret, frame = capture.read()
    if not ret: 
        raise RuntimeError("Failed to read first frame")
        
    prev_gray, roi_offset = preprocess_and_crop(frame)
    
    #initialize background model for static detection
    bg_model_fast = prev_gray.copy() 
    bg_model_slow = prev_gray.copy() #np.ones_like(prev_gray, dtype=np.uint8) * 255
    persist_map=np.zeros_like(prev_gray, dtype=np.uint8)
    
    # instantiate empty arrays for tracking and latency calculations
    tracks = [] #store tracking in array
    next_track_id = 0 
    #explicit multi-target capacity metrics
    latencies, det_counts, track_counts, frames, thresh_frames = [], [], [], [], []
       
        #frames = []
        #thresh_frames = []
    
    # precompute grids ONCE
    H, W = prev_gray.shape
    yy, xx = np.mgrid[0:H, 0:W]
    CIRCLE_RADIUS_SQ = CIRCLE_RADIUS ** 2
    
    frame_idx = 0
    
    #begin loop, occurs over duration of video
    while True: 
        ret, frame = capture.read()
        if not ret: 
            break
    
        start_frame = time.perf_counter() #records detection speed
    
         # Preprocess & crop
        start = time.perf_counter()
        curr_gray, _ = preprocess_and_crop(frame)
        t_preprocess = time.perf_counter() - start
    
        # Moving detection
        start = time.perf_counter()
        move_dets, thresh = detect_moving_objects_fast(prev_gray, curr_gray)
        t_move = time.perf_counter() - start
    
        # Static detection
        start = time.perf_counter()
        static_dets = detect_static_objects_fast(
            curr_gray, bg_model_fast, bg_model_slow, persist_map
        ) #previously used tracks
        t_static = time.perf_counter() - start

        # kalman predictions
        start = time.perf_counter()
        for t in tracks: 
            kalman_predict(t)
        t_kalman = time.perf_counter() - start
    
        # Merge detections + tracking
        start = time.perf_counter()
        detections = merge_detections(move_dets, static_dets, tracks)
        tracks, next_track_id = associate_detections_to_tracking_fast(
            detections, tracks, next_track_id
        )
        tracks = deduplicate_tracks(tracks) # one track per fly, protect stationary leak
        t_tracking = time.perf_counter() - start
    
        # Background update
        start_bg = time.perf_counter()

        # update slow background -- never mask 
        bg_model_slow = cv2.addWeighted(
                bg_model_slow, 1 - SLOW_ALPHA, 
                curr_gray, SLOW_ALPHA, 0)

        # update fast background (mask flies) 
        if len(tracks) == 0:
            # no flies --> full fast update
            bg_model_fast = cv2.addWeighted(
                bg_model_fast, 1 - BACKGROUND_ALPHA,
                curr_gray, BACKGROUND_ALPHA, 0
            )
            
        else:
            fly_mask = np.zeros_like(curr_gray, dtype=np.uint8)
        
            for t in tracks:
                x, y = t.last_position
        
                x0 = max(0, x - CIRCLE_RADIUS)
                y0 = max(0, y - CIRCLE_RADIUS)
                x1 = min(W, x + CIRCLE_RADIUS + 1)
                y1 = min(H, y + CIRCLE_RADIUS + 1)
        
                cm_x0 = x0 - (x - CIRCLE_RADIUS)
                cm_y0 = y0 - (y - CIRCLE_RADIUS)
                cm_x1 = cm_x0 + (x1 - x0)
                cm_y1 = cm_y0 + (y1 - y0)
        
                fly_mask[y0:y1, x0:x1] |= circle_mask[cm_y0:cm_y1, cm_x0:cm_x1]

            # compute blended background ONCE
            blended_fast = cv2.addWeighted(
                bg_model_fast, 1 - BACKGROUND_ALPHA,
                curr_gray, BACKGROUND_ALPHA, 0
            )
            #bg_model[fly_mask == 0] = cv2.addWeighted(
             #   bg_model[fly_mask == 0], 1 - BACKGROUND_ALPHA,
              #  curr_gray[fly_mask == 0], BACKGROUND_ALPHA, 0
            #)
            #update only non-fly pixels TODO is this fast or slow
            bg_model_fast[fly_mask == 0] = blended_fast[fly_mask == 0]
            
        
        t_bg = (time.perf_counter() - start_bg)
        
        # Visualization
        start = time.perf_counter()
        visual = cv2.cvtColor(curr_gray, cv2.COLOR_GRAY2BGR)
        cv2.rectangle(visual, (0,0), (visual.shape[1]-1, visual.shape[0]-1), (255,255,0), 1)
        for t in tracks:
            # draw centroid history 
            for i in range(1, len(t.centroids)): 
                cv2.line(visual, t.centroids[i-1], t.centroids[i], (0,255,0), 1)

            # draw Kalman post-state prediction (blue circles)
            pred_x, pred_y = t.history["post"][-1] if t.history["post"] else t.last_position
            cv2.circle(visual, (int(pred_x), int(pred_y)), 3, (255,0,0), -1) 

            # original detection circle
            cv2.circle(visual, t.last_position, 3, (0,0,255), -1)  # red = detection
            cv2.putText(visual, f"ID {t.id}", (t.last_position[0]+5, t.last_position[1]-5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,0,0), 1)

            #draw predicted vs measured as lines
            if t.history["meas"] and t.history["post"]: 
                meas_x, meas_y = t.history["meas"][-1]
                post_x, post_y = t.history["post"][-1] 
                cv2.line(visual, (int(meas_x), int(meas_y)), (int(post_x), int(post_y)), (0, 255, 255), 1)


            
            # measured 
            mx, my = t.last_position
            cv2.circle(visual, (mx, my), 3, (0,0,255), -1)

            # predicted 
            px, py = int(t.x[0,0]), int(t.x[1,0])
            cv2.circle(visual, (px,py), 5, (255, 0, 0), 1)

            # velocity arrow
            vx, vy = t.x[2,0], t.x[3,0]
            end = (int(px + 8*vx), int(py + 8*vy))
            cv2.arrowedLine(visual, (px, py), end, (0, 255, 255), 1, tipLength=0.3)
            
            # label
            # do NOT repeat n times (moved outside loop)
            #cv2.circle(visual, t.last_position, 3, (0,0,255), -1)
            label = f"ID {t.id} | {t.state_label}"
            cv2.putText(
                visual, label, 
                (px+6, py-6), 
                cv2.FONT_HERSHEY_SIMPLEX, 
                0.4, (255,255,255), 1
            )
            if frame_idx % 10 == 0:
                frames.append(visual.copy())
                thresh_frames.append(thresh.copy())
        t_vis = time.perf_counter() - start
    
        # Metrics
        total_frame = (time.perf_counter() - start_frame) * 1000.0
        print(f"Frame {frame_idx}: preprocess={t_preprocess*1000:.1f}ms, "
              f"move={t_move*1000:.1f}ms, static={t_static*1000:.1f}ms, "
              f"kalman={t_kalman*1000:.1f}ms",
              f"tracking={t_tracking*1000:.1f}ms, bg={t_bg*1000:.1f}ms, "
              f"vis={t_vis*1000:.1f}ms, total={total_frame:.1f}ms")
        total_frame_no_vis = (t_preprocess + t_move + t_static + t_kalman + t_tracking + t_bg) * 1000.0

        latencies.append(total_frame_no_vis)
        det_counts.append(len(detections))
        track_counts.append(len(tracks))

    
        prev_gray = curr_gray
        frame_idx += 1
    

    capture.release()
    print ("Done processing.")
    return latencies, det_counts, track_counts, frames, thresh_frames

# %%
import cProfile
import pstats

#cProfile.run('process_video()', 'profile_results')
#p = pstats.Stats('profile_results')
#p.strip_dirs().sort_stats('cumtime').print_stats(50)

latencies, det_counts, track_counts, frames, thresh_frames = process_video()
# Out:
# beginning...
#
# Frame 0: preprocess=3.4ms, move=16.4ms, static=30.6ms, kalman=0.0ms tracking=0.1ms, bg=4.5ms, vis=1.7ms, total=56.7ms
# Frame 1: preprocess=2.5ms, move=12.5ms, static=30.6ms, kalman=0.0ms tracking=0.3ms, bg=12.4ms, vis=2.1ms, total=60.4ms
# Frame 2: preprocess=1.6ms, move=12.7ms, static=29.2ms, kalman=0.2ms tracking=1.4ms, bg=12.4ms, vis=2.9ms, total=60.3ms
# Frame 3: preprocess=2.2ms, move=13.2ms, static=30.4ms, kalman=0.3ms tracking=1.4ms, bg=13.0ms, vis=3.1ms, total=63.5ms
# Frame 4: preprocess=1.8ms, move=13.8ms, static=30.6ms, kalman=0.3ms tracking=1.3ms, bg=13.9ms, vis=2.5ms, total=64.3ms
# Frame 5: preprocess=1.5ms, move=12.3ms, static=29.7ms, kalman=0.3ms tracking=1.4ms, bg=13.5ms, vis=2.7ms, total=61.4ms
# Frame 6: preprocess=2.4ms, move=12.1ms, static=29.4ms, kalman=0.2ms tracking=1.3ms, bg=13.7ms, vis=2.1ms, total=61.3ms
# Frame 7: preprocess=2.4ms, move=12.5ms, static=29.9ms, kalman=0.3ms tracking=1.1ms, bg=11.6ms, vis=2.3ms, total=60.2ms
# Frame 8: preprocess=2.0ms, move=12.5ms, static=30.7ms, kalman=0.3ms tracking=1.3ms, bg=13.0ms, vis=3.0ms, total=62.9ms
# Frame 9: preprocess=2.5ms, move=12.1ms, static=30.8ms, kalman=0.3ms tracking=1.3ms, bg=13.7ms, vis=3.0ms, total=63.8ms
# Frame 10: preprocess=2.1ms, move=13.6ms, static=27.1ms, kalman=0.2ms tracking=0.2ms, bg=13.6ms, vis=13.1ms, total=69.9ms
# Frame 11: preprocess=1.9ms, move=14.2ms, static=30.2ms, kalman=0.3ms tracking=0.2ms, bg=13.8ms, vis=3.2ms, total=63.9ms
# Frame 12: preprocess=2.0ms, move=12.5ms, static=28.1ms, kalman=0.3ms tracking=0.2ms, bg=13.0ms, vis=3.0ms, total=59.0ms
# Frame 13: preprocess=2.4ms, move=12.5ms, static=27.5ms, kalman=0.3ms tracking=0.2ms, bg=13.9ms, vis=2.5ms, total=59.3ms
# Frame 14: preprocess=2.0ms, move=13.3ms, static=29.2ms, kalman=0.2ms tracking=0.2ms, bg=13.8ms, vis=2.7ms, total=61.4ms
# Frame 15: preprocess=1.9ms, move=12.6ms, static=30.1ms, kalman=0.2ms tracking=0.2ms, bg=13.4ms, vis=2.9ms, total=61.3ms
# Frame 16: preprocess=2.2ms, move=13.3ms, static=28.7ms, kalman=0.2ms tracking=0.2ms, bg=12.3ms, vis=3.1ms, total=60.0ms
# Frame 17: preprocess=2.6ms, move=12.9ms, static=29.1ms, kalman=0.2ms tracking=0.2ms, bg=13.6ms, vis=3.1ms, total=61.7ms
# Frame 18: preprocess=2.4ms, move=12.5ms, static=32.3ms, kalman=0.2ms tracking=0.1ms, bg=13.0ms, vis=2.4ms, total=62.9ms
# Frame 19: preprocess=2.6ms, move=12.5ms, static=30.7ms, kalman=0.2ms tracking=0.1ms, bg=15.2ms, vis=2.8ms, total=64.1ms
# Frame 20: preprocess=2.0ms, move=12.7ms, static=31.7ms, kalman=0.2ms tracking=0.1ms, bg=4.5ms, vis=2.7ms, total=53.8ms
# Frame 21: preprocess=2.2ms, move=12.8ms, static=33.5ms, kalman=0.0ms tracking=0.1ms, bg=7.4ms, vis=2.3ms, total=58.4ms
# Frame 22: preprocess=2.1ms, move=12.7ms, static=32.7ms, kalman=0.0ms tracking=0.0ms, bg=4.1ms, vis=2.6ms, total=54.2ms
# Frame 23: preprocess=2.2ms, move=11.9ms, static=32.4ms, kalman=0.0ms tracking=0.0ms, bg=4.5ms, vis=2.5ms, total=53.6ms
# Frame 24: preprocess=3.1ms, move=13.1ms, static=33.4ms, kalman=0.0ms tracking=0.0ms, bg=4.6ms, vis=2.7ms, total=57.0ms
# Frame 25: preprocess=2.0ms, move=14.3ms, static=29.6ms, kalman=0.0ms tracking=0.0ms, bg=3.3ms, vis=2.7ms, total=51.9ms
# Frame 26: preprocess=1.9ms, move=12.9ms, static=32.6ms, kalman=0.0ms tracking=0.2ms, bg=13.6ms, vis=2.8ms, total=64.0ms
# Frame 27: preprocess=2.3ms, move=12.4ms, static=32.0ms, kalman=0.2ms tracking=1.2ms, bg=13.3ms, vis=3.0ms, total=64.4ms
# Frame 28: preprocess=2.3ms, move=13.2ms, static=32.5ms, kalman=0.2ms tracking=1.3ms, bg=13.3ms, vis=3.1ms, total=65.9ms
# Frame 29: preprocess=2.3ms, move=13.4ms, static=30.2ms, kalman=0.2ms tracking=1.3ms, bg=14.3ms, vis=3.0ms, total=64.8ms
# Frame 30: preprocess=2.7ms, move=13.3ms, static=32.4ms, kalman=0.2ms tracking=1.1ms, bg=13.2ms, vis=5.8ms, total=68.7ms
# Frame 31: preprocess=2.7ms, move=14.6ms, static=31.6ms, kalman=0.2ms tracking=1.0ms, bg=13.4ms, vis=3.1ms, total=66.7ms
# Frame 32: preprocess=1.9ms, move=12.7ms, static=33.5ms, kalman=0.2ms tracking=1.0ms, bg=12.7ms, vis=2.7ms, total=64.7ms
# Frame 33: preprocess=1.8ms, move=14.0ms, static=36.4ms, kalman=0.2ms tracking=1.0ms, bg=14.4ms, vis=3.4ms, total=71.3ms
# Frame 34: preprocess=2.1ms, move=16.5ms, static=33.6ms, kalman=0.2ms tracking=0.0ms, bg=13.7ms, vis=3.5ms, total=69.7ms
# Frame 35: preprocess=4.0ms, move=15.9ms, static=36.2ms, kalman=0.2ms tracking=0.1ms, bg=14.3ms, vis=2.6ms, total=73.4ms
# Frame 36: preprocess=2.3ms, move=15.3ms, static=33.8ms, kalman=0.2ms tracking=0.0ms, bg=13.7ms, vis=2.8ms, total=68.1ms
# Frame 37: preprocess=2.6ms, move=17.1ms, static=36.1ms, kalman=0.2ms tracking=0.1ms, bg=14.2ms, vis=3.0ms, total=73.3ms
# Frame 38: preprocess=2.2ms, move=12.2ms, static=32.5ms, kalman=0.2ms tracking=0.1ms, bg=14.0ms, vis=2.8ms, total=64.0ms
# Frame 39: preprocess=2.7ms, move=13.7ms, static=37.5ms, kalman=0.2ms tracking=0.0ms, bg=13.5ms, vis=2.8ms, total=70.3ms
# Frame 40: preprocess=1.7ms, move=13.1ms, static=27.3ms, kalman=0.1ms tracking=0.0ms, bg=13.5ms, vis=6.3ms, total=62.0ms
# Frame 41: preprocess=2.7ms, move=13.7ms, static=32.5ms, kalman=0.2ms tracking=0.0ms, bg=14.1ms, vis=3.1ms, total=66.3ms
# Frame 42: preprocess=2.7ms, move=12.5ms, static=32.2ms, kalman=0.2ms tracking=0.0ms, bg=13.9ms, vis=2.7ms, total=64.2ms
# Frame 43: preprocess=2.2ms, move=13.0ms, static=31.7ms, kalman=0.2ms tracking=0.0ms, bg=11.1ms, vis=2.6ms, total=60.9ms
# Frame 44: preprocess=2.6ms, move=12.5ms, static=31.8ms, kalman=0.2ms tracking=0.0ms, bg=4.5ms, vis=2.7ms, total=54.3ms
# Frame 45: preprocess=1.7ms, move=12.7ms, static=30.8ms, kalman=0.0ms tracking=0.1ms, bg=4.1ms, vis=2.4ms, total=51.8ms
# Frame 46: preprocess=2.1ms, move=13.4ms, static=35.2ms, kalman=0.0ms tracking=0.1ms, bg=4.7ms, vis=3.2ms, total=58.7ms
# Frame 47: preprocess=2.1ms, move=12.4ms, static=34.7ms, kalman=0.0ms tracking=0.0ms, bg=5.1ms, vis=3.0ms, total=57.3ms
# Frame 48: preprocess=2.0ms, move=14.1ms, static=31.8ms, kalman=0.0ms tracking=0.0ms, bg=11.5ms, vis=1.8ms, total=61.2ms
# Frame 49: preprocess=3.3ms, move=18.8ms, static=36.2ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=2.8ms, total=66.9ms
# Frame 50: preprocess=1.7ms, move=12.1ms, static=33.5ms, kalman=0.0ms tracking=0.0ms, bg=4.8ms, vis=2.1ms, total=54.3ms
# Frame 51: preprocess=2.5ms, move=13.4ms, static=32.3ms, kalman=0.0ms tracking=0.0ms, bg=4.7ms, vis=2.7ms, total=55.6ms
# Frame 52: preprocess=1.9ms, move=12.9ms, static=32.3ms, kalman=0.0ms tracking=0.0ms, bg=4.6ms, vis=2.1ms, total=54.0ms
# Frame 53: preprocess=1.4ms, move=11.2ms, static=32.4ms, kalman=0.0ms tracking=0.0ms, bg=4.6ms, vis=2.5ms, total=52.2ms
# Frame 54: preprocess=2.4ms, move=13.8ms, static=32.9ms, kalman=0.0ms tracking=0.0ms, bg=4.7ms, vis=2.4ms, total=56.3ms
# Frame 55: preprocess=2.7ms, move=13.9ms, static=46.0ms, kalman=0.0ms tracking=0.0ms, bg=3.8ms, vis=2.6ms, total=69.1ms
# Frame 56: preprocess=2.8ms, move=11.9ms, static=32.2ms, kalman=0.0ms tracking=0.0ms, bg=4.6ms, vis=2.6ms, total=54.2ms
# Frame 57: preprocess=1.8ms, move=13.5ms, static=32.5ms, kalman=0.0ms tracking=0.0ms, bg=4.6ms, vis=3.3ms, total=55.8ms
# Frame 58: preprocess=2.2ms, move=14.1ms, static=34.0ms, kalman=0.0ms tracking=0.0ms, bg=4.4ms, vis=2.3ms, total=57.2ms
# Frame 59: preprocess=2.3ms, move=14.1ms, static=33.3ms, kalman=0.0ms tracking=0.0ms, bg=4.5ms, vis=2.9ms, total=57.1ms
# Frame 60: preprocess=3.2ms, move=12.9ms, static=32.9ms, kalman=0.0ms tracking=0.0ms, bg=4.7ms, vis=2.7ms, total=56.5ms
# Frame 61: preprocess=2.3ms, move=11.7ms, static=30.8ms, kalman=0.0ms tracking=0.0ms, bg=4.7ms, vis=2.4ms, total=51.9ms
# Frame 62: preprocess=1.7ms, move=14.9ms, static=33.9ms, kalman=0.0ms tracking=0.0ms, bg=4.7ms, vis=2.8ms, total=58.1ms
# Frame 63: preprocess=2.5ms, move=14.2ms, static=33.2ms, kalman=0.0ms tracking=0.0ms, bg=4.7ms, vis=3.0ms, total=57.7ms
# Frame 64: preprocess=3.6ms, move=13.6ms, static=32.0ms, kalman=0.0ms tracking=0.0ms, bg=4.2ms, vis=2.6ms, total=56.1ms
# Frame 65: preprocess=1.5ms, move=13.2ms, static=32.6ms, kalman=0.0ms tracking=0.0ms, bg=4.5ms, vis=2.1ms, total=54.0ms
# Frame 66: preprocess=2.6ms, move=13.4ms, static=32.8ms, kalman=0.0ms tracking=0.0ms, bg=4.6ms, vis=2.9ms, total=56.2ms
# Frame 67: preprocess=1.9ms, move=13.1ms, static=34.1ms, kalman=0.0ms tracking=0.1ms, bg=3.9ms, vis=2.5ms, total=55.6ms
# Frame 68: preprocess=2.0ms, move=13.0ms, static=32.3ms, kalman=0.0ms tracking=0.0ms, bg=4.5ms, vis=2.7ms, total=54.7ms
# Frame 69: preprocess=2.0ms, move=15.4ms, static=34.8ms, kalman=0.0ms tracking=0.0ms, bg=3.7ms, vis=2.3ms, total=58.2ms
# Frame 70: preprocess=1.4ms, move=13.4ms, static=34.9ms, kalman=0.0ms tracking=0.0ms, bg=3.5ms, vis=1.7ms, total=54.9ms
# Frame 71: preprocess=2.5ms, move=13.0ms, static=33.2ms, kalman=0.0ms tracking=0.0ms, bg=4.0ms, vis=2.8ms, total=55.7ms
# Frame 72: preprocess=3.1ms, move=14.6ms, static=32.1ms, kalman=0.0ms tracking=0.0ms, bg=4.7ms, vis=3.3ms, total=57.9ms
# Frame 73: preprocess=2.1ms, move=13.6ms, static=32.0ms, kalman=0.0ms tracking=0.0ms, bg=4.0ms, vis=2.4ms, total=54.2ms
# Frame 74: preprocess=1.8ms, move=12.7ms, static=32.8ms, kalman=0.0ms tracking=0.0ms, bg=4.7ms, vis=2.6ms, total=54.6ms
# Frame 75: preprocess=2.0ms, move=13.0ms, static=33.2ms, kalman=0.0ms tracking=0.0ms, bg=4.8ms, vis=2.1ms, total=55.0ms
# Frame 76: preprocess=2.3ms, move=13.6ms, static=33.8ms, kalman=0.0ms tracking=0.0ms, bg=4.4ms, vis=2.3ms, total=56.4ms
# Frame 77: preprocess=3.5ms, move=14.1ms, static=33.3ms, kalman=0.0ms tracking=0.1ms, bg=4.1ms, vis=2.5ms, total=57.6ms
# Frame 78: preprocess=2.0ms, move=13.6ms, static=31.7ms, kalman=0.0ms tracking=0.0ms, bg=4.5ms, vis=2.7ms, total=54.5ms
# Frame 79: preprocess=1.9ms, move=12.9ms, static=31.2ms, kalman=0.0ms tracking=0.0ms, bg=4.0ms, vis=2.6ms, total=52.7ms
# Frame 80: preprocess=1.9ms, move=11.1ms, static=30.9ms, kalman=0.0ms tracking=0.0ms, bg=4.6ms, vis=2.7ms, total=51.3ms
# Frame 81: preprocess=2.0ms, move=13.1ms, static=34.4ms, kalman=0.0ms tracking=0.0ms, bg=4.5ms, vis=2.8ms, total=56.9ms
# Frame 82: preprocess=2.3ms, move=15.0ms, static=33.3ms, kalman=0.0ms tracking=0.0ms, bg=4.3ms, vis=2.3ms, total=57.2ms
# Frame 83: preprocess=2.3ms, move=12.5ms, static=30.9ms, kalman=0.0ms tracking=0.0ms, bg=4.6ms, vis=2.6ms, total=53.0ms
# Frame 84: preprocess=1.8ms, move=11.9ms, static=30.6ms, kalman=0.0ms tracking=0.0ms, bg=4.9ms, vis=3.2ms, total=52.5ms
# Frame 85: preprocess=2.7ms, move=14.0ms, static=31.9ms, kalman=0.0ms tracking=0.0ms, bg=4.7ms, vis=2.6ms, total=55.9ms
# Frame 86: preprocess=2.5ms, move=12.9ms, static=34.4ms, kalman=0.0ms tracking=0.0ms, bg=4.2ms, vis=2.3ms, total=56.5ms
# Frame 87: preprocess=2.3ms, move=11.4ms, static=35.5ms, kalman=0.0ms tracking=0.0ms, bg=4.6ms, vis=2.5ms, total=56.4ms
# Frame 88: preprocess=1.7ms, move=13.0ms, static=37.8ms, kalman=0.0ms tracking=0.0ms, bg=3.3ms, vis=2.5ms, total=58.3ms
# Frame 89: preprocess=2.0ms, move=13.1ms, static=40.3ms, kalman=0.0ms tracking=0.1ms, bg=4.2ms, vis=2.5ms, total=62.3ms
# Frame 90: preprocess=2.1ms, move=14.2ms, static=46.4ms, kalman=0.0ms tracking=0.2ms, bg=13.9ms, vis=6.6ms, total=83.6ms
# Frame 91: preprocess=2.4ms, move=13.7ms, static=46.1ms, kalman=0.2ms tracking=31.1ms, bg=13.5ms, vis=2.4ms, total=109.3ms
# Frame 92: preprocess=2.7ms, move=13.8ms, static=64.6ms, kalman=0.2ms tracking=81.0ms, bg=14.8ms, vis=2.9ms, total=180.2ms
# Frame 93: preprocess=1.8ms, move=13.1ms, static=81.2ms, kalman=0.2ms tracking=181.4ms, bg=16.3ms, vis=2.7ms, total=296.7ms
# Frame 94: preprocess=2.0ms, move=14.3ms, static=113.3ms, kalman=0.3ms tracking=312.1ms, bg=14.0ms, vis=2.4ms, total=458.4ms
# Frame 95: preprocess=3.0ms, move=14.2ms, static=137.6ms, kalman=0.2ms tracking=413.9ms, bg=14.0ms, vis=3.0ms, total=585.9ms
# Frame 96: preprocess=2.2ms, move=12.9ms, static=143.3ms, kalman=0.2ms tracking=482.9ms, bg=14.9ms, vis=2.8ms, total=659.1ms
# Frame 97: preprocess=3.8ms, move=17.8ms, static=159.2ms, kalman=0.2ms tracking=462.6ms, bg=13.8ms, vis=2.6ms, total=660.0ms
# Frame 98: preprocess=1.9ms, move=12.9ms, static=132.2ms, kalman=0.2ms tracking=417.2ms, bg=13.6ms, vis=3.4ms, total=581.4ms
# Frame 99: preprocess=2.7ms, move=12.9ms, static=130.7ms, kalman=0.2ms tracking=420.7ms, bg=13.8ms, vis=3.3ms, total=584.2ms
# Frame 100: preprocess=2.7ms, move=13.8ms, static=138.1ms, kalman=0.2ms tracking=384.9ms, bg=14.1ms, vis=9.4ms, total=563.1ms
# Frame 101: preprocess=2.0ms, move=13.7ms, static=127.0ms, kalman=0.2ms tracking=385.6ms, bg=14.9ms, vis=3.2ms, total=546.8ms
# Frame 102: preprocess=2.2ms, move=14.1ms, static=126.1ms, kalman=0.3ms tracking=385.7ms, bg=13.3ms, vis=3.3ms, total=545.1ms
# Frame 103: preprocess=2.3ms, move=13.0ms, static=114.2ms, kalman=0.2ms tracking=374.5ms, bg=13.9ms, vis=3.2ms, total=521.3ms
# Frame 104: preprocess=2.4ms, move=12.7ms, static=110.5ms, kalman=0.2ms tracking=364.4ms, bg=13.4ms, vis=3.3ms, total=506.8ms
# Frame 105: preprocess=1.8ms, move=13.2ms, static=110.1ms, kalman=0.2ms tracking=367.4ms, bg=13.9ms, vis=3.7ms, total=510.2ms
# Frame 106: preprocess=3.0ms, move=14.8ms, static=112.1ms, kalman=0.2ms tracking=329.9ms, bg=13.4ms, vis=2.8ms, total=476.2ms
# Frame 107: preprocess=1.9ms, move=12.7ms, static=102.0ms, kalman=0.2ms tracking=349.8ms, bg=13.8ms, vis=3.3ms, total=483.8ms
# Frame 108: preprocess=2.2ms, move=11.5ms, static=96.6ms, kalman=0.2ms tracking=339.9ms, bg=14.4ms, vis=3.1ms, total=467.8ms
# Frame 109: preprocess=2.3ms, move=13.3ms, static=102.7ms, kalman=0.2ms tracking=330.2ms, bg=15.1ms, vis=3.1ms, total=466.9ms
# Frame 110: preprocess=1.3ms, move=13.0ms, static=102.2ms, kalman=0.2ms tracking=343.6ms, bg=13.8ms, vis=5.8ms, total=480.0ms
# Frame 111: preprocess=1.9ms, move=13.2ms, static=100.4ms, kalman=0.2ms tracking=335.4ms, bg=14.3ms, vis=2.7ms, total=468.1ms
# Frame 112: preprocess=1.7ms, move=13.2ms, static=101.4ms, kalman=0.2ms tracking=376.0ms, bg=26.6ms, vis=6.1ms, total=525.3ms
# Frame 113: preprocess=6.4ms, move=16.6ms, static=103.5ms, kalman=0.2ms tracking=365.0ms, bg=13.3ms, vis=3.0ms, total=508.1ms
# Frame 114: preprocess=2.3ms, move=12.8ms, static=99.6ms, kalman=0.3ms tracking=350.7ms, bg=14.1ms, vis=3.6ms, total=483.3ms
# Frame 115: preprocess=2.2ms, move=13.8ms, static=102.3ms, kalman=0.3ms tracking=368.9ms, bg=13.4ms, vis=3.4ms, total=504.4ms
# Frame 116: preprocess=3.2ms, move=12.7ms, static=103.4ms, kalman=0.3ms tracking=384.3ms, bg=14.4ms, vis=3.7ms, total=521.9ms
# Frame 117: preprocess=2.3ms, move=14.2ms, static=107.5ms, kalman=0.3ms tracking=432.4ms, bg=14.6ms, vis=3.1ms, total=574.4ms
# Frame 118: preprocess=2.1ms, move=12.7ms, static=103.1ms, kalman=0.4ms tracking=406.7ms, bg=14.7ms, vis=3.8ms, total=543.4ms
# Frame 119: preprocess=2.7ms, move=12.7ms, static=101.2ms, kalman=0.4ms tracking=352.8ms, bg=14.7ms, vis=3.7ms, total=488.1ms
# Frame 120: preprocess=2.2ms, move=13.0ms, static=93.4ms, kalman=0.5ms tracking=300.5ms, bg=14.7ms, vis=78.1ms, total=502.4ms
# Frame 121: preprocess=2.5ms, move=15.4ms, static=87.9ms, kalman=0.5ms tracking=228.0ms, bg=15.3ms, vis=3.9ms, total=353.5ms
# Frame 122: preprocess=2.5ms, move=16.3ms, static=74.8ms, kalman=0.6ms tracking=175.9ms, bg=16.3ms, vis=4.5ms, total=290.8ms
# Frame 123: preprocess=2.5ms, move=17.9ms, static=64.5ms, kalman=0.6ms tracking=116.5ms, bg=16.9ms, vis=4.3ms, total=223.2ms
# Frame 124: preprocess=2.5ms, move=17.2ms, static=54.6ms, kalman=0.5ms tracking=67.2ms, bg=16.2ms, vis=4.1ms, total=162.3ms
# Frame 125: preprocess=2.8ms, move=16.7ms, static=49.7ms, kalman=0.5ms tracking=34.9ms, bg=17.7ms, vis=4.1ms, total=126.5ms
# Frame 126: preprocess=2.7ms, move=16.5ms, static=47.1ms, kalman=0.7ms tracking=18.8ms, bg=17.8ms, vis=5.1ms, total=108.6ms
# Frame 127: preprocess=2.7ms, move=16.3ms, static=48.7ms, kalman=0.5ms tracking=10.1ms, bg=17.7ms, vis=4.5ms, total=100.4ms
# Frame 128: preprocess=2.9ms, move=17.2ms, static=44.8ms, kalman=0.4ms tracking=5.2ms, bg=17.2ms, vis=3.9ms, total=91.6ms
# Frame 129: preprocess=2.9ms, move=16.7ms, static=46.7ms, kalman=0.4ms tracking=4.1ms, bg=17.1ms, vis=4.4ms, total=92.2ms
# Frame 130: preprocess=3.4ms, move=17.2ms, static=51.7ms, kalman=0.3ms tracking=3.7ms, bg=18.6ms, vis=28.8ms, total=123.8ms
# Frame 131: preprocess=4.0ms, move=20.5ms, static=54.2ms, kalman=1.2ms tracking=3.9ms, bg=17.7ms, vis=4.7ms, total=106.2ms
# Frame 132: preprocess=3.2ms, move=18.8ms, static=44.4ms, kalman=0.3ms tracking=2.7ms, bg=17.8ms, vis=3.6ms, total=90.8ms
# Frame 133: preprocess=3.6ms, move=19.3ms, static=45.6ms, kalman=0.2ms tracking=1.7ms, bg=17.3ms, vis=4.4ms, total=92.0ms
# Frame 134: preprocess=2.6ms, move=17.0ms, static=46.0ms, kalman=0.2ms tracking=1.6ms, bg=5.8ms, vis=3.3ms, total=76.7ms
# Frame 135: preprocess=3.7ms, move=15.6ms, static=43.9ms, kalman=0.0ms tracking=0.2ms, bg=18.2ms, vis=4.0ms, total=85.6ms
# Frame 136: preprocess=2.3ms, move=17.1ms, static=45.5ms, kalman=0.2ms tracking=2.2ms, bg=17.5ms, vis=4.1ms, total=89.0ms
# Frame 137: preprocess=2.7ms, move=16.8ms, static=44.3ms, kalman=0.2ms tracking=2.4ms, bg=17.5ms, vis=3.6ms, total=87.4ms
# Frame 138: preprocess=2.6ms, move=16.7ms, static=42.7ms, kalman=0.3ms tracking=2.9ms, bg=16.7ms, vis=3.7ms, total=85.7ms
# Frame 139: preprocess=1.9ms, move=15.5ms, static=45.6ms, kalman=0.3ms tracking=2.5ms, bg=17.3ms, vis=4.0ms, total=87.2ms
# Frame 140: preprocess=2.4ms, move=15.6ms, static=41.1ms, kalman=0.3ms tracking=2.1ms, bg=17.5ms, vis=22.4ms, total=101.5ms
# Frame 141: preprocess=2.8ms, move=17.2ms, static=41.8ms, kalman=0.4ms tracking=2.5ms, bg=17.2ms, vis=4.3ms, total=86.3ms
# Frame 142: preprocess=2.4ms, move=14.8ms, static=41.4ms, kalman=0.3ms tracking=1.9ms, bg=17.3ms, vis=3.6ms, total=81.6ms
# Frame 143: preprocess=2.0ms, move=14.3ms, static=40.1ms, kalman=0.3ms tracking=1.8ms, bg=18.4ms, vis=4.1ms, total=81.0ms
# Frame 144: preprocess=2.0ms, move=14.6ms, static=42.3ms, kalman=0.3ms tracking=1.9ms, bg=16.3ms, vis=4.3ms, total=81.9ms
# Frame 145: preprocess=2.4ms, move=17.1ms, static=42.3ms, kalman=1.1ms tracking=2.3ms, bg=14.9ms, vis=4.4ms, total=84.5ms
# Frame 146: preprocess=3.2ms, move=16.1ms, static=40.8ms, kalman=0.3ms tracking=2.2ms, bg=14.7ms, vis=3.3ms, total=80.8ms
# Frame 147: preprocess=1.8ms, move=15.7ms, static=40.8ms, kalman=0.3ms tracking=2.0ms, bg=15.5ms, vis=3.4ms, total=79.5ms
# Frame 148: preprocess=2.3ms, move=16.3ms, static=40.6ms, kalman=0.3ms tracking=1.6ms, bg=16.0ms, vis=3.9ms, total=81.1ms
# Frame 149: preprocess=2.8ms, move=15.9ms, static=39.4ms, kalman=0.3ms tracking=1.6ms, bg=16.3ms, vis=3.3ms, total=79.6ms
# Frame 150: preprocess=2.6ms, move=17.7ms, static=42.7ms, kalman=0.2ms tracking=1.8ms, bg=16.3ms, vis=21.3ms, total=102.7ms
# Frame 151: preprocess=2.8ms, move=16.2ms, static=43.4ms, kalman=0.2ms tracking=1.6ms, bg=18.4ms, vis=4.1ms, total=86.7ms
# Frame 152: preprocess=2.7ms, move=16.7ms, static=41.6ms, kalman=0.3ms tracking=1.6ms, bg=16.7ms, vis=4.4ms, total=84.0ms
# Frame 153: preprocess=2.8ms, move=20.7ms, static=44.5ms, kalman=0.3ms tracking=1.4ms, bg=17.0ms, vis=3.8ms, total=90.4ms
# Frame 154: preprocess=3.5ms, move=19.5ms, static=44.5ms, kalman=0.2ms tracking=1.4ms, bg=17.9ms, vis=4.8ms, total=91.9ms
# Frame 155: preprocess=2.5ms, move=17.6ms, static=40.8ms, kalman=0.2ms tracking=1.3ms, bg=17.9ms, vis=4.2ms, total=84.6ms
# Frame 156: preprocess=3.9ms, move=18.0ms, static=41.0ms, kalman=0.2ms tracking=1.3ms, bg=17.0ms, vis=4.1ms, total=85.6ms
# Frame 157: preprocess=2.4ms, move=16.3ms, static=41.0ms, kalman=0.2ms tracking=1.0ms, bg=16.8ms, vis=4.5ms, total=82.4ms
# Frame 158: preprocess=3.1ms, move=16.2ms, static=41.5ms, kalman=0.2ms tracking=0.7ms, bg=17.1ms, vis=4.1ms, total=82.9ms
# Frame 159: preprocess=2.7ms, move=16.4ms, static=42.0ms, kalman=0.3ms tracking=1.1ms, bg=19.0ms, vis=4.1ms, total=85.7ms
# Frame 160: preprocess=2.8ms, move=17.2ms, static=40.4ms, kalman=0.2ms tracking=0.5ms, bg=16.5ms, vis=21.7ms, total=99.2ms
# Frame 161: preprocess=2.6ms, move=16.1ms, static=42.2ms, kalman=0.3ms tracking=0.5ms, bg=17.6ms, vis=4.3ms, total=83.6ms
# Frame 162: preprocess=2.6ms, move=16.3ms, static=40.3ms, kalman=0.3ms tracking=0.8ms, bg=16.6ms, vis=4.0ms, total=80.9ms
# Frame 163: preprocess=2.6ms, move=14.5ms, static=42.4ms, kalman=0.4ms tracking=1.0ms, bg=17.6ms, vis=4.3ms, total=82.7ms
# Frame 164: preprocess=2.6ms, move=17.0ms, static=39.8ms, kalman=0.3ms tracking=0.4ms, bg=17.5ms, vis=4.7ms, total=82.1ms
# Frame 165: preprocess=2.4ms, move=18.7ms, static=42.3ms, kalman=0.4ms tracking=0.9ms, bg=17.0ms, vis=4.4ms, total=86.1ms
# Frame 166: preprocess=2.8ms, move=16.8ms, static=41.2ms, kalman=0.3ms tracking=1.5ms, bg=17.6ms, vis=4.0ms, total=84.2ms
# Frame 167: preprocess=2.5ms, move=16.4ms, static=40.5ms, kalman=0.3ms tracking=1.4ms, bg=18.5ms, vis=4.3ms, total=83.8ms
# Frame 168: preprocess=3.0ms, move=17.9ms, static=39.7ms, kalman=0.3ms tracking=1.0ms, bg=17.1ms, vis=4.0ms, total=83.0ms
# Frame 169: preprocess=3.5ms, move=17.5ms, static=41.9ms, kalman=0.2ms tracking=0.4ms, bg=16.6ms, vis=4.0ms, total=84.2ms
# Frame 170: preprocess=2.6ms, move=16.4ms, static=41.4ms, kalman=0.3ms tracking=0.3ms, bg=17.0ms, vis=14.5ms, total=92.5ms
# Frame 171: preprocess=2.9ms, move=16.3ms, static=42.0ms, kalman=0.2ms tracking=0.3ms, bg=17.1ms, vis=4.3ms, total=83.2ms
# Frame 172: preprocess=2.4ms, move=15.7ms, static=40.8ms, kalman=0.2ms tracking=0.4ms, bg=17.1ms, vis=4.4ms, total=81.1ms
# Frame 173: preprocess=2.0ms, move=15.4ms, static=41.7ms, kalman=0.2ms tracking=0.4ms, bg=17.6ms, vis=4.0ms, total=81.3ms
# Frame 174: preprocess=2.4ms, move=18.4ms, static=41.9ms, kalman=0.2ms tracking=0.3ms, bg=17.4ms, vis=3.7ms, total=84.5ms
# Frame 175: preprocess=3.3ms, move=16.5ms, static=42.2ms, kalman=0.2ms tracking=0.3ms, bg=17.2ms, vis=4.6ms, total=84.4ms
# Frame 176: preprocess=2.5ms, move=17.9ms, static=43.3ms, kalman=0.2ms tracking=0.3ms, bg=17.0ms, vis=3.4ms, total=84.6ms
# Frame 177: preprocess=2.1ms, move=16.6ms, static=41.5ms, kalman=0.2ms tracking=0.2ms, bg=18.5ms, vis=3.5ms, total=82.5ms
# Frame 178: preprocess=2.8ms, move=17.2ms, static=41.1ms, kalman=0.2ms tracking=0.3ms, bg=16.9ms, vis=3.6ms, total=82.0ms
# Frame 179: preprocess=2.6ms, move=16.6ms, static=41.2ms, kalman=0.2ms tracking=0.0ms, bg=6.0ms, vis=3.7ms, total=70.4ms
# Frame 180: preprocess=2.6ms, move=17.8ms, static=40.6ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.8ms, total=70.6ms
# Frame 181: preprocess=2.6ms, move=15.7ms, static=41.2ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.4ms, total=68.7ms
# Frame 182: preprocess=3.1ms, move=17.3ms, static=42.1ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.6ms, total=72.0ms
# Frame 183: preprocess=2.6ms, move=15.9ms, static=37.9ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.2ms, total=65.3ms
# Frame 184: preprocess=2.6ms, move=16.6ms, static=40.9ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.9ms, total=69.8ms
# Frame 185: preprocess=2.5ms, move=17.0ms, static=42.6ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.6ms, total=71.5ms
# Frame 186: preprocess=3.0ms, move=16.3ms, static=39.0ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.9ms, total=68.2ms
# Frame 187: preprocess=3.0ms, move=16.7ms, static=40.1ms, kalman=0.0ms tracking=0.0ms, bg=5.6ms, vis=3.6ms, total=69.1ms
# Frame 188: preprocess=2.6ms, move=16.4ms, static=41.4ms, kalman=0.0ms tracking=0.0ms, bg=6.5ms, vis=4.0ms, total=70.8ms
# Frame 189: preprocess=2.6ms, move=17.0ms, static=40.8ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.5ms, total=70.0ms
# Frame 190: preprocess=2.8ms, move=18.1ms, static=43.2ms, kalman=0.0ms tracking=0.0ms, bg=6.4ms, vis=3.3ms, total=73.9ms
# Frame 191: preprocess=3.4ms, move=17.8ms, static=40.6ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.3ms, total=70.9ms
# Frame 192: preprocess=2.7ms, move=16.7ms, static=40.7ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=3.6ms, total=69.8ms
# Frame 193: preprocess=3.1ms, move=16.7ms, static=40.7ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.6ms, total=70.1ms
# Frame 194: preprocess=3.1ms, move=16.2ms, static=40.8ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.9ms, total=70.0ms
# Frame 195: preprocess=2.7ms, move=17.4ms, static=42.6ms, kalman=0.0ms tracking=0.0ms, bg=5.6ms, vis=3.4ms, total=71.8ms
# Frame 196: preprocess=3.3ms, move=16.8ms, static=40.8ms, kalman=0.0ms tracking=0.0ms, bg=6.2ms, vis=3.5ms, total=70.6ms
# Frame 197: preprocess=2.8ms, move=16.3ms, static=39.5ms, kalman=0.0ms tracking=0.0ms, bg=12.6ms, vis=3.8ms, total=75.1ms
# Frame 198: preprocess=3.1ms, move=19.7ms, static=45.6ms, kalman=0.0ms tracking=0.0ms, bg=7.0ms, vis=3.5ms, total=78.9ms
# Frame 199: preprocess=2.9ms, move=19.5ms, static=44.5ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=4.2ms, total=76.9ms
# Frame 200: preprocess=3.0ms, move=19.3ms, static=44.6ms, kalman=0.0ms tracking=0.1ms, bg=7.7ms, vis=4.0ms, total=78.7ms
# Frame 201: preprocess=2.8ms, move=19.1ms, static=42.1ms, kalman=0.0ms tracking=0.0ms, bg=6.1ms, vis=3.5ms, total=73.8ms
# Frame 202: preprocess=2.9ms, move=15.3ms, static=40.6ms, kalman=0.0ms tracking=0.0ms, bg=6.3ms, vis=3.3ms, total=68.4ms
# Frame 203: preprocess=2.7ms, move=17.2ms, static=39.7ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.4ms, total=68.7ms
# Frame 204: preprocess=3.4ms, move=17.2ms, static=40.4ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=4.3ms, total=71.0ms
# Frame 205: preprocess=4.0ms, move=20.3ms, static=47.3ms, kalman=0.0ms tracking=0.1ms, bg=5.5ms, vis=3.9ms, total=81.1ms
# Frame 206: preprocess=2.1ms, move=14.4ms, static=39.1ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.7ms, total=65.2ms
# Frame 207: preprocess=2.5ms, move=16.2ms, static=39.5ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.8ms, total=67.8ms
# Frame 208: preprocess=2.4ms, move=17.0ms, static=39.8ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=4.3ms, total=69.6ms
# Frame 209: preprocess=2.1ms, move=16.0ms, static=38.5ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.8ms, total=66.3ms
# Frame 210: preprocess=2.5ms, move=16.4ms, static=41.9ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=3.2ms, total=70.0ms
# Frame 211: preprocess=2.3ms, move=16.5ms, static=39.5ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=4.1ms, total=68.5ms
# Frame 212: preprocess=2.4ms, move=17.7ms, static=37.5ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.8ms, total=67.2ms
# Frame 213: preprocess=2.2ms, move=17.0ms, static=41.1ms, kalman=0.0ms tracking=0.0ms, bg=6.1ms, vis=3.6ms, total=70.2ms
# Frame 214: preprocess=2.8ms, move=17.5ms, static=43.0ms, kalman=0.0ms tracking=0.0ms, bg=6.1ms, vis=3.6ms, total=73.0ms
# Frame 215: preprocess=2.7ms, move=15.7ms, static=40.7ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.6ms, total=68.5ms
# Frame 216: preprocess=2.6ms, move=15.8ms, static=40.7ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=4.3ms, total=69.3ms
# Frame 217: preprocess=2.8ms, move=16.3ms, static=40.1ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.8ms, total=68.8ms
# Frame 218: preprocess=3.2ms, move=19.4ms, static=39.2ms, kalman=0.0ms tracking=0.0ms, bg=6.1ms, vis=4.0ms, total=71.9ms
# Frame 219: preprocess=2.4ms, move=16.3ms, static=41.3ms, kalman=0.0ms tracking=0.0ms, bg=5.4ms, vis=3.5ms, total=69.0ms
# Frame 220: preprocess=3.1ms, move=17.8ms, static=43.5ms, kalman=0.0ms tracking=0.0ms, bg=6.2ms, vis=3.7ms, total=74.3ms
# Frame 221: preprocess=2.3ms, move=17.4ms, static=41.5ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.4ms, total=70.6ms
# Frame 222: preprocess=2.9ms, move=17.4ms, static=40.9ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=4.7ms, total=71.8ms
# Frame 223: preprocess=2.1ms, move=16.3ms, static=41.9ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.1ms, total=69.3ms
# Frame 224: preprocess=2.6ms, move=17.7ms, static=43.1ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.4ms, total=72.7ms
# Frame 225: preprocess=2.5ms, move=17.1ms, static=42.6ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.8ms, total=72.0ms
# Frame 226: preprocess=3.3ms, move=18.4ms, static=44.0ms, kalman=0.0ms tracking=0.1ms, bg=5.9ms, vis=4.0ms, total=75.6ms
# Frame 227: preprocess=3.1ms, move=16.8ms, static=43.2ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=4.2ms, total=73.4ms
# Frame 228: preprocess=2.8ms, move=17.2ms, static=41.4ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=4.5ms, total=71.7ms
# Frame 229: preprocess=2.4ms, move=16.3ms, static=42.3ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.6ms, total=70.5ms
# Frame 230: preprocess=2.3ms, move=16.2ms, static=40.5ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.5ms, total=68.5ms
# Frame 231: preprocess=2.4ms, move=17.1ms, static=42.4ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=3.8ms, total=71.7ms
# Frame 232: preprocess=2.9ms, move=21.3ms, static=45.1ms, kalman=0.0ms tracking=0.0ms, bg=6.2ms, vis=4.4ms, total=80.0ms
# Frame 233: preprocess=4.2ms, move=22.2ms, static=44.3ms, kalman=0.0ms tracking=0.0ms, bg=6.2ms, vis=3.2ms, total=80.1ms
# Frame 234: preprocess=3.6ms, move=19.1ms, static=41.8ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.9ms, total=74.3ms
# Frame 235: preprocess=3.7ms, move=17.5ms, static=40.6ms, kalman=0.0ms tracking=0.0ms, bg=6.6ms, vis=3.8ms, total=72.2ms
# Frame 236: preprocess=2.7ms, move=16.2ms, static=40.3ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.2ms, total=68.4ms
# Frame 237: preprocess=2.4ms, move=16.4ms, static=41.1ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.9ms, total=69.6ms
# Frame 238: preprocess=2.3ms, move=16.4ms, static=40.7ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.6ms, total=69.0ms
# Frame 239: preprocess=2.3ms, move=16.6ms, static=41.1ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.8ms, total=69.8ms
# Frame 240: preprocess=2.8ms, move=17.7ms, static=39.6ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=3.5ms, total=69.6ms
# Frame 241: preprocess=2.5ms, move=17.7ms, static=42.1ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=4.0ms, total=72.1ms
# Frame 242: preprocess=3.0ms, move=17.3ms, static=41.4ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=3.6ms, total=71.3ms
# Frame 243: preprocess=2.4ms, move=17.7ms, static=42.4ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=4.0ms, total=72.5ms
# Frame 244: preprocess=3.1ms, move=19.1ms, static=43.0ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.9ms, total=74.9ms
# Frame 245: preprocess=2.8ms, move=17.4ms, static=42.7ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=4.0ms, total=72.9ms
# Frame 246: preprocess=2.4ms, move=17.5ms, static=42.7ms, kalman=0.0ms tracking=0.0ms, bg=5.5ms, vis=3.0ms, total=71.2ms
# Frame 247: preprocess=2.5ms, move=16.4ms, static=43.1ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=4.0ms, total=71.9ms
# Frame 248: preprocess=2.4ms, move=18.1ms, static=42.7ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=4.1ms, total=73.2ms
# Frame 249: preprocess=2.8ms, move=16.5ms, static=42.2ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.9ms, total=71.4ms
# Frame 250: preprocess=2.4ms, move=30.0ms, static=72.1ms, kalman=0.0ms tracking=0.0ms, bg=10.1ms, vis=7.2ms, total=121.8ms
# Frame 251: preprocess=6.7ms, move=18.0ms, static=42.0ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.8ms, total=76.4ms
# Frame 252: preprocess=2.3ms, move=16.5ms, static=41.2ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.7ms, total=69.7ms
# Frame 253: preprocess=2.7ms, move=17.7ms, static=41.9ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=4.0ms, total=72.1ms
# Frame 254: preprocess=2.4ms, move=17.9ms, static=41.2ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.4ms, total=70.7ms
# Frame 255: preprocess=3.2ms, move=17.8ms, static=126.2ms, kalman=0.0ms tracking=3.3ms, bg=6.1ms, vis=3.9ms, total=160.5ms
# Frame 256: preprocess=3.6ms, move=15.3ms, static=133.1ms, kalman=0.0ms tracking=3.3ms, bg=6.4ms, vis=4.5ms, total=166.1ms
# Frame 257: preprocess=3.1ms, move=17.2ms, static=124.8ms, kalman=0.0ms tracking=3.6ms, bg=6.5ms, vis=4.5ms, total=159.8ms
# Frame 258: preprocess=2.1ms, move=16.7ms, static=127.8ms, kalman=0.0ms tracking=3.0ms, bg=5.9ms, vis=4.0ms, total=159.6ms
# Frame 259: preprocess=2.4ms, move=16.4ms, static=126.9ms, kalman=0.0ms tracking=3.3ms, bg=6.3ms, vis=4.2ms, total=159.5ms
# Frame 260: preprocess=2.2ms, move=17.3ms, static=127.3ms, kalman=0.0ms tracking=3.1ms, bg=5.7ms, vis=4.2ms, total=159.8ms
# Frame 261: preprocess=2.7ms, move=15.7ms, static=133.5ms, kalman=0.0ms tracking=3.4ms, bg=5.4ms, vis=3.7ms, total=164.5ms
# Frame 262: preprocess=2.5ms, move=16.6ms, static=127.7ms, kalman=0.0ms tracking=3.1ms, bg=5.1ms, vis=3.1ms, total=158.1ms
# Frame 263: preprocess=2.9ms, move=15.3ms, static=128.7ms, kalman=0.0ms tracking=3.1ms, bg=6.1ms, vis=4.0ms, total=160.1ms
# Frame 264: preprocess=2.9ms, move=18.7ms, static=137.1ms, kalman=0.0ms tracking=3.6ms, bg=5.7ms, vis=3.7ms, total=171.9ms
# Frame 265: preprocess=3.0ms, move=18.7ms, static=135.5ms, kalman=0.0ms tracking=3.2ms, bg=6.0ms, vis=3.9ms, total=170.3ms
# Frame 266: preprocess=2.6ms, move=16.8ms, static=127.6ms, kalman=0.0ms tracking=2.9ms, bg=5.9ms, vis=3.5ms, total=159.3ms
# Frame 267: preprocess=2.4ms, move=16.8ms, static=121.9ms, kalman=0.0ms tracking=3.0ms, bg=6.1ms, vis=3.5ms, total=153.6ms
# Frame 268: preprocess=3.0ms, move=16.3ms, static=110.8ms, kalman=0.0ms tracking=3.1ms, bg=6.1ms, vis=4.2ms, total=143.5ms
# Frame 269: preprocess=2.6ms, move=16.3ms, static=117.7ms, kalman=0.0ms tracking=3.0ms, bg=5.8ms, vis=3.8ms, total=149.2ms
# Frame 270: preprocess=2.1ms, move=16.6ms, static=115.6ms, kalman=0.0ms tracking=3.2ms, bg=6.1ms, vis=3.7ms, total=147.4ms
# Frame 271: preprocess=2.6ms, move=17.1ms, static=118.4ms, kalman=0.0ms tracking=3.3ms, bg=6.0ms, vis=3.2ms, total=150.7ms
# Frame 272: preprocess=2.9ms, move=18.2ms, static=122.1ms, kalman=0.0ms tracking=3.3ms, bg=6.1ms, vis=3.3ms, total=155.9ms
# Frame 273: preprocess=2.5ms, move=16.7ms, static=118.7ms, kalman=0.0ms tracking=2.8ms, bg=6.0ms, vis=4.2ms, total=150.8ms
# Frame 274: preprocess=3.6ms, move=16.1ms, static=130.4ms, kalman=0.0ms tracking=3.0ms, bg=6.1ms, vis=3.2ms, total=162.6ms
# Frame 275: preprocess=3.1ms, move=17.9ms, static=129.5ms, kalman=0.0ms tracking=3.0ms, bg=6.0ms, vis=4.4ms, total=163.8ms
# Frame 276: preprocess=3.1ms, move=15.3ms, static=36.5ms, kalman=0.0ms tracking=0.0ms, bg=5.3ms, vis=2.7ms, total=63.0ms
# Frame 277: preprocess=2.0ms, move=14.6ms, static=34.1ms, kalman=0.0ms tracking=0.0ms, bg=4.5ms, vis=2.6ms, total=57.9ms
# Frame 278: preprocess=2.5ms, move=13.5ms, static=35.0ms, kalman=0.0ms tracking=0.0ms, bg=4.3ms, vis=2.2ms, total=57.5ms
# Frame 279: preprocess=2.3ms, move=15.0ms, static=34.9ms, kalman=0.0ms tracking=0.0ms, bg=5.0ms, vis=2.8ms, total=60.0ms
# Frame 280: preprocess=3.8ms, move=15.1ms, static=36.7ms, kalman=0.0ms tracking=0.0ms, bg=4.7ms, vis=2.6ms, total=63.0ms
# Frame 281: preprocess=2.2ms, move=15.7ms, static=34.2ms, kalman=0.0ms tracking=0.0ms, bg=4.7ms, vis=2.2ms, total=59.0ms
# Frame 282: preprocess=1.6ms, move=13.5ms, static=37.2ms, kalman=0.0ms tracking=0.0ms, bg=5.3ms, vis=2.7ms, total=60.4ms
# Frame 283: preprocess=2.3ms, move=16.4ms, static=41.8ms, kalman=0.0ms tracking=0.0ms, bg=5.2ms, vis=2.9ms, total=68.6ms
# Frame 284: preprocess=2.5ms, move=16.2ms, static=42.0ms, kalman=0.0ms tracking=0.0ms, bg=5.6ms, vis=3.1ms, total=69.5ms
# Frame 285: preprocess=2.6ms, move=16.6ms, static=40.9ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.4ms, total=69.4ms
# Frame 286: preprocess=2.2ms, move=17.0ms, static=41.7ms, kalman=0.0ms tracking=0.0ms, bg=6.2ms, vis=3.3ms, total=70.4ms
# Frame 287: preprocess=2.7ms, move=17.1ms, static=42.4ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=4.0ms, total=72.0ms
# Frame 288: preprocess=3.0ms, move=18.4ms, static=41.6ms, kalman=0.0ms tracking=0.0ms, bg=5.4ms, vis=3.5ms, total=71.9ms
# Frame 289: preprocess=2.9ms, move=16.3ms, static=41.7ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.8ms, total=70.4ms
# Frame 290: preprocess=2.8ms, move=16.9ms, static=41.2ms, kalman=0.0ms tracking=0.0ms, bg=5.1ms, vis=3.0ms, total=69.2ms
# Frame 291: preprocess=2.7ms, move=17.2ms, static=39.4ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.8ms, total=69.1ms
# Frame 292: preprocess=2.8ms, move=16.9ms, static=41.9ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.7ms, total=71.3ms
# Frame 293: preprocess=2.4ms, move=17.6ms, static=42.6ms, kalman=0.0ms tracking=0.0ms, bg=5.6ms, vis=3.8ms, total=72.1ms
# Frame 294: preprocess=6.5ms, move=16.7ms, static=39.8ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=4.1ms, total=73.1ms
# Frame 295: preprocess=2.4ms, move=16.9ms, static=41.1ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=4.4ms, total=70.8ms
# Frame 296: preprocess=3.5ms, move=21.7ms, static=42.5ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.7ms, total=77.2ms
# Frame 297: preprocess=2.5ms, move=18.0ms, static=43.8ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=4.1ms, total=74.3ms
# Frame 298: preprocess=2.3ms, move=17.5ms, static=46.2ms, kalman=0.0ms tracking=0.0ms, bg=6.5ms, vis=3.8ms, total=76.5ms
# Frame 299: preprocess=2.3ms, move=17.5ms, static=43.1ms, kalman=0.0ms tracking=0.0ms, bg=6.3ms, vis=3.5ms, total=72.8ms
# Frame 300: preprocess=2.9ms, move=18.5ms, static=43.4ms, kalman=0.0ms tracking=0.0ms, bg=6.2ms, vis=3.8ms, total=74.9ms
# Frame 301: preprocess=2.4ms, move=16.9ms, static=40.8ms, kalman=0.0ms tracking=0.0ms, bg=6.1ms, vis=3.9ms, total=70.2ms
# Frame 302: preprocess=2.6ms, move=17.1ms, static=42.6ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.5ms, total=71.7ms
# Frame 303: preprocess=2.5ms, move=16.6ms, static=41.1ms, kalman=0.0ms tracking=0.0ms, bg=6.3ms, vis=3.1ms, total=69.6ms
# Frame 304: preprocess=3.1ms, move=19.4ms, static=43.5ms, kalman=0.0ms tracking=0.0ms, bg=6.6ms, vis=4.3ms, total=77.0ms
# Frame 305: preprocess=3.3ms, move=22.2ms, static=44.0ms, kalman=0.0ms tracking=0.0ms, bg=6.5ms, vis=3.9ms, total=79.9ms
# Frame 306: preprocess=2.0ms, move=17.0ms, static=41.0ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=3.5ms, total=69.6ms
# Frame 307: preprocess=2.4ms, move=16.3ms, static=41.4ms, kalman=0.0ms tracking=0.1ms, bg=6.1ms, vis=3.9ms, total=70.1ms
# Frame 308: preprocess=2.5ms, move=16.0ms, static=42.3ms, kalman=0.0ms tracking=0.0ms, bg=6.6ms, vis=3.3ms, total=70.8ms
# Frame 309: preprocess=2.3ms, move=16.0ms, static=41.7ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.3ms, total=69.2ms
# Frame 310: preprocess=2.6ms, move=17.9ms, static=43.0ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.6ms, total=72.9ms
# Frame 311: preprocess=2.2ms, move=16.3ms, static=43.5ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.6ms, total=71.6ms
# Frame 312: preprocess=2.6ms, move=17.7ms, static=44.7ms, kalman=0.0ms tracking=0.0ms, bg=6.1ms, vis=4.0ms, total=75.3ms
# Frame 313: preprocess=3.8ms, move=18.5ms, static=45.4ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.2ms, total=76.9ms
# Frame 314: preprocess=2.1ms, move=16.1ms, static=46.8ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.6ms, total=74.5ms
# Frame 315: preprocess=2.6ms, move=16.5ms, static=47.0ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=4.4ms, total=76.6ms
# Frame 316: preprocess=2.6ms, move=16.5ms, static=49.6ms, kalman=0.0ms tracking=0.1ms, bg=6.2ms, vis=4.0ms, total=78.9ms
# Frame 317: preprocess=3.6ms, move=16.1ms, static=52.9ms, kalman=0.0ms tracking=0.1ms, bg=6.0ms, vis=3.1ms, total=81.9ms
# Frame 318: preprocess=2.6ms, move=16.3ms, static=59.3ms, kalman=0.0ms tracking=0.4ms, bg=5.8ms, vis=3.3ms, total=87.6ms
# Frame 319: preprocess=2.5ms, move=17.6ms, static=75.0ms, kalman=0.0ms tracking=0.7ms, bg=5.9ms, vis=4.0ms, total=105.7ms
# Frame 320: preprocess=3.7ms, move=17.4ms, static=89.4ms, kalman=0.0ms tracking=0.9ms, bg=5.9ms, vis=3.9ms, total=121.2ms
# Frame 321: preprocess=2.3ms, move=16.1ms, static=85.9ms, kalman=0.0ms tracking=1.0ms, bg=6.0ms, vis=3.6ms, total=114.9ms
# Frame 322: preprocess=2.7ms, move=19.2ms, static=95.7ms, kalman=0.0ms tracking=1.4ms, bg=6.8ms, vis=3.3ms, total=129.0ms
# Frame 323: preprocess=2.3ms, move=16.6ms, static=96.5ms, kalman=0.0ms tracking=1.5ms, bg=5.7ms, vis=3.7ms, total=126.4ms
# Frame 324: preprocess=3.5ms, move=16.8ms, static=106.2ms, kalman=0.0ms tracking=1.7ms, bg=6.7ms, vis=3.6ms, total=138.5ms
# Frame 325: preprocess=3.0ms, move=16.8ms, static=103.1ms, kalman=0.0ms tracking=1.8ms, bg=6.0ms, vis=3.8ms, total=134.4ms
# Frame 326: preprocess=2.7ms, move=17.9ms, static=99.9ms, kalman=0.0ms tracking=1.5ms, bg=6.3ms, vis=3.3ms, total=131.6ms
# Frame 327: preprocess=2.4ms, move=16.2ms, static=100.1ms, kalman=0.0ms tracking=1.3ms, bg=6.5ms, vis=3.7ms, total=130.3ms
# Frame 328: preprocess=3.1ms, move=16.6ms, static=100.9ms, kalman=0.0ms tracking=1.3ms, bg=6.0ms, vis=4.1ms, total=132.0ms
# Frame 329: preprocess=2.2ms, move=16.6ms, static=94.2ms, kalman=0.0ms tracking=1.0ms, bg=6.1ms, vis=3.5ms, total=123.7ms
# Frame 330: preprocess=2.8ms, move=17.0ms, static=109.8ms, kalman=0.0ms tracking=1.0ms, bg=3.6ms, vis=4.4ms, total=138.6ms
# Frame 331: preprocess=2.5ms, move=15.0ms, static=88.1ms, kalman=0.0ms tracking=1.3ms, bg=6.1ms, vis=3.7ms, total=116.6ms
# Frame 332: preprocess=2.1ms, move=14.9ms, static=78.5ms, kalman=0.0ms tracking=0.8ms, bg=6.4ms, vis=3.6ms, total=106.2ms
# Frame 333: preprocess=2.4ms, move=15.4ms, static=85.0ms, kalman=0.0ms tracking=0.9ms, bg=5.9ms, vis=3.4ms, total=113.1ms
# Frame 334: preprocess=3.3ms, move=15.2ms, static=68.5ms, kalman=0.0ms tracking=0.6ms, bg=6.0ms, vis=3.9ms, total=97.5ms
# Frame 335: preprocess=2.1ms, move=14.4ms, static=67.7ms, kalman=0.0ms tracking=0.3ms, bg=5.3ms, vis=3.3ms, total=93.2ms
# Frame 336: preprocess=2.7ms, move=15.2ms, static=60.5ms, kalman=0.0ms tracking=0.3ms, bg=5.7ms, vis=2.4ms, total=86.8ms
# Frame 337: preprocess=2.2ms, move=16.7ms, static=56.4ms, kalman=0.0ms tracking=0.1ms, bg=6.1ms, vis=3.9ms, total=85.5ms
# Frame 338: preprocess=3.2ms, move=17.0ms, static=51.2ms, kalman=0.0ms tracking=0.1ms, bg=6.2ms, vis=2.8ms, total=80.6ms
# Frame 339: preprocess=2.4ms, move=14.5ms, static=46.5ms, kalman=0.0ms tracking=0.3ms, bg=14.7ms, vis=2.8ms, total=81.2ms
# Frame 340: preprocess=1.9ms, move=13.4ms, static=41.0ms, kalman=0.2ms tracking=5.7ms, bg=15.4ms, vis=6.0ms, total=83.5ms
# Frame 341: preprocess=2.1ms, move=11.8ms, static=40.5ms, kalman=0.2ms tracking=4.3ms, bg=13.8ms, vis=2.8ms, total=75.6ms
# Frame 342: preprocess=2.2ms, move=12.6ms, static=36.3ms, kalman=0.2ms tracking=3.4ms, bg=13.6ms, vis=3.0ms, total=71.4ms
# Frame 343: preprocess=2.4ms, move=13.1ms, static=37.3ms, kalman=0.2ms tracking=2.4ms, bg=14.2ms, vis=2.7ms, total=72.2ms
# Frame 344: preprocess=2.6ms, move=12.4ms, static=40.7ms, kalman=0.2ms tracking=2.2ms, bg=13.8ms, vis=3.2ms, total=75.0ms
# Frame 345: preprocess=2.9ms, move=17.9ms, static=41.3ms, kalman=0.3ms tracking=3.4ms, bg=17.6ms, vis=3.5ms, total=86.8ms
# Frame 346: preprocess=2.4ms, move=17.0ms, static=43.0ms, kalman=0.2ms tracking=1.7ms, bg=16.2ms, vis=4.0ms, total=84.6ms
# Frame 347: preprocess=2.4ms, move=18.3ms, static=40.6ms, kalman=0.3ms tracking=1.8ms, bg=17.6ms, vis=3.1ms, total=84.1ms
# Frame 348: preprocess=2.0ms, move=16.1ms, static=39.2ms, kalman=0.2ms tracking=2.0ms, bg=16.0ms, vis=3.8ms, total=79.4ms
# Frame 349: preprocess=3.1ms, move=21.3ms, static=43.1ms, kalman=0.3ms tracking=2.3ms, bg=17.7ms, vis=3.5ms, total=91.4ms
# Frame 350: preprocess=2.9ms, move=16.1ms, static=39.2ms, kalman=0.2ms tracking=1.7ms, bg=17.4ms, vis=8.6ms, total=86.1ms
# Frame 351: preprocess=2.7ms, move=17.1ms, static=38.5ms, kalman=0.2ms tracking=1.5ms, bg=17.5ms, vis=3.5ms, total=81.0ms
# Frame 352: preprocess=3.3ms, move=17.9ms, static=38.3ms, kalman=0.2ms tracking=1.3ms, bg=17.0ms, vis=4.0ms, total=82.1ms
# Frame 353: preprocess=2.8ms, move=18.7ms, static=40.3ms, kalman=0.2ms tracking=1.2ms, bg=17.5ms, vis=4.4ms, total=85.0ms
# Frame 354: preprocess=2.6ms, move=18.7ms, static=40.4ms, kalman=0.2ms tracking=1.1ms, bg=17.1ms, vis=3.4ms, total=83.5ms
# Frame 355: preprocess=2.4ms, move=17.3ms, static=38.7ms, kalman=0.2ms tracking=1.2ms, bg=5.9ms, vis=3.6ms, total=69.4ms
# Frame 356: preprocess=2.4ms, move=16.3ms, static=36.3ms, kalman=0.0ms tracking=0.0ms, bg=5.4ms, vis=3.8ms, total=64.2ms
# Frame 357: preprocess=2.4ms, move=16.5ms, static=35.7ms, kalman=0.0ms tracking=0.0ms, bg=5.4ms, vis=3.6ms, total=63.7ms
# Frame 358: preprocess=2.6ms, move=16.8ms, static=36.6ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.2ms, total=65.1ms
# Frame 359: preprocess=2.6ms, move=16.5ms, static=36.6ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=3.4ms, total=65.0ms
# Frame 360: preprocess=2.3ms, move=17.9ms, static=35.0ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.6ms, total=64.5ms
# Frame 361: preprocess=3.1ms, move=17.2ms, static=36.3ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.5ms, total=65.9ms
# Frame 362: preprocess=3.9ms, move=17.7ms, static=38.4ms, kalman=0.0ms tracking=0.0ms, bg=5.5ms, vis=3.5ms, total=68.9ms
# Frame 363: preprocess=2.6ms, move=17.2ms, static=36.2ms, kalman=0.0ms tracking=0.0ms, bg=6.2ms, vis=3.8ms, total=66.2ms
# Frame 364: preprocess=3.4ms, move=19.2ms, static=36.7ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.9ms, total=69.1ms
# Frame 365: preprocess=2.3ms, move=16.8ms, static=35.8ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=3.5ms, total=64.5ms
# Frame 366: preprocess=2.3ms, move=18.0ms, static=36.2ms, kalman=0.0ms tracking=0.2ms, bg=17.1ms, vis=3.1ms, total=77.0ms
# Frame 367: preprocess=2.4ms, move=17.5ms, static=37.8ms, kalman=0.2ms tracking=0.7ms, bg=16.6ms, vis=4.2ms, total=79.4ms
# Frame 368: preprocess=2.9ms, move=18.8ms, static=37.5ms, kalman=0.2ms tracking=0.8ms, bg=17.2ms, vis=4.3ms, total=81.6ms
# Frame 369: preprocess=2.5ms, move=18.5ms, static=38.5ms, kalman=0.2ms tracking=0.8ms, bg=17.2ms, vis=3.7ms, total=81.4ms
# Frame 370: preprocess=2.7ms, move=16.9ms, static=33.2ms, kalman=0.2ms tracking=0.7ms, bg=17.7ms, vis=8.9ms, total=80.4ms
# Frame 371: preprocess=2.3ms, move=18.9ms, static=36.4ms, kalman=0.2ms tracking=0.7ms, bg=18.0ms, vis=3.5ms, total=80.0ms
# Frame 372: preprocess=2.5ms, move=18.8ms, static=37.9ms, kalman=0.2ms tracking=0.8ms, bg=18.3ms, vis=5.1ms, total=83.7ms
# Frame 373: preprocess=2.9ms, move=17.6ms, static=36.3ms, kalman=0.2ms tracking=0.7ms, bg=15.8ms, vis=3.9ms, total=77.3ms
# Frame 374: preprocess=1.9ms, move=16.8ms, static=37.2ms, kalman=0.2ms tracking=0.9ms, bg=17.5ms, vis=4.1ms, total=78.6ms
# Frame 375: preprocess=2.6ms, move=19.1ms, static=33.8ms, kalman=0.2ms tracking=0.7ms, bg=16.8ms, vis=3.7ms, total=76.9ms
# Frame 376: preprocess=2.6ms, move=16.0ms, static=35.5ms, kalman=0.2ms tracking=0.7ms, bg=17.5ms, vis=3.6ms, total=76.1ms
# Frame 377: preprocess=2.6ms, move=17.4ms, static=36.1ms, kalman=0.2ms tracking=0.8ms, bg=5.7ms, vis=4.0ms, total=66.8ms
# Frame 378: preprocess=2.4ms, move=16.7ms, static=34.3ms, kalman=0.0ms tracking=0.0ms, bg=5.9ms, vis=4.0ms, total=63.3ms
# Frame 379: preprocess=3.2ms, move=16.7ms, static=33.7ms, kalman=0.0ms tracking=0.0ms, bg=6.1ms, vis=3.5ms, total=63.2ms
# Frame 380: preprocess=2.3ms, move=17.1ms, static=34.8ms, kalman=0.0ms tracking=0.1ms, bg=5.9ms, vis=3.8ms, total=64.1ms
# Frame 381: preprocess=2.2ms, move=16.4ms, static=32.8ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=3.7ms, total=61.1ms
# Frame 382: preprocess=2.5ms, move=16.8ms, static=35.2ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.6ms, total=64.1ms
# Frame 383: preprocess=2.6ms, move=17.7ms, static=35.1ms, kalman=0.0ms tracking=0.0ms, bg=5.6ms, vis=3.4ms, total=64.4ms
# Frame 384: preprocess=2.1ms, move=17.8ms, static=35.5ms, kalman=0.0ms tracking=0.0ms, bg=6.1ms, vis=3.7ms, total=65.2ms
# Frame 385: preprocess=2.5ms, move=17.3ms, static=35.4ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.9ms, total=64.9ms
# Frame 386: preprocess=2.3ms, move=17.7ms, static=36.6ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=4.0ms, total=66.6ms
# Frame 387: preprocess=2.3ms, move=17.5ms, static=34.5ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=4.1ms, total=64.2ms
# Frame 388: preprocess=2.3ms, move=15.0ms, static=37.4ms, kalman=0.0ms tracking=0.1ms, bg=5.9ms, vis=3.7ms, total=64.4ms
# Frame 389: preprocess=2.2ms, move=16.5ms, static=31.7ms, kalman=0.0ms tracking=0.0ms, bg=5.5ms, vis=3.8ms, total=59.7ms
# Frame 390: preprocess=2.2ms, move=16.9ms, static=34.7ms, kalman=0.0ms tracking=0.0ms, bg=6.0ms, vis=3.8ms, total=63.7ms
# Frame 391: preprocess=2.2ms, move=15.8ms, static=55.6ms, kalman=0.0ms tracking=0.0ms, bg=6.6ms, vis=5.7ms, total=85.9ms
# Frame 392: preprocess=3.1ms, move=19.7ms, static=36.6ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.8ms, total=69.0ms
# Frame 393: preprocess=2.5ms, move=18.6ms, static=32.9ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=3.1ms, total=62.9ms
# Frame 394: preprocess=2.2ms, move=16.1ms, static=32.3ms, kalman=0.0ms tracking=0.0ms, bg=5.8ms, vis=3.4ms, total=59.8ms
# Frame 395: preprocess=2.6ms, move=15.8ms, static=31.5ms, kalman=0.0ms tracking=0.0ms, bg=5.4ms, vis=3.9ms, total=59.2ms
# Frame 396: preprocess=2.2ms, move=16.8ms, static=31.5ms, kalman=0.0ms tracking=0.0ms, bg=4.8ms, vis=3.1ms, total=58.5ms
# ...
# Frame 1424: preprocess=6.1ms, move=26.3ms, static=59.0ms, kalman=0.0ms tracking=0.1ms, bg=9.0ms, vis=5.7ms, total=106.2ms
# Frame 1425: preprocess=7.3ms, move=33.2ms, static=50.1ms, kalman=0.0ms tracking=0.0ms, bg=10.4ms, vis=5.1ms, total=106.2ms
# Frame 1426: preprocess=3.5ms, move=26.7ms, static=56.3ms, kalman=0.0ms tracking=0.0ms, bg=10.3ms, vis=5.5ms, total=102.3ms
# Frame 1427: preprocess=4.0ms, move=23.1ms, static=47.0ms, kalman=0.0ms tracking=1.5ms, bg=10.1ms, vis=5.3ms, total=90.9ms
# Frame 1428: preprocess=6.4ms, move=30.6ms, static=47.1ms, kalman=0.0ms tracking=0.0ms, bg=8.0ms, vis=4.4ms, total=96.6ms
# Frame 1429: preprocess=4.6ms, move=21.9ms, static=50.3ms, kalman=0.9ms tracking=0.1ms, bg=8.6ms, vis=5.3ms, total=91.6ms
# Frame 1430: preprocess=10.0ms, move=42.2ms, static=59.2ms, kalman=0.0ms tracking=0.1ms, bg=10.6ms, vis=4.6ms, total=126.7ms
# Frame 1431: preprocess=8.7ms, move=28.5ms, static=86.1ms, kalman=0.0ms tracking=0.0ms, bg=8.6ms, vis=8.4ms, total=140.4ms
# Frame 1432: preprocess=7.0ms, move=40.2ms, static=59.3ms, kalman=0.0ms tracking=0.0ms, bg=8.9ms, vis=5.1ms, total=120.5ms
# Frame 1433: preprocess=4.1ms, move=21.2ms, static=51.6ms, kalman=0.0ms tracking=0.0ms, bg=9.0ms, vis=3.9ms, total=89.9ms
# Frame 1434: preprocess=5.4ms, move=22.6ms, static=50.2ms, kalman=0.0ms tracking=0.0ms, bg=8.3ms, vis=4.8ms, total=91.4ms
# Frame 1435: preprocess=15.3ms, move=33.2ms, static=49.6ms, kalman=0.0ms tracking=0.0ms, bg=9.7ms, vis=4.4ms, total=112.2ms
# Frame 1436: preprocess=5.5ms, move=26.6ms, static=54.0ms, kalman=0.0ms tracking=0.0ms, bg=11.8ms, vis=4.9ms, total=103.0ms
# Frame 1437: preprocess=5.8ms, move=26.1ms, static=48.7ms, kalman=0.0ms tracking=0.0ms, bg=7.5ms, vis=3.7ms, total=91.9ms
# Frame 1438: preprocess=8.0ms, move=20.9ms, static=50.3ms, kalman=0.0ms tracking=0.0ms, bg=7.9ms, vis=5.7ms, total=92.8ms
# Frame 1439: preprocess=9.7ms, move=43.7ms, static=66.3ms, kalman=0.0ms tracking=0.1ms, bg=7.9ms, vis=5.1ms, total=132.8ms
# Frame 1440: preprocess=3.7ms, move=33.5ms, static=53.0ms, kalman=0.0ms tracking=0.2ms, bg=24.2ms, vis=10.4ms, total=125.0ms
# Frame 1441: preprocess=6.7ms, move=25.5ms, static=49.8ms, kalman=0.2ms tracking=1.0ms, bg=23.7ms, vis=4.6ms, total=111.5ms
# Frame 1442: preprocess=5.1ms, move=26.2ms, static=54.6ms, kalman=0.2ms tracking=1.4ms, bg=20.0ms, vis=4.1ms, total=111.6ms
# Frame 1443: preprocess=3.0ms, move=18.6ms, static=46.3ms, kalman=0.2ms tracking=1.2ms, bg=21.5ms, vis=4.1ms, total=95.0ms
# Frame 1444: preprocess=2.6ms, move=18.4ms, static=42.8ms, kalman=0.2ms tracking=0.7ms, bg=21.9ms, vis=7.2ms, total=93.9ms
# Frame 1445: preprocess=2.9ms, move=22.1ms, static=40.0ms, kalman=0.2ms tracking=0.7ms, bg=19.2ms, vis=3.3ms, total=88.3ms
# Frame 1446: preprocess=3.0ms, move=17.5ms, static=35.9ms, kalman=0.2ms tracking=0.8ms, bg=19.9ms, vis=3.7ms, total=81.1ms
# Frame 1447: preprocess=3.7ms, move=17.1ms, static=43.1ms, kalman=0.2ms tracking=1.0ms, bg=20.5ms, vis=3.5ms, total=89.1ms
# Frame 1448: preprocess=2.6ms, move=17.5ms, static=37.5ms, kalman=0.2ms tracking=1.1ms, bg=18.9ms, vis=3.4ms, total=81.1ms
# Frame 1449: preprocess=3.7ms, move=18.9ms, static=37.8ms, kalman=0.2ms tracking=1.2ms, bg=20.8ms, vis=3.9ms, total=86.5ms
# Frame 1450: preprocess=2.8ms, move=18.0ms, static=41.7ms, kalman=0.3ms tracking=1.4ms, bg=23.2ms, vis=11.2ms, total=98.6ms
# Frame 1451: preprocess=3.1ms, move=17.8ms, static=40.8ms, kalman=0.2ms tracking=1.5ms, bg=19.4ms, vis=3.6ms, total=86.3ms
# Frame 1452: preprocess=4.3ms, move=17.8ms, static=44.7ms, kalman=0.3ms tracking=2.2ms, bg=18.9ms, vis=3.4ms, total=91.5ms
# Frame 1453: preprocess=3.1ms, move=28.4ms, static=46.9ms, kalman=0.3ms tracking=2.7ms, bg=22.3ms, vis=6.3ms, total=110.0ms
# Frame 1454: preprocess=3.1ms, move=19.3ms, static=41.7ms, kalman=0.4ms tracking=2.8ms, bg=20.0ms, vis=6.4ms, total=93.8ms
# Frame 1455: preprocess=3.9ms, move=23.4ms, static=42.9ms, kalman=0.3ms tracking=2.2ms, bg=20.3ms, vis=5.3ms, total=98.4ms
# Frame 1456: preprocess=5.2ms, move=21.1ms, static=41.6ms, kalman=0.4ms tracking=3.4ms, bg=20.7ms, vis=4.6ms, total=97.1ms
# Frame 1457: preprocess=3.2ms, move=22.9ms, static=41.1ms, kalman=0.7ms tracking=2.9ms, bg=20.8ms, vis=5.0ms, total=96.7ms
# Frame 1458: preprocess=3.7ms, move=21.3ms, static=38.7ms, kalman=0.5ms tracking=3.1ms, bg=21.2ms, vis=5.4ms, total=93.9ms
# Frame 1459: preprocess=3.4ms, move=21.3ms, static=41.5ms, kalman=0.5ms tracking=2.7ms, bg=19.8ms, vis=4.9ms, total=94.2ms
# Frame 1460: preprocess=3.8ms, move=19.3ms, static=38.0ms, kalman=0.5ms tracking=1.7ms, bg=20.5ms, vis=58.5ms, total=142.2ms
# Frame 1461: preprocess=5.5ms, move=29.4ms, static=43.7ms, kalman=0.5ms tracking=1.4ms, bg=24.2ms, vis=5.8ms, total=110.6ms
# Frame 1462: preprocess=5.3ms, move=20.9ms, static=41.5ms, kalman=0.5ms tracking=1.9ms, bg=19.7ms, vis=5.0ms, total=94.9ms
# Frame 1463: preprocess=3.4ms, move=20.4ms, static=36.8ms, kalman=0.6ms tracking=1.4ms, bg=19.0ms, vis=5.1ms, total=86.6ms
# Frame 1464: preprocess=3.9ms, move=21.3ms, static=38.0ms, kalman=0.5ms tracking=1.7ms, bg=19.9ms, vis=4.5ms, total=89.8ms
# Frame 1465: preprocess=3.0ms, move=19.7ms, static=40.5ms, kalman=0.6ms tracking=1.2ms, bg=19.1ms, vis=5.4ms, total=89.6ms
# Frame 1466: preprocess=3.6ms, move=19.9ms, static=37.5ms, kalman=0.3ms tracking=1.1ms, bg=19.4ms, vis=4.9ms, total=86.7ms
# Frame 1467: preprocess=2.8ms, move=19.6ms, static=40.9ms, kalman=0.3ms tracking=0.9ms, bg=19.7ms, vis=4.6ms, total=88.9ms
# Frame 1468: preprocess=2.2ms, move=17.9ms, static=37.1ms, kalman=0.3ms tracking=1.0ms, bg=20.3ms, vis=4.3ms, total=83.0ms
# Frame 1469: preprocess=2.6ms, move=20.8ms, static=42.3ms, kalman=0.2ms tracking=1.0ms, bg=21.4ms, vis=4.2ms, total=92.5ms
# Frame 1470: preprocess=2.7ms, move=23.5ms, static=43.9ms, kalman=0.2ms tracking=1.1ms, bg=6.9ms, vis=3.6ms, total=82.0ms
# Frame 1471: preprocess=4.0ms, move=21.7ms, static=38.6ms, kalman=0.0ms tracking=0.0ms, bg=7.1ms, vis=4.4ms, total=75.8ms
# Frame 1472: preprocess=5.5ms, move=22.6ms, static=40.5ms, kalman=0.0ms tracking=0.1ms, bg=6.8ms, vis=4.1ms, total=79.6ms
# Frame 1473: preprocess=3.1ms, move=19.1ms, static=38.8ms, kalman=0.0ms tracking=0.1ms, bg=6.9ms, vis=4.0ms, total=72.0ms
# Frame 1474: preprocess=2.6ms, move=21.2ms, static=39.5ms, kalman=0.0ms tracking=0.0ms, bg=6.9ms, vis=4.1ms, total=74.3ms
# Frame 1475: preprocess=2.8ms, move=18.6ms, static=42.7ms, kalman=0.0ms tracking=0.0ms, bg=7.1ms, vis=3.9ms, total=75.2ms
# Frame 1476: preprocess=3.1ms, move=18.8ms, static=37.6ms, kalman=0.0ms tracking=0.0ms, bg=7.7ms, vis=3.7ms, total=70.9ms
# Frame 1477: preprocess=5.3ms, move=19.2ms, static=34.8ms, kalman=0.0ms tracking=0.0ms, bg=10.2ms, vis=5.0ms, total=74.5ms
# Frame 1478: preprocess=2.7ms, move=22.9ms, static=40.6ms, kalman=0.0ms tracking=0.1ms, bg=6.9ms, vis=4.0ms, total=77.2ms
# Frame 1479: preprocess=4.4ms, move=20.4ms, static=37.7ms, kalman=0.0ms tracking=0.0ms, bg=7.2ms, vis=4.3ms, total=74.0ms
# Frame 1480: preprocess=2.6ms, move=20.7ms, static=40.8ms, kalman=0.0ms tracking=0.0ms, bg=7.0ms, vis=5.5ms, total=76.7ms
# Frame 1481: preprocess=2.9ms, move=19.8ms, static=35.4ms, kalman=0.0ms tracking=0.0ms, bg=6.6ms, vis=4.2ms, total=69.0ms
# Frame 1482: preprocess=2.9ms, move=20.6ms, static=35.4ms, kalman=0.0ms tracking=0.0ms, bg=6.9ms, vis=3.9ms, total=69.8ms
# Frame 1483: preprocess=3.5ms, move=21.5ms, static=36.9ms, kalman=0.0ms tracking=0.0ms, bg=7.0ms, vis=4.4ms, total=73.3ms
# Frame 1484: preprocess=2.8ms, move=19.1ms, static=39.0ms, kalman=0.0ms tracking=0.0ms, bg=6.3ms, vis=3.7ms, total=71.0ms
# Frame 1485: preprocess=3.9ms, move=23.0ms, static=47.1ms, kalman=0.0ms tracking=0.0ms, bg=6.9ms, vis=3.2ms, total=84.2ms
# Frame 1486: preprocess=2.6ms, move=17.5ms, static=38.8ms, kalman=0.0ms tracking=0.0ms, bg=7.0ms, vis=3.8ms, total=69.8ms
# Frame 1487: preprocess=3.3ms, move=21.4ms, static=42.8ms, kalman=0.0ms tracking=0.0ms, bg=9.6ms, vis=4.0ms, total=81.1ms
# Frame 1488: preprocess=2.8ms, move=23.7ms, static=41.6ms, kalman=0.0ms tracking=0.1ms, bg=7.2ms, vis=4.8ms, total=80.2ms
# Frame 1489: preprocess=2.7ms, move=19.1ms, static=44.9ms, kalman=0.0ms tracking=0.0ms, bg=6.9ms, vis=6.1ms, total=79.6ms
# Frame 1490: preprocess=2.8ms, move=23.0ms, static=40.9ms, kalman=0.0ms tracking=0.0ms, bg=6.9ms, vis=3.9ms, total=77.6ms
# Frame 1491: preprocess=2.9ms, move=18.4ms, static=43.9ms, kalman=0.0ms tracking=0.0ms, bg=6.8ms, vis=4.3ms, total=76.4ms
# Frame 1492: preprocess=4.4ms, move=20.4ms, static=43.5ms, kalman=0.0ms tracking=0.1ms, bg=7.1ms, vis=3.7ms, total=79.1ms
# Frame 1493: preprocess=5.9ms, move=21.9ms, static=43.2ms, kalman=0.0ms tracking=0.0ms, bg=7.5ms, vis=4.1ms, total=82.7ms
# Frame 1494: preprocess=3.9ms, move=20.0ms, static=36.4ms, kalman=0.0ms tracking=0.0ms, bg=6.6ms, vis=3.8ms, total=70.7ms
# Frame 1495: preprocess=3.7ms, move=19.9ms, static=46.2ms, kalman=0.0ms tracking=0.0ms, bg=8.4ms, vis=3.9ms, total=82.2ms
# Frame 1496: preprocess=3.1ms, move=19.9ms, static=43.2ms, kalman=0.0ms tracking=0.0ms, bg=7.0ms, vis=4.6ms, total=77.9ms
# Frame 1497: preprocess=7.8ms, move=19.1ms, static=41.0ms, kalman=0.0ms tracking=0.0ms, bg=7.0ms, vis=4.7ms, total=79.7ms
# Frame 1498: preprocess=2.9ms, move=19.2ms, static=42.2ms, kalman=0.0ms tracking=0.0ms, bg=7.0ms, vis=5.8ms, total=77.2ms
# Frame 1499: preprocess=3.6ms, move=23.5ms, static=44.8ms, kalman=0.0ms tracking=0.0ms, bg=6.8ms, vis=4.8ms, total=83.6ms
# Frame 1500: preprocess=3.7ms, move=24.8ms, static=52.7ms, kalman=0.0ms tracking=0.0ms, bg=6.7ms, vis=7.5ms, total=95.5ms
# Frame 1501: preprocess=3.8ms, move=25.2ms, static=42.4ms, kalman=0.0ms tracking=0.0ms, bg=6.9ms, vis=4.1ms, total=82.5ms
# Frame 1502: preprocess=4.2ms, move=21.7ms, static=48.2ms, kalman=0.0ms tracking=0.2ms, bg=9.4ms, vis=3.9ms, total=87.5ms
# Frame 1503: preprocess=3.7ms, move=24.7ms, static=47.5ms, kalman=0.0ms tracking=0.0ms, bg=9.9ms, vis=4.0ms, total=89.8ms
# Frame 1504: preprocess=4.7ms, move=22.4ms, static=62.6ms, kalman=0.0ms tracking=0.0ms, bg=11.8ms, vis=5.0ms, total=106.7ms
# Frame 1505: preprocess=6.5ms, move=23.0ms, static=39.7ms, kalman=0.0ms tracking=0.0ms, bg=7.3ms, vis=3.3ms, total=79.9ms
# Frame 1506: preprocess=6.9ms, move=21.7ms, static=39.5ms, kalman=0.0ms tracking=0.0ms, bg=7.3ms, vis=3.2ms, total=78.7ms
# Frame 1507: preprocess=3.7ms, move=18.6ms, static=34.0ms, kalman=0.0ms tracking=0.0ms, bg=7.5ms, vis=3.3ms, total=67.2ms
# Frame 1508: preprocess=2.5ms, move=17.6ms, static=34.8ms, kalman=0.0ms tracking=0.0ms, bg=7.6ms, vis=2.9ms, total=65.4ms
# Frame 1509: preprocess=2.9ms, move=18.5ms, static=34.7ms, kalman=0.0ms tracking=0.0ms, bg=6.1ms, vis=3.1ms, total=65.4ms
# Frame 1510: preprocess=3.8ms, move=16.3ms, static=37.6ms, kalman=0.0ms tracking=0.0ms, bg=6.5ms, vis=3.3ms, total=67.6ms
# Frame 1511: preprocess=2.3ms, move=14.6ms, static=32.5ms, kalman=0.0ms tracking=0.0ms, bg=6.7ms, vis=3.1ms, total=59.2ms
# Frame 1512: preprocess=2.6ms, move=15.9ms, static=33.7ms, kalman=0.0ms tracking=0.0ms, bg=6.8ms, vis=3.1ms, total=62.1ms
# Frame 1513: preprocess=2.4ms, move=17.6ms, static=36.0ms, kalman=0.0ms tracking=0.0ms, bg=6.7ms, vis=3.1ms, total=65.9ms
# Frame 1514: preprocess=3.8ms, move=17.1ms, static=34.1ms, kalman=0.0ms tracking=0.0ms, bg=6.1ms, vis=3.1ms, total=64.3ms
# Frame 1515: preprocess=3.9ms, move=15.8ms, static=31.5ms, kalman=0.0ms tracking=0.0ms, bg=6.7ms, vis=3.2ms, total=61.0ms
# Frame 1516: preprocess=2.5ms, move=16.5ms, static=42.0ms, kalman=0.0ms tracking=0.0ms, bg=6.8ms, vis=3.0ms, total=70.9ms
# Frame 1517: preprocess=2.7ms, move=15.3ms, static=33.8ms, kalman=0.0ms tracking=0.0ms, bg=6.4ms, vis=3.3ms, total=61.6ms
# Frame 1518: preprocess=2.7ms, move=16.3ms, static=31.0ms, kalman=0.0ms tracking=0.0ms, bg=6.5ms, vis=3.0ms, total=59.6ms
# Frame 1519: preprocess=3.2ms, move=14.8ms, static=35.3ms, kalman=0.0ms tracking=0.0ms, bg=6.4ms, vis=2.8ms, total=62.4ms
# Frame 1520: preprocess=2.5ms, move=14.7ms, static=35.2ms, kalman=0.0ms tracking=0.0ms, bg=6.4ms, vis=3.5ms, total=62.3ms
# Frame 1521: preprocess=2.7ms, move=15.3ms, static=36.8ms, kalman=0.0ms tracking=0.0ms, bg=6.4ms, vis=4.9ms, total=66.2ms
# Frame 1522: preprocess=3.2ms, move=18.8ms, static=37.4ms, kalman=0.0ms tracking=0.0ms, bg=9.8ms, vis=3.3ms, total=72.6ms
# Frame 1523: preprocess=2.6ms, move=17.0ms, static=34.2ms, kalman=0.0ms tracking=0.0ms, bg=6.3ms, vis=3.6ms, total=63.7ms
# Frame 1524: preprocess=2.9ms, move=13.9ms, static=34.1ms, kalman=0.0ms tracking=0.0ms, bg=6.1ms, vis=3.1ms, total=60.2ms
# Frame 1525: preprocess=2.5ms, move=17.6ms, static=34.7ms, kalman=0.0ms tracking=0.0ms, bg=6.3ms, vis=2.7ms, total=63.8ms
# Frame 1526: preprocess=4.8ms, move=16.6ms, static=32.6ms, kalman=0.0ms tracking=0.0ms, bg=6.7ms, vis=2.6ms, total=63.4ms
# Frame 1527: preprocess=2.4ms, move=18.0ms, static=35.4ms, kalman=0.0ms tracking=0.0ms, bg=6.6ms, vis=4.0ms, total=66.4ms
# Frame 1528: preprocess=4.6ms, move=17.2ms, static=34.9ms, kalman=0.0ms tracking=0.0ms, bg=6.4ms, vis=3.8ms, total=67.0ms
# Frame 1529: preprocess=2.6ms, move=14.2ms, static=32.4ms, kalman=0.0ms tracking=0.1ms, bg=6.7ms, vis=2.9ms, total=58.8ms
# Frame 1530: preprocess=2.5ms, move=16.3ms, static=35.4ms, kalman=0.0ms tracking=0.0ms, bg=6.2ms, vis=2.9ms, total=63.4ms
# Frame 1531: preprocess=3.6ms, move=15.0ms, static=33.3ms, kalman=0.0ms tracking=0.1ms, bg=6.4ms, vis=2.5ms, total=60.9ms
# Frame 1532: preprocess=4.8ms, move=16.3ms, static=33.4ms, kalman=0.0ms tracking=0.0ms, bg=8.4ms, vis=2.4ms, total=65.5ms
# Frame 1533: preprocess=2.4ms, move=14.4ms, static=35.0ms, kalman=0.0ms tracking=0.0ms, bg=6.9ms, vis=3.3ms, total=62.0ms
# Frame 1534: preprocess=2.0ms, move=14.5ms, static=31.8ms, kalman=0.0ms tracking=0.0ms, bg=5.7ms, vis=2.6ms, total=56.8ms
# Frame 1535: preprocess=3.1ms, move=15.5ms, static=32.8ms, kalman=0.0ms tracking=0.1ms, bg=6.4ms, vis=2.9ms, total=60.9ms
# Frame 1536: preprocess=2.7ms, move=14.6ms, static=33.3ms, kalman=0.0ms tracking=0.1ms, bg=6.1ms, vis=2.5ms, total=59.3ms
# Frame 1537: preprocess=2.3ms, move=15.0ms, static=34.6ms, kalman=0.0ms tracking=0.1ms, bg=6.5ms, vis=3.0ms, total=61.4ms
# Frame 1538: preprocess=3.1ms, move=14.2ms, static=32.8ms, kalman=0.0ms tracking=0.1ms, bg=6.8ms, vis=2.7ms, total=59.8ms
# Frame 1539: preprocess=2.5ms, move=16.8ms, static=34.4ms, kalman=0.0ms tracking=0.1ms, bg=5.9ms, vis=2.9ms, total=62.5ms
# Frame 1540: preprocess=2.0ms, move=14.1ms, static=34.7ms, kalman=0.0ms tracking=0.1ms, bg=6.2ms, vis=3.2ms, total=60.3ms
# Frame 1541: preprocess=3.3ms, move=14.2ms, static=31.8ms, kalman=0.0ms tracking=0.1ms, bg=7.0ms, vis=2.4ms, total=58.7ms
# Frame 1542: preprocess=3.0ms, move=13.5ms, static=32.5ms, kalman=0.0ms tracking=0.1ms, bg=5.9ms, vis=2.4ms, total=57.3ms
# Frame 1543: preprocess=3.3ms, move=14.6ms, static=30.3ms, kalman=0.0ms tracking=0.1ms, bg=5.7ms, vis=2.6ms, total=56.6ms
# Frame 1544: preprocess=1.8ms, move=13.1ms, static=30.2ms, kalman=0.0ms tracking=0.1ms, bg=5.8ms, vis=3.1ms, total=54.1ms
# Frame 1545: preprocess=1.8ms, move=15.0ms, static=32.1ms, kalman=0.0ms tracking=0.1ms, bg=5.9ms, vis=2.4ms, total=57.4ms
# Frame 1546: preprocess=2.6ms, move=14.3ms, static=36.4ms, kalman=0.0ms tracking=0.1ms, bg=6.2ms, vis=2.3ms, total=61.9ms
# Frame 1547: preprocess=1.8ms, move=13.0ms, static=33.5ms, kalman=0.0ms tracking=0.1ms, bg=5.5ms, vis=3.6ms, total=57.6ms
# Frame 1548: preprocess=2.5ms, move=14.2ms, static=34.1ms, kalman=0.0ms tracking=0.0ms, bg=5.5ms, vis=2.3ms, total=58.7ms
# Frame 1549: preprocess=3.8ms, move=14.4ms, static=30.3ms, kalman=0.0ms tracking=0.0ms, bg=5.2ms, vis=2.5ms, total=56.3ms
# Frame 1550: preprocess=2.1ms, move=13.3ms, static=31.7ms, kalman=0.0ms tracking=0.1ms, bg=6.0ms, vis=2.2ms, total=55.4ms
# Frame 1551: preprocess=1.8ms, move=13.8ms, static=31.3ms, kalman=0.0ms tracking=0.0ms, bg=5.4ms, vis=2.9ms, total=55.3ms
# Frame 1552: preprocess=2.1ms, move=14.0ms, static=32.7ms, kalman=0.0ms tracking=0.1ms, bg=5.8ms, vis=1.9ms, total=56.5ms
# Frame 1553: preprocess=2.0ms, move=14.8ms, static=30.2ms, kalman=0.0ms tracking=0.1ms, bg=5.1ms, vis=2.5ms, total=54.6ms
# Frame 1554: preprocess=2.8ms, move=12.9ms, static=30.6ms, kalman=0.0ms tracking=0.1ms, bg=6.2ms, vis=2.6ms, total=55.1ms
# Done processing.

# %%
# === RESULTS AND DIAGNOSTICS ===

# latency metrics
#print(f"Processed {frame_idx} frames")
print(f"Average per-frame latency: {np.mean(latencies):.2f} ms")
print(f"Max per-frame latency: {np.max(latencies):.2f} ms")
print(f"Estimated FPS capability: {1000.0 / np.mean(latencies):.1f} FPS")

# plot latency distribution 
plt.figure()
plt.hist(latencies, bins=30)
plt.xlabel("Latency per frame (ms)")
plt.ylabel("Count")
plt.title("Frame Processing Latency Distribution")
plt.show()

#plot detection metrics to quantitatively show scaling behavior
plt.figure()
plt.plot(det_counts, label="Detections")
plt.plot(track_counts, label="Active Tracks")
plt.legend()
plt.title("Multi-target Capacity Over Time")
plt.xlabel("Frame")
plt.ylabel("Count")
plt.show()
# Out:
# Average per-frame latency: 90.50 ms
# Max per-frame latency: 2126.98 ms
# Estimated FPS capability: 11.0 FPS

# %%
#TODO figure out how to evaluate error

#pred_err, post_err = [], []
#for t in tracks:
 #   for pred, meas, post in zip(t.history["pred"], t.history["meas"], t.history["post"]):
  #      pred_err.append(np.linalg.norm(np.array(pred)-np.array(meas)))
   #     post_err.append(np.linalg.norm(np.array(post)-np.array(meas)))

# %%
# example frames
num_show = min(50, len(frames))
for i in range(num_show):
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.imshow(frames[i][..., ::-1])
    plt.title("Tracked Flies")
    plt.axis("off")
    
    
    plt.subplot(1,2,2)
    plt.imshow(thresh_frames[i], cmap='gray')
    plt.title("Frame Subtraction Mask")
    plt.axis("off")
    plt.show()
